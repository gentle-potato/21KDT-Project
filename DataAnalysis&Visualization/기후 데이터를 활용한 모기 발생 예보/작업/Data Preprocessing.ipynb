# %%
import numpy as np
import pandas as pd
import pandas_profiling

# %%
# !cd
# Out:
# C:\Users\khl06\Desktop\Mr.GentleKim\21KDT\21KDT-Project\DataAnalysis&Visualization\기후 데이터를 활용한 모기 발생 예보\작업

# %% [markdown]
# ## 1. 서울 DMS + 기후

# %% [markdown]
# ### Reading Data

# %%
df = pd.read_csv('../데이터/통합 데이터/1. dms_seoul.csv')

df
# Out:
#             date  mosquito  temp  l_temp  h_temp  rain_per_day  cum_rain  \
# 0     2015-04-06       199  10.3     6.9    15.4           NaN         0
# 1     2015-04-07       146   8.4     5.5    12.2           NaN         0
# 2     2015-04-08        90   8.3     3.5    13.7           NaN         0
# 3     2015-04-09       172   9.6     3.8    16.3           NaN         0
# 4     2015-04-10       249  11.6     4.6    19.2           NaN         0
# ...          ...       ...   ...     ...     ...           ...       ...
# 1168  2020-10-27       535  14.0     9.0    19.4           NaN         0
# 1169  2020-10-28       884  13.8     8.6    18.2           NaN         0
# 1170  2020-10-29       695  10.8     5.5    16.1           NaN         0
# 1171  2020-10-30       543  11.9     5.8    19.6           NaN         0
# 1172  2020-10-31       454  13.6     8.5    18.2           NaN         0
#
#       wind  dew  humidity  steam_pressure  sunshine_time  sunshine  \
# 0      2.7  1.2      55.8             6.8            1.7     10.20
# 1      2.6  0.9      59.5             6.5            4.7     10.17
# 2      2.9 -1.3      52.5             5.6            8.3     14.69
# 3      2.3 -2.8      43.0             5.0           10.8     18.20
# 4      2.8 -2.2      40.5             5.3           11.6     20.67
# ...    ...  ...       ...             ...            ...       ...
# 1168   1.8  9.0      74.1            11.6            8.3     12.23
# 1169   2.5  2.8      52.1             8.2            9.2     15.27
# 1170   2.0 -2.6      40.3             5.1            9.0     13.77
# 1171   1.5 -0.8      42.9             5.8            9.7     14.62
# 1172   2.6  5.9      60.3             9.3            5.8     11.03
#
#       ground_surface_temp
# 0                    11.0
# 1                    11.6
# 2                     9.6
# 3                    11.8
# 4                    13.3
# ...                   ...
# 1168                 13.2
# 1169                 13.8
# 1170                 11.5
# 1171                 11.2
# 1172                 12.9
#
# [1173 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# date                     0
# mosquito                 0
# temp                     0
# l_temp                   0
# h_temp                   1
# rain_per_day           795
# cum_rain                 0
# wind                     0
# dew                      0
# humidity                 0
# steam_pressure           0
# sunshine_time            0
# sunshine                 0
# ground_surface_temp      0
# dtype: int64

# %%
sum(np.isnan(df['rain_per_day']))
# Out:
# 795

# %%
# temp(평균기온)만 남기고 평균기온과 상관성이 큰 컬럼과 date 컬럼 제거
date = df['date']
df.drop(['date', 'l_temp', 'h_temp', 'dew', 'ground_surface_temp'], axis=1, inplace=True)

df
# Out:
#       mosquito  temp  rain_per_day  cum_rain  wind  humidity  steam_pressure  \
# 0          199  10.3           NaN         0   2.7      55.8             6.8
# 1          146   8.4           NaN         0   2.6      59.5             6.5
# 2           90   8.3           NaN         0   2.9      52.5             5.6
# 3          172   9.6           NaN         0   2.3      43.0             5.0
# 4          249  11.6           NaN         0   2.8      40.5             5.3
# ...        ...   ...           ...       ...   ...       ...             ...
# 1168       535  14.0           NaN         0   1.8      74.1            11.6
# 1169       884  13.8           NaN         0   2.5      52.1             8.2
# 1170       695  10.8           NaN         0   2.0      40.3             5.1
# 1171       543  11.9           NaN         0   1.5      42.9             5.8
# 1172       454  13.6           NaN         0   2.6      60.3             9.3
#
#       sunshine_time  sunshine
# 0               1.7     10.20
# 1               4.7     10.17
# 2               8.3     14.69
# 3              10.8     18.20
# 4              11.6     20.67
# ...             ...       ...
# 1168            8.3     12.23
# 1169            9.2     15.27
# 1170            9.0     13.77
# 1171            9.7     14.62
# 1172            5.8     11.03
#
# [1173 rows x 9 columns]

# %% [markdown]
# ### Setting Target Variable

# %%
y = df['mosquito']
X = df.drop('mosquito', axis=1)

# %%
y.head()
# Out:
# 0    199
# 1    146
# 2     90
# 3    172
# 4    249
# Name: mosquito, dtype: int64

# %%
X.head()
# Out:
#    temp  rain_per_day  cum_rain  wind  humidity  steam_pressure  \
# 0  10.3           NaN         0   2.7      55.8             6.8
# 1   8.4           NaN         0   2.6      59.5             6.5
# 2   8.3           NaN         0   2.9      52.5             5.6
# 3   9.6           NaN         0   2.3      43.0             5.0
# 4  11.6           NaN         0   2.8      40.5             5.3
#
#    sunshine_time  sunshine
# 0            1.7     10.20
# 1            4.7     10.17
# 2            8.3     14.69
# 3           10.8     18.20
# 4           11.6     20.67

# %% [markdown]
# ### Imputation

# %%
y = y.values
X = X.values

sum(np.isnan(X).flatten())
# Out:
# 795

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='constant', fill_value=0)

imputer.fit(X)
# Out:
# SimpleImputer(fill_value=0, strategy='constant')

# %%
X_trans = imputer.transform(X)

# %%
sum(np.isnan(X_trans).flatten())
# Out:
# 0

# %% [markdown]
# ### To CSV

# %%
y = pd.DataFrame(y, columns=['mosquito'])

y.head()
# Out:
#    mosquito
# 0       199
# 1       146
# 2        90
# 3       172
# 4       249

# %%
X_trans = pd.DataFrame(X_trans, columns=['temp', 'rain_per_day', 'cum_rain', 'wind', 'humidity', 'steam_pressure', 'sunshine_time', 'sunshine'])

X_trans.head()
# Out:
#    temp  rain_per_day  cum_rain  wind  humidity  steam_pressure  \
# 0  10.3           0.0       0.0   2.7      55.8             6.8
# 1   8.4           0.0       0.0   2.6      59.5             6.5
# 2   8.3           0.0       0.0   2.9      52.5             5.6
# 3   9.6           0.0       0.0   2.3      43.0             5.0
# 4  11.6           0.0       0.0   2.8      40.5             5.3
#
#    sunshine_time  sunshine
# 0            1.7     10.20
# 1            4.7     10.17
# 2            8.3     14.69
# 3           10.8     18.20
# 4           11.6     20.67

# %%
data = pd.concat([date, y, X_trans], axis=1)

data.head()
# Out:
#          date  mosquito  temp  rain_per_day  cum_rain  wind  humidity  \
# 0  2015-04-06       199  10.3           0.0       0.0   2.7      55.8
# 1  2015-04-07       146   8.4           0.0       0.0   2.6      59.5
# 2  2015-04-08        90   8.3           0.0       0.0   2.9      52.5
# 3  2015-04-09       172   9.6           0.0       0.0   2.3      43.0
# 4  2015-04-10       249  11.6           0.0       0.0   2.8      40.5
#
#    steam_pressure  sunshine_time  sunshine
# 0             6.8            1.7     10.20
# 1             6.5            4.7     10.17
# 2             5.6            8.3     14.69
# 3             5.0           10.8     18.20
# 4             5.3           11.6     20.67

# %%
data.to_csv('1. dms_seoul.csv')
# index 컬럼이 새로 생성되기 때문에 csv 파일에서 컬럼 제거 필요

# %% [markdown]
# ## 2. 서울 DMS + 7일 전 기후

# %% [markdown]
# ### Reading Data

# %%
df = pd.read_csv('../데이터/통합 데이터/2. dms_seoul_07.csv')

df
# Out:
#             date  mosquito  temp  l_temp  h_temp  rain_per_day  cum_rain  \
# 0     2015-04-06       199  12.0     7.4    17.6           6.5         1
# 1     2015-04-07       146   6.9     5.8     8.0          10.5         2
# 2     2015-04-08        90  11.1     5.6    17.0           1.0         3
# 3     2015-04-09       172   9.9     6.9    14.8           7.0         4
# 4     2015-04-10       249  10.5     4.8    16.1           NaN         0
# ...          ...       ...   ...     ...     ...           ...       ...
# 1168  2020-10-27       535   5.1     2.7     8.6           0.5         3
# 1169  2020-10-28       884   4.9     0.2    10.8           NaN         0
# 1170  2020-10-29       695   9.6     3.4    15.9           NaN         0
# 1171  2020-10-30       543  13.5     9.9    17.2           NaN         0
# 1172  2020-10-31       454  14.6    12.2    18.1           0.1         1
#
#       wind  dew  humidity  steam_pressure  sunshine_time  sunshine  \
# 0      5.9  1.9      53.9             7.1            5.6     14.89
# 1      2.7  5.3      89.9             8.9            0.0      5.33
# 2      2.9  5.8      72.0             9.2            8.5     16.51
# 3      3.6  4.4      69.5             8.5            1.1      3.64
# 4      3.7 -1.7      45.4             5.4           12.1     22.45
# ...    ...  ...       ...             ...            ...       ...
# 1168   3.5 -5.4      47.5             4.1            9.2     15.22
# 1169   2.3 -7.1      43.9             3.7            9.6     15.36
# 1170   1.8  2.3      61.5             7.3            8.4     12.77
# 1171   1.7  6.4      63.3             9.8            0.3      5.65
# 1172   2.7  8.4      68.8            11.2            7.0     11.01
#
#       ground_surface_temp
# 0                    14.7
# 1                     9.8
# 2                    13.6
# 3                     8.7
# 4                    12.6
# ...                   ...
# 1168                  6.1
# 1169                  5.2
# 1170                 10.5
# 1171                 12.5
# 1172                 14.6
#
# [1173 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# date                     0
# mosquito                 0
# temp                     0
# l_temp                   0
# h_temp                   0
# rain_per_day           794
# cum_rain                 0
# wind                     0
# dew                      0
# humidity                 0
# steam_pressure           0
# sunshine_time            0
# sunshine                 0
# ground_surface_temp      0
# dtype: int64

# %%
sum(np.isnan(df['rain_per_day']))
# Out:
# 794

# %%
# temp(평균기온)만 남기고 평균기온과 상관성이 큰 컬럼과 date 컬럼 제거
date = df['date']
df.drop(['date', 'l_temp', 'h_temp', 'dew', 'ground_surface_temp'], axis=1, inplace=True)

df
# Out:
#       mosquito  temp  rain_per_day  cum_rain  wind  humidity  steam_pressure  \
# 0          199  12.0           6.5         1   5.9      53.9             7.1
# 1          146   6.9          10.5         2   2.7      89.9             8.9
# 2           90  11.1           1.0         3   2.9      72.0             9.2
# 3          172   9.9           7.0         4   3.6      69.5             8.5
# 4          249  10.5           NaN         0   3.7      45.4             5.4
# ...        ...   ...           ...       ...   ...       ...             ...
# 1168       535   5.1           0.5         3   3.5      47.5             4.1
# 1169       884   4.9           NaN         0   2.3      43.9             3.7
# 1170       695   9.6           NaN         0   1.8      61.5             7.3
# 1171       543  13.5           NaN         0   1.7      63.3             9.8
# 1172       454  14.6           0.1         1   2.7      68.8            11.2
#
#       sunshine_time  sunshine
# 0               5.6     14.89
# 1               0.0      5.33
# 2               8.5     16.51
# 3               1.1      3.64
# 4              12.1     22.45
# ...             ...       ...
# 1168            9.2     15.22
# 1169            9.6     15.36
# 1170            8.4     12.77
# 1171            0.3      5.65
# 1172            7.0     11.01
#
# [1173 rows x 9 columns]

# %% [markdown]
# ### Setting Target Variable

# %%
y = df['mosquito']
X = df.drop('mosquito', axis=1)

# %%
y.head()
# Out:
# 0    199
# 1    146
# 2     90
# 3    172
# 4    249
# Name: mosquito, dtype: int64

# %%
X.head()
# Out:
#    temp  rain_per_day  cum_rain  wind  humidity  steam_pressure  \
# 0  12.0           6.5         1   5.9      53.9             7.1
# 1   6.9          10.5         2   2.7      89.9             8.9
# 2  11.1           1.0         3   2.9      72.0             9.2
# 3   9.9           7.0         4   3.6      69.5             8.5
# 4  10.5           NaN         0   3.7      45.4             5.4
#
#    sunshine_time  sunshine
# 0            5.6     14.89
# 1            0.0      5.33
# 2            8.5     16.51
# 3            1.1      3.64
# 4           12.1     22.45

# %% [markdown]
# ### Imputation

# %%
y = y.values
X = X.values

sum(np.isnan(X).flatten())
# Out:
# 794

# %%
X_trans = imputer.transform(X)

# %%
sum(np.isnan(X_trans).flatten())
# Out:
# 0

# %% [markdown]
# ### To CSV

# %%
y = pd.DataFrame(y, columns=['mosquito'])

y.head()
# Out:
#    mosquito
# 0       199
# 1       146
# 2        90
# 3       172
# 4       249

# %%
X_trans = pd.DataFrame(X_trans, columns=['temp', 'rain_per_day', 'cum_rain', 'wind', 'humidity', 'steam_pressure', 'sunshine_time', 'sunshine'])

X_trans.head()
# Out:
#    temp  rain_per_day  cum_rain  wind  humidity  steam_pressure  \
# 0  12.0           6.5       1.0   5.9      53.9             7.1
# 1   6.9          10.5       2.0   2.7      89.9             8.9
# 2  11.1           1.0       3.0   2.9      72.0             9.2
# 3   9.9           7.0       4.0   3.6      69.5             8.5
# 4  10.5           0.0       0.0   3.7      45.4             5.4
#
#    sunshine_time  sunshine
# 0            5.6     14.89
# 1            0.0      5.33
# 2            8.5     16.51
# 3            1.1      3.64
# 4           12.1     22.45

# %%
data = pd.concat([date, y, X_trans], axis=1)

data.head()
# Out:
#          date  mosquito  temp  rain_per_day  cum_rain  wind  humidity  \
# 0  2015-04-06       199  12.0           6.5       1.0   5.9      53.9
# 1  2015-04-07       146   6.9          10.5       2.0   2.7      89.9
# 2  2015-04-08        90  11.1           1.0       3.0   2.9      72.0
# 3  2015-04-09       172   9.9           7.0       4.0   3.6      69.5
# 4  2015-04-10       249  10.5           0.0       0.0   3.7      45.4
#
#    steam_pressure  sunshine_time  sunshine
# 0             7.1            5.6     14.89
# 1             8.9            0.0      5.33
# 2             9.2            8.5     16.51
# 3             8.5            1.1      3.64
# 4             5.4           12.1     22.45

# %%
data.to_csv('2. dms_seoul_07.csv')
# index 컬럼이 새로 생성되기 때문에 csv 파일에서 컬럼 제거 필요

# %% [markdown]
# ## 서울 DMS + 14일 전 기후

# %% [markdown]
# ### Reading Data

# %%
df = pd.read_csv('../데이터/통합 데이터/3. dms_seoul_14.csv')

df
# Out:
#             date  mosquito  temp  l_temp  h_temp  rain_per_day  cum_rain  \
# 0     2015-04-06       199  12.2    10.3    16.8           5.5         2
# 1     2015-04-07       146  14.0     7.7    20.9           NaN         0
# 2     2015-04-08        90  14.2     9.3    20.7           NaN         0
# 3     2015-04-09       172  14.5     8.0    20.1           NaN         0
# 4     2015-04-10       249  15.7    10.4    22.8           NaN         0
# ...          ...       ...   ...     ...     ...           ...       ...
# 1168  2020-10-27       535   7.7     3.5    12.9           NaN         0
# 1169  2020-10-28       884   9.3     3.5    16.5           NaN         0
# 1170  2020-10-29       695  10.4     4.6    17.7           NaN         0
# 1171  2020-10-30       543  12.2     8.5    17.6           NaN         0
# 1172  2020-10-31       454  12.5     6.8    19.3           NaN         0
#
#       wind  dew  humidity  steam_pressure  sunshine_time  sunshine  \
# 0      3.2  7.6      75.3            10.5            3.2      8.68
# 1      2.9  0.1      46.0             6.6           12.5     22.93
# 2      3.0  2.7      47.0             7.5           11.2     19.32
# 3      3.5  0.0      41.1             6.2           10.8     21.03
# 4      3.2 -0.1      38.3             6.3           12.2     22.53
# ...    ...  ...       ...             ...            ...       ...
# 1168   2.2 -0.9      56.1             5.8            9.6     13.61
# 1169   1.6 -0.2      53.5             6.1            9.6     12.96
# 1170   1.7  1.6      56.9             6.9            9.4     12.27
# 1171   1.6  6.9      71.5            10.0            5.5      8.92
# 1172   1.7  5.8      66.9             9.2            8.0     11.58
#
#       ground_surface_temp
# 0                    14.3
# 1                    15.8
# 2                    15.0
# 3                    15.7
# 4                    18.5
# ...                   ...
# 1168                  7.9
# 1169                  8.7
# 1170                  9.2
# 1171                 12.1
# 1172                 10.9
#
# [1173 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# date                     0
# mosquito                 0
# temp                     0
# l_temp                   0
# h_temp                   0
# rain_per_day           794
# cum_rain                 0
# wind                     0
# dew                      0
# humidity                 0
# steam_pressure           0
# sunshine_time            0
# sunshine                 0
# ground_surface_temp      0
# dtype: int64

# %%
sum(np.isnan(df['rain_per_day']))
# Out:
# 794

# %%
# temp(평균기온)만 남기고 평균기온과 상관성이 큰 컬럼과 date 컬럼 제거
date = df['date']
df.drop(['date', 'l_temp', 'h_temp', 'dew', 'ground_surface_temp'], axis=1, inplace=True)

df
# Out:
#       mosquito  temp  rain_per_day  cum_rain  wind  humidity  steam_pressure  \
# 0          199  12.2           5.5         2   3.2      75.3            10.5
# 1          146  14.0           NaN         0   2.9      46.0             6.6
# 2           90  14.2           NaN         0   3.0      47.0             7.5
# 3          172  14.5           NaN         0   3.5      41.1             6.2
# 4          249  15.7           NaN         0   3.2      38.3             6.3
# ...        ...   ...           ...       ...   ...       ...             ...
# 1168       535   7.7           NaN         0   2.2      56.1             5.8
# 1169       884   9.3           NaN         0   1.6      53.5             6.1
# 1170       695  10.4           NaN         0   1.7      56.9             6.9
# 1171       543  12.2           NaN         0   1.6      71.5            10.0
# 1172       454  12.5           NaN         0   1.7      66.9             9.2
#
#       sunshine_time  sunshine
# 0               3.2      8.68
# 1              12.5     22.93
# 2              11.2     19.32
# 3              10.8     21.03
# 4              12.2     22.53
# ...             ...       ...
# 1168            9.6     13.61
# 1169            9.6     12.96
# 1170            9.4     12.27
# 1171            5.5      8.92
# 1172            8.0     11.58
#
# [1173 rows x 9 columns]

# %% [markdown]
# ### Setting Target Variable

# %%
y = df['mosquito']
X = df.drop('mosquito', axis=1)

# %%
y.head()
# Out:
# 0    199
# 1    146
# 2     90
# 3    172
# 4    249
# Name: mosquito, dtype: int64

# %%
X.head()
# Out:
#    temp  rain_per_day  cum_rain  wind  humidity  steam_pressure  \
# 0  12.2           5.5         2   3.2      75.3            10.5
# 1  14.0           NaN         0   2.9      46.0             6.6
# 2  14.2           NaN         0   3.0      47.0             7.5
# 3  14.5           NaN         0   3.5      41.1             6.2
# 4  15.7           NaN         0   3.2      38.3             6.3
#
#    sunshine_time  sunshine
# 0            3.2      8.68
# 1           12.5     22.93
# 2           11.2     19.32
# 3           10.8     21.03
# 4           12.2     22.53

# %% [markdown]
# ### Imputation

# %%
y = y.values
X = X.values

sum(np.isnan(X).flatten())
# Out:
# 794

# %%
imputer.fit(X)
# Out:
# SimpleImputer(fill_value=0, strategy='constant')

# %%
X_trans = imputer.transform(X)

# %%
sum(np.isnan(X_trans).flatten())
# Out:
# 0

# %% [markdown]
# ### To CSV

# %%
y = pd.DataFrame(y, columns=['mosquito'])

y.head()
# Out:
#    mosquito
# 0       199
# 1       146
# 2        90
# 3       172
# 4       249

# %%
X_trans = pd.DataFrame(X_trans, columns=['temp', 'rain_per_day', 'cum_rain', 'wind', 'humidity', 'steam_pressure', 'sunshine_time', 'sunshine'])

X_trans.head()
# Out:
#    temp  rain_per_day  cum_rain  wind  humidity  steam_pressure  \
# 0  12.2           5.5       2.0   3.2      75.3            10.5
# 1  14.0           0.0       0.0   2.9      46.0             6.6
# 2  14.2           0.0       0.0   3.0      47.0             7.5
# 3  14.5           0.0       0.0   3.5      41.1             6.2
# 4  15.7           0.0       0.0   3.2      38.3             6.3
#
#    sunshine_time  sunshine
# 0            3.2      8.68
# 1           12.5     22.93
# 2           11.2     19.32
# 3           10.8     21.03
# 4           12.2     22.53

# %%
data = pd.concat([date, y, X_trans], axis=1)

data.head()
# Out:
#          date  mosquito  temp  rain_per_day  cum_rain  wind  humidity  \
# 0  2015-04-06       199  12.2           5.5       2.0   3.2      75.3
# 1  2015-04-07       146  14.0           0.0       0.0   2.9      46.0
# 2  2015-04-08        90  14.2           0.0       0.0   3.0      47.0
# 3  2015-04-09       172  14.5           0.0       0.0   3.5      41.1
# 4  2015-04-10       249  15.7           0.0       0.0   3.2      38.3
#
#    steam_pressure  sunshine_time  sunshine
# 0            10.5            3.2      8.68
# 1             6.6           12.5     22.93
# 2             7.5           11.2     19.32
# 3             6.2           10.8     21.03
# 4             6.3           12.2     22.53

# %%
data.to_csv('3. dms_seoul_14.csv')
# index 컬럼이 새로 생성되기 때문에 csv 파일에서 컬럼 제거 필요
