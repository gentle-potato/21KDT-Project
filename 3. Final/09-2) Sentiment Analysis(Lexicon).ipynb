# %% [markdown]
# # **Sentiment Analysis(Lexicon)**

# %%
import numpy as np
import pandas as pd

### Visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

### DB 연결
# !pip install pymysql
import pymysql

### DB에 저장
import sqlalchemy
from sqlalchemy import create_engine

### 실시간 주식가격 데이터
# !pip install finance-datareader
import FinanceDataReader as fdr

### 텍스트 분석
## KoNLPy
# 1) JAVA 설치, 2) Python 버전과 맞는 JPype1-py3 설치, 3) !pip install konlpy, 4) 설치 경로에서 jvm.py 파일 코드 67번 줄 주석 처리 
from konlpy.tag import Okt
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import re
## FastText
# !pip install gensim
# !pip install fasttext
import fasttext
import fasttext.util
# Facebook 한국어 Embedding 모델 다운로드 → 한 번만 설치하면 됨
# fasttext.util.download_model('ko', if_exists='ignore')   # FastText 모델 사용 시에만 필요
# 유사도 계산
from gensim import models

### 모델 학습 및 평가
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.metrics import precision_score, recall_score, f1_score

### 모델 저장 및 로드
import joblib

### 기타
import datetime
from collections import Counter
import sys
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## **Read Data**

# %% [markdown]
# ### **① KOSELF + Blog 감성사전**

# %%
# 블로그에서 가져온 기본적인 한국어 긍부정 텍스트 목록
with open('positive_words_self.txt', encoding='utf-8') as pos_blog:
    positive_blog = pos_blog.readlines()
positive_blog = [pos_blog.replace('\n', '') for pos_blog in positive_blog]
with open('negative_words_self.txt', encoding='utf-8') as neg_blog:
    negative_blog = neg_blog.readlines()
negative_blog = [neg_blog.replace('\n', '') for neg_blog in negative_blog]

# KOSELF 감성 어휘 사전
with open('KOSELF_pos.txt', encoding='utf-8') as pos:
    positive = pos.readlines()
positive = [pos.replace('\n', '') for pos in positive]
with open('KOSELF_neg.txt', encoding='utf-8') as neg:
    negative = neg.readlines()
negative = [neg.replace('\n', '') for neg in negative]

# %%
len(positive), len(positive_blog), len(negative), len(negative_blog)
# Out:
# (48, 46, 47, 74)

# %%
# 긍정사전 통합
for i in range(len(positive_blog)):
    if positive_blog[i] not in positive:
        positive.append(positive_blog[i])

# 부정사전 통합
for i in range(len(negative_blog)):
    if negative_blog[i] not in negative:
        negative.append(negative_blog[i])

# %%
len(positive), len(negative)
# Out:
# (92, 111)

# %%
# 중복 확인
cnt = 0
for i in range(len(positive)):
    if positive[i] in negative:
        cnt += 1

cnt
# Out:
# 0

# %% [markdown]
# ### **② Text Data**

# %%
# 종목별, 연도별 데이터 통합
corp_list = ['samsung', 'hyundai', 'lg', 'sk', 'celltrion']
years = ['2018', '2019', '2020', '2021']
media_list = ['maeil', 'asia']

for i in range(len(corp_list)):
    globals()[corp_list[i] + '_news'] = []
    for j in range(len(years)):
        for k in range(len(media_list)):
            globals()[corp_list[i] + '_' + media_list[k] + '_' + years[j]] = pd.read_csv('../../../../Final Data/{0}_{1}_{2}.csv'.format(years[j], media_list[k], corp_list[i]))
            globals()[corp_list[i] + '_news'].append(globals()[corp_list[i] + '_' + media_list[k] + '_' + years[j]])

# %%
for i in range(len(corp_list)):
    globals()[corp_list[i]] = pd.concat(globals()[corp_list[i] + '_news'], axis=0)

# %% [markdown]
# ## **Sentiment Score**

# %%
samsung[samsung['Tokenization'].isna()]
# Out:
#       st_n  st_cd  news    datetime  \
# 4144  삼성전자   5930  매일경제  2018121204
# 754   삼성전자   5930  매일경제  2021040516
#
#                                                   title  \
# 4144             [2018 대한민국 지식재산대전] 일상의 불편함 없앤 발명품 한자리에
# 754   QLED·OLED·미니LED… 복잡한 TV 제품, 삼성·LG TV 제품별 기능 차이...
#
#                                                     url  \
# 4144  http://news.mk.co.kr/newsRead.php?year=2018&no...
# 754   http://news.mk.co.kr/newsRead.php?no=325040&ye...
#
#                                                    text        date  time  \
# 4144  \n\n\nДыХыЗЩЛѓРЛ МіЛѓЧб КЅУГБтОї ОЦГЏЗЮБзЧУЗЏН...  2018-12-12     4
# 754   ¿ÃÇØ¿¡µµ ´Ù½Ã ÇÑ ¹ø »ï¼ºÀüÀÚ¿Í LGÀüÀÚÀÇ ¡®TV À...  2021-04-06    16
#
#        Open   High    Low  Close    Volume    Change  UpDown Tokenization
# 4144  40250  40700  40150  40450  12024279  0.004969       1          NaN
# 754   86200  86200  85100  86000  19042023  0.007026       1          NaN

# %%
hyundai[hyundai['Tokenization'].isna()]
# Out:
#      st_n  st_cd  news    datetime  \
# 294   현대차   5380  매일경제  2019021914
# 300   현대차   5380  매일경제  2019022011
# 349   현대차   5380  매일경제  2020022017
# 1891  현대차   5380  매일경제  2020103016
# 2198  현대차   5380  매일경제  2020121808
# 2216  현대차   5380  매일경제  2020122113
# 2224  현대차   5380  매일경제  2020122215
# 2251  현대차   5380  매일경제  2020122814
# 272   현대차   5380  매일경제  2021020518
# 467   현대차   5380  매일경제  2021031110
# 589   현대차   5380  매일경제  2021033017
# 775   현대차   5380  매일경제  2021042723
# 872   현대차   5380  매일경제  2021051712
# 891   현대차   5380  매일경제  2021052113
# 1072  현대차   5380  매일경제  2021061822
# 1122  현대차   5380  매일경제  2021062914
# 1131  현대차   5380  매일경제  2021063017
# 1185  현대차   5380  매일경제  2021070710
# 1347  현대차   5380  매일경제  2021080513
# 1389  현대차   5380  매일경제  2021081315
# 1503  현대차   5380  매일경제  2021090616
#
#                                                   title  \
# 294   이시한, 취업계 2년 연속 트렌드 예측 경향성 소름 돋는 적중, ‘문어시한’이 떴다...
# 300       이시한이 말하는, 100:1이 일반화된 채용시장에서 살아남는 방법 - 인터뷰 #2
# 349                     스스로 알아서 최적 기어변속…현대·기아차 세계 최초 개발
# 1891               현대차 `두번` 찾은 문 대통령…"고용안정도 협력사 상생도 1등"
# 2198               "로봇 안내견, 내쫓지 마세요"…현대차, `구조·돌봄 로봇` 공개
# 2216             "없어서 못 팔아"…중고 `싼타페·투싼·포터`, `비대면 수출` 효자
# 2224                 "지금 팔면 돈 버네"…중고 `그랜저·쏘렌토·티볼리`, 몸값↑
# 2251               "팰리세이드, 두고 보자"…더 강해진 `포드 신형 SUV`가 온다
# 272               2월엔 그랜저 팔고 볼보XC60 사라…중고차 가격, 세단↑ SUV↓
# 467            '카니발 강적' 스타리아, '슈퍼맨 아빠' 이동국 탄다…정의선 회장 선물
# 589                시동켜고 3.5초만에 시속100㎞…EV6 역대급 고성능모델 나온다
# 775            타보면 스며든다…'신스틸러' 아이오닉5, 왜 이제야 나왔니 [왜몰랐을카]
# 872             [단독] 사람 죽인 '중고차 허위매물', 결국 '청와대 국민청원' 등장
# 891                     정의선 GO, 현대차 GO…지속가능 미래 화두 'ESG'
# 1072        이 가격엔 '대체불가'…'벤츠 심장' 신형 XM3, 도가 지나쳤네[왜몰랐을카]
# 1122            "정의선 로봇, BTS와 함께 춤췄다"…현대차 '로봇 군무' 영상 공개
# 1131           "이(耳) 맛에 산다"…'막귀도 득음' 현대모비스-메리디안 사운드 시스템
# 1185             현대차그룹 5개사 'RE100' 참여…친환경 재생에너지로 車 생산한다
# 1347      테슬라 도요타 아성 세계 최대 북미 친환경車 '다크호스' 떴다…현대차 판매 4배↑
# 1389         '1조 베팅' 정의선, 로봇 태권V에 꽂혔나…현대차, 의료·탐사 로봇 만든다
# 1503            '만(MAN)사형통' 만트럭 "더 탈만해졌으니 일도 술술 풀릴 겁니다"
#
#                                                     url  \
# 294   http://edu.mk.co.kr/edunews/news_view.php?sc=5...
# 300   http://edu.mk.co.kr/edunews/news_view.php?sc=5...
# 349   http://news.mk.co.kr/newsRead.php?no=178210&ye...
# 1891  http://news.mk.co.kr/newsRead.php?no=1116169&y...
# 2198  http://news.mk.co.kr/newsRead.php?no=1297569&y...
# 2216  http://news.mk.co.kr/newsRead.php?no=1305818&y...
# 2224  http://news.mk.co.kr/newsRead.php?no=1310643&y...
# 2251  http://news.mk.co.kr/newsRead.php?no=1326358&y...
# 272   http://news.mk.co.kr/newsRead.php?no=124283&ye...
# 467   http://news.mk.co.kr/newsRead.php?no=232045&ye...
# 589   http://news.mk.co.kr/newsRead.php?no=303038&ye...
# 775   http://news.mk.co.kr/newsRead.php?no=406753&ye...
# 872   http://news.mk.co.kr/newsRead.php?no=473737&ye...
# 891   http://news.mk.co.kr/newsRead.php?no=490664&ye...
# 1072  http://news.mk.co.kr/newsRead.php?no=593046&ye...
# 1122  http://news.mk.co.kr/newsRead.php?no=627141&ye...
# 1131  http://news.mk.co.kr/newsRead.php?no=633586&ye...
# 1185  http://news.mk.co.kr/newsRead.php?no=654935&ye...
# 1347  http://news.mk.co.kr/newsRead.php?no=758718&ye...
# 1389  http://news.mk.co.kr/newsRead.php?no=786723&ye...
# 1503  http://news.mk.co.kr/newsRead.php?no=859873&ye...
#
#                                                    text        date  time  \
# 294                                                \n\n  2019-02-19    14
# 300                                                \n\n  2019-02-20    11
# 349   ЧіДыЁЄБтОЦРкЕПТїДТ РќЙц ЕЕЗЮПЭ БГХы ЛѓШВРЛ ТїЗ...  2020-02-21    17
# 1891   ЧіДыРкЕПТїИІ ЕЮЙјТА ЙцЙЎЧб ЙЎРчРЮ ДыХыЗЩРЬ Чі...  2020-11-02    16
# 2198  \n\n\nНКЦЬ НУПЌ РхИщ [ЛчСјСІАј=ЧіДыТїБзЗь]\n А...  2020-12-18     8
# 2216  \n\n\nÄ„·¹æ”¼­ ĄĪ±ā³ōĄŗ Åõ½Ń [»ēĮų Į¦°ų = æĄÅä...  2020-12-21    13
# 2224  \n\n\nĮß°ķĀ÷ ½ĆĄå ŗń¼ö±āæ”µµ ĮĮĄŗ °Ŗæ” ĘČ ¼ö Ą...  2020-12-23    15
# 2251  \n\n\nЦїЕх РЭНКЧУЗЮЗЏ [ЛчСј УтУГ = ЦїЕхФкИЎОЦ]...  2020-12-28    14
# 272   \n\n\nРгПЕПѕАњ G4ЗКНКХЯ [ЛчСј СІАј=НжПыТї]\n С...  2021-02-08    18
# 467   \n\n\nЧіДыТї НКХИИЎОЦ [ЛчСј СІАј=ЧіДыТї]\n"ФЋД...  2021-03-11    10
# 589   \n\n\n±ā¾Ę, Ć¹ Ąüæė Ąü±āĀ÷ `EV6` ¼¼°č ĆÖĆŹ °ų°...  2021-03-31    17
# 775   \n\n\n���̿���5(����)�� ����[���� ��ó=������, �...  2021-04-28    23
# 872   \n\n\nЧуРЇИХЙА БйР§ УЛПЭДы УЛПјАњ ЧуРЇИХЙА ЧЧЧ...  2021-05-17    12
# 891   \n\n\n[ЛчСј СІАј = ЧіДыТї]\n СЄРЧМБ ЧіДыРкЕПТї...  2021-05-21    13
# 1072  \n\n\n2022³āĒü XM3[»ēĮų Į¦°ų = ø£³ė»ļ¼ŗ]\n"½ŗÅ...  2021-06-21    22
# 1122   ЧіДыРкЕПТїБзЗь МвМгРЮ ЗЮКПЕщРЬ ЙцХКМвГтДм(BTS...  2021-06-29    14
# 1131  \n\n\nИЗБЭЕЕ ЕцРНЧв МіСиРЧ ЖйОюГ­ РНСњРЛ АЎУс ...  2021-07-01    17
# 1185  Ēö“ėĄŚµæĀ÷±×·ģ Ēö“ėĀ÷”¤±ā¾Ę µī ĮÖæä 5°³»ē°” ±Ū...  2021-07-07    10
# 1347  \n\n\nЧіДыТїБзЗьАњ ХзННЖѓ РќБтТї СжЗТ И№ЕЈ [Лч...  2021-08-05    13
# 1389  \n\n\nЧіДыИ№ХЭНКЦЉЕ№ПР КЮЛъПЁ РќНУЕШ ХТБЧV [Лч...  2021-08-17    15
# 1503  \n\n\n[ЛчСј СІАј = ИИЦЎЗАЙіНК]\n "ИИ(MAN)РК Сі...  2021-09-07    16
#
#         Open    High     Low   Close   Volume    Change  UpDown Tokenization
# 294   119500  120500  119000  119500   470357 -0.008299      -1          NaN
# 300   119500  121500  119000  119000   735087 -0.004184      -1          NaN
# 349   128000  129500  127000  128000   686417 -0.015385      -1          NaN
# 1891  166000  170500  166000  170500  1052301  0.036474       1          NaN
# 2198  191000  191000  189000  189000   930831 -0.007874      -1          NaN
# 2216  188500  189000  185000  187000  1120752 -0.010582      -1          NaN
# 2224  183000  188500  183000  185000  1301433  0.005435       1          NaN
# 2251  189000  193000  187500  189500  2410348  0.013369       1          NaN
# 272   238000  240500  228500  234000  3212977 -0.062124      -1          NaN
# 467   228000  232000  227500  228500  1154314  0.004396       1          NaN
# 589   221500  222000  218000  218000   750876 -0.006834      -1          NaN
# 775   220000  223500  219500  221500   701452  0.006818       1          NaN
# 872   232000  232500  225000  227000   875528 -0.008734      -1          NaN
# 891   227000  233000  225500  227500  1333704  0.013363       1          NaN
# 1072  234000  236000  232000  233000   823355 -0.008511      -1          NaN
# 1122  240500  242500  239000  239500   627915 -0.006224      -1          NaN
# 1131  238500  243000  236000  242000  1031692  0.010438       1          NaN
# 1185  235000  235500  232000  232000  1122107 -0.016949      -1          NaN
# 1347  223000  224500  222500  223000   470741 -0.008889      -1          NaN
# 1389  216000  217000  211000  213000   863610 -0.018433      -1          NaN
# 1503  214500  214500  211500  212500   434105 -0.011628      -1          NaN

# %%
lg[lg['Tokenization'].isna()]
# Out:
#      st_n  st_cd  news    datetime                                    title  \
# 256  LG화학  51910  매일경제  2018042713                          배출권시장협의회 출범식 개최
# 784  LG화학  51910  매일경제  2020092109  "신풍제약, 시가총액은 10조 원인데 영업이익은 20억 원? 미스터리"
#
#                                                    url  \
# 256  http://news.mk.co.kr/newsRead.php?year=2018&no...
# 784  http://news.mk.co.kr/newsRead.php?no=971416&ye...
#
#                                                   text        date  time  \
# 256  \n\n\nЧбБЙАХЗЁМвДТ 27РЯ М­ПяЛчПСПЁМ­ ШЏАцКЮ, Й...  2018-04-27    13
# 784  ½ÅÁ¾ ÄÚ·Î³ª¹ÙÀÌ·¯½º °¨¿°Áõ(ÄÚ·Î³ª19)À¸·Î Áõ½Ã°...  2020-09-21     9
#
#        Open    High     Low   Close   Volume    Change  UpDown Tokenization
# 256  354000  360000  354000  354500   156968  0.002829       1          NaN
# 784  656000  657000  626000  627000  1239438 -0.058559      -1          NaN

# %%
sk[sk['Tokenization'].isna()]
# Out:
#         st_n  st_cd  news    datetime                                  title  \
# 1153  sk하이닉스    660  매일경제  2019112017  이시한의 2020년 취업트렌드코리아 #2 : Implement AI
#
#                                                     url  text        date  \
# 1153  http://edu.mk.co.kr/edunews/news_view.php?sc=5...  \n\n  2019-11-21
#
#       time   Open   High    Low  Close   Volume    Change  UpDown Tokenization
# 1153    17  81700  82500  80500  80900  3346746 -0.021765      -1          NaN

# %%
celltrion[celltrion['Tokenization'].isna()]
# Out:
#      st_n  st_cd   news    datetime  \
# 363  셀트리온  68270  아시아경제  2020060215
#
#                                                title  \
# 363  [속보] 당국 "셀트리온 항체치료제, 유럽서 임상 준비중…혈장치료제 우선 확보 목표"
#
#                                                    url text        date  time  \
# 363  https://view.asiae.co.kr/article/2020060215162...  NaN  2020-06-03    15
#
#        Open    High     Low   Close   Volume    Change  UpDown Tokenization
# 363  227335  230772  220461  223407  1813508  0.013363       1          NaN

# %%
# 결측치 제거
for i in range(len(corp_list)):
    globals()[corp_list[i]].dropna(inplace=True)
    globals()[corp_list[i]] = globals()[corp_list[i]].reset_index(drop=True)

# %%
# iteration limit 조정
limit_number = 15000
sys.setrecursionlimit(limit_number)

for i in range(len(corp_list)):
    globals()[corp_list[i]]['Positive_Score'] = 0
    globals()[corp_list[i]]['Negative_Score'] = 0
    globals()[corp_list[i]]['Ratio'] = 0.1
    globals()[corp_list[i]]['Pred'] = 0
    globals()[corp_list[i]]['NSI'] = 0.1
    
    for j in range(len(globals()[corp_list[i]])):
        pos_score = 0 ; neg_score = 0
        
        for k in range(len(globals()[corp_list[i]]['Tokenization'][j].split())):
            if globals()[corp_list[i]]['Tokenization'][j].split()[k] in positive:
                pos_score += 1
            elif globals()[corp_list[i]]['Tokenization'][j].split()[k] in negative:
                neg_score += 1
            else:
                pass
        
        globals()[corp_list[i]]['Positive_Score'][j] = pos_score
        globals()[corp_list[i]]['Negative_Score'][j] = neg_score
        
        # 긍정과 부정의 비율
        if (pos_score==0) and (neg_score==0):
            globals()[corp_list[i]]['Ratio'][j] = 0.5   # 둘 다 0일 경우에는 긍정으로 가정
        else:
            globals()[corp_list[i]]['Ratio'][j] = pos_score / (pos_score + neg_score)
        
        # 예측 결과
        if globals()[corp_list[i]]['Ratio'][j]>=0.5:
            globals()[corp_list[i]]['Pred'][j] = 1
        else:
            globals()[corp_list[i]]['Pred'][j] = -1
        
        # 뉴스심리지수(NSI) 계산
        if (pos_score==0) and (neg_score==0):
            globals()[corp_list[i]]['NSI'][j] = 101
        else:
            globals()[corp_list[i]]['NSI'][j] = (pos_score - neg_score) / (pos_score + neg_score) * 100 + 100
    
    # CSV로 저장
    globals()[corp_list[i]].to_csv('../../../../Final Data/{}. {}_score.csv'.format(i+1, corp_list[i]), index=False)
    
    corp = corp_list[i].upper()
    print("... {}'s Sentiment Score 계산 완료! ...".format(corp))

print('##### 전부 완료-! #####')
# Out:
# ... SAMSUNG's Sentiment Score 계산 완료! ...
# ... HYUNDAI's Sentiment Score 계산 완료! ...
# ... LG's Sentiment Score 계산 완료! ...
# ... SK's Sentiment Score 계산 완료! ...
# ... CELLTRION's Sentiment Score 계산 완료! ...
# ##### 전부 완료-! #####

# %%
# Accuracy 확인
for i in range(len(corp_list)):
    corp = corp_list[i].upper()
    print('<{}> Acccuracy of {} : {}'.format(i+1, corp, (len(globals()[corp_list[i]][(globals()[corp_list[i]]['UpDown']<0) & (globals()[corp_list[i]]['Pred']<0)]) + len(globals()[corp_list[i]][(globals()[corp_list[i]]['UpDown']>0) & (globals()[corp_list[i]]['Pred']>0)])) / len(globals()[corp_list[i]])))
# Out:
# <1> Acccuracy of SAMSUNG : 0.49452925798018266
# <2> Acccuracy of HYUNDAI : 0.4659692543216177
# <3> Acccuracy of LG : 0.5101088646967341
# <4> Acccuracy of SK : 0.4948020581749449
# <5> Acccuracy of CELLTRION : 0.49267223667990684
