# %% [markdown]
# # **Lexicon**

# %%
import numpy as np
import pandas as pd

### Visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

### DB 연결
# !pip install pymysql
import pymysql

### DB에 저장
import sqlalchemy
from sqlalchemy import create_engine

### 실시간 주식가격 데이터
# !pip install finance-datareader
import FinanceDataReader as fdr

### 텍스트 분석
## KoNLPy
# 1) JAVA 설치, 2) Python 버전과 맞는 JPype1-py3 설치, 3) !pip install konlpy, 4) 설치 경로에서 jvm.py 파일 코드 67번 줄 주석 처리 
from konlpy.tag import Okt
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import re
## FastText
# !pip install gensim
# !pip install fasttext
import fasttext
import fasttext.util
# Facebook 한국어 Embedding 모델 다운로드 → 한 번만 설치하면 됨
fasttext.util.download_model('ko', if_exists='ignore')
# 유사도 계산
from gensim import models

### 모델 학습 및 평가
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.metrics import precision_score, recall_score, f1_score

### 모델 저장 및 로드
import joblib

### 기타
import datetime
from collections import Counter
import sys
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf

print('GPU', '사용 가능' if tf.config.experimental.list_physical_devices('GPU') else '사용 불가능')
# Out:
# GPU 사용 불가능

# %%
# !nvidia-smi
# Out:
# Fri Sep 17 05:43:44 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 452.56       Driver Version: 452.56       CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce MX450      WDDM  | 00000000:2D:00.0 Off |                  N/A |
# | N/A   66C    P8    N/A /  N/A |    119MiB /  2048MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## **Read KOSELF & Test Data**

# %% [markdown]
# ### **① KOSELF 감성 어휘 사전**

# %%
# 블로그에서 가져온 기본적인 한국어 긍부정 텍스트 목록
with open('positive_words_self.txt', encoding='utf-8') as pos_blog:
    positive_blog = pos_blog.readlines()
positive_blog = [pos_blog.replace('\n', '') for pos_blog in positive_blog]
with open('negative_words_self.txt', encoding='utf-8') as neg_blog:
    negative_blog = neg_blog.readlines()
negative_blog = [neg_blog.replace('\n', '') for neg_blog in negative_blog]

# KOSELF 감성 어휘 사전
with open('KOSELF_pos.txt', encoding='utf-8') as pos:
    positive = pos.readlines()
positive = [pos.replace('\n', '') for pos in positive]
with open('KOSELF_neg.txt', encoding='utf-8') as neg:
    negative = neg.readlines()
negative = [neg.replace('\n', '') for neg in negative]

# %% [markdown]
# ### **② 2019년 Samsung Data**

# %%
lexicon_2019 = pd.read_csv('../../../../Code/Data/Test/Stock-Year/2019_samsung.csv')

lexicon_2019.head(1)
# Out:
#    st_n  st_cd  news    datetime                             title  \
# 0  삼성전자   5930  매일경제  2019010100  "韓기업 파괴적 혁신해야 성장…전담조직 회사 밖에 만들라"
#
#                                                  url  \
# 0  http://news.mk.co.kr/newsRead.php?year=2019&no=70
#
#                                                 text        date  time   Open  \
# 0  ◆ 2019신년기획 인터뷰 ◆\r\n\n\n 위 그래프는 크리스텐슨 교수가 매일경제...  2019-01-02     0  39400
#
#     High    Low  Close   Volume    Change  UpDown  Extremely_Changed  \
# 0  39400  38550  38750  7847664  0.001292       1                  0
#
#                                         Tokenization
# 0  신년 기획 인터뷰 그래프 크리스 텐슨 교수 매일경제 직접 그림 그래프 의미 과거 한...

# %%
lexicon_2019[lexicon_2019['text'].isna()]
# Out:
# Empty DataFrame
# Columns: [st_n, st_cd, news, datetime, title, url, text, date, time, Open, High, Low, Close, Volume, Change, UpDown, Extremely_Changed, Tokenization]
# Index: []

# %%
lexicon_2019.dropna(axis=0, inplace=True)
lexicon_2019 = lexicon_2019.reset_index(drop=True)
lexicon_2019.isna().sum()
# Out:
# st_n                 0
# st_cd                0
# news                 0
# datetime             0
# title                0
# url                  0
# text                 0
# date                 0
# time                 0
# Open                 0
# High                 0
# Low                  0
# Close                0
# Volume               0
# Change               0
# UpDown               0
# Extremely_Changed    0
# Tokenization         0
# dtype: int64

# %% [markdown]
# ## **Calculate Cosine Similarity**

# %%
# 이미 학습된 FastText 내장 한국어 모델
try:
    print(ko_model, '모델 로드 불필요')
except:
    ko_model = models.fasttext.load_facebook_model('cc.ko.300.bin')

# %%
limit_number = 15000
sys.setrecursionlimit(limit_number)

# %%
neg_lexicon_2019 = pd.DataFrame(columns=['date', 'news_num', 'KOSELF_neg_word', 'news_word', 'cosine_similarity', 'frequency'])   # 'frequency' 구현할 방법은 추후 생각...ㅠㅠ

# KOSELF_neg와의 Cosine Similarity 계산
for x in range(len(lexicon_2019['Tokenization'])):
    news_num = x+1
    for y in range(len(negative)):
        for z in range(len(list(set(lexicon_2019['Tokenization'][x].split())))):
            if (ko_model.wv.similarity(negative[y], list(set(lexicon_2019['Tokenization'][x].split()))[z]) >= 0.5) and (ko_model.wv.similarity(negative[y], list(set(lexicon_2019['Tokenization'][x].split()))[z]) != 1.0):
                freq = 0
                for w in range(len(lexicon_2019['Tokenization'][x].split())):
                    if lexicon_2019['Tokenization'][x].split()[w] == list(set(lexicon_2019['Tokenization'][x].split()))[z]:
                        freq += 1
                data = {
                    'date': lexicon_2019['date'][x],
                    'news_num': news_num,
                    'KOSELF_neg_word': negative[y],
                    'news_word': list(set(lexicon_2019['Tokenization'][x].split()))[z],
                    'cosine_similarity': ko_model.wv.similarity(negative[y], list(set(lexicon_2019['Tokenization'][x].split()))[z]),
                    'frequency': freq
                    }
                neg_lexicon_2019 = neg_lexicon_2019.append(data, ignore_index=True)
                print("***{0} Cosine Similarity between <{1}> & <{2}> : {3}".format(lexicon_2019['date'][x], negative[y], list(set(lexicon_2019['Tokenization'][x].split()))[z], ko_model.wv.similarity(negative[y], list(set(lexicon_2019['Tokenization'][x].split()))[z])))
# Out:
# ***2019-01-02 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-02 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2019-01-02 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-02 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-02 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-02 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-02 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-02 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-02 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-02 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-02 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-01-02 Cosine Similarity between <배상> & <보상> : 0.5126209259033203
# ***2019-01-02 Cosine Similarity between <실패> & <실패> : 0.9999999403953552
# ***2019-01-02 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-02 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-02 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-01-02 Cosine Similarity between <둔화> & <악화> : 0.5065980553627014
# ***2019-01-02 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2019-01-02 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2019-01-02 Cosine Similarity between <둔화> & <반등> : 0.5092458128929138
# ***2019-01-02 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-02 Cosine Similarity between <약화> & <악화> : 0.5064777731895447
# ***2019-01-02 Cosine Similarity between <약화> & <저하> : 0.5494821071624756
# ***2019-01-02 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2019-01-02 Cosine Similarity between <침체> & <불황> : 0.6393564939498901
# ***2019-01-02 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-02 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-02 Cosine Similarity between <침체> & <업황> : 0.5205409526824951
# ***2019-01-02 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-02 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-02 Cosine Similarity between <하락> & <저하> : 0.5286632776260376
# ***2019-01-02 Cosine Similarity between <하락> & <급락> : 0.6878489255905151
# ***2019-01-02 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2019-01-02 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-02 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2019-01-02 Cosine Similarity between <침체> & <호황> : 0.6176011562347412
# ***2019-01-02 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-02 Cosine Similarity between <침체> & <위기> : 0.5072819590568542
# ***2019-01-02 Cosine Similarity between <침체> & <업황> : 0.5205409526824951
# ***2019-01-02 Cosine Similarity between <하락> & <급등> : 0.6149086356163025
# ***2019-01-02 Cosine Similarity between <마이너스> & <플러스> : 0.5253470540046692
# ***2019-01-02 Cosine Similarity between <과적> & <차량> : 0.5693626403808594
# ***2019-01-02 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-01-02 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-01-02 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2019-01-02 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2019-01-02 Cosine Similarity between <둔화> & <침체> : 0.5701860189437866
# ***2019-01-02 Cosine Similarity between <둔화> & <악화> : 0.5065980553627014
# ***2019-01-02 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-02 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-02 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-01-02 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2019-01-02 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2019-01-02 Cosine Similarity between <둔화> & <반등> : 0.5092458128929138
# ***2019-01-02 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-02 Cosine Similarity between <약화> & <악화> : 0.5064777731895447
# ***2019-01-02 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-02 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-01-02 Cosine Similarity between <약화> & <저하> : 0.5494821071624756
# ***2019-01-02 Cosine Similarity between <여파> & <악재> : 0.5317699313163757
# ***2019-01-02 Cosine Similarity between <침체> & <급감> : 0.504062831401825
# ***2019-01-02 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-02 Cosine Similarity between <침체> & <호황> : 0.6176011562347412
# ***2019-01-02 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-02 Cosine Similarity between <침체> & <침체> : 0.9999999403953552
# ***2019-01-02 Cosine Similarity between <침체> & <업황> : 0.5205409526824951
# ***2019-01-02 Cosine Similarity between <하락> & <급감> : 0.5196216106414795
# ***2019-01-02 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-02 Cosine Similarity between <하락> & <약세> : 0.5661998987197876
# ***2019-01-02 Cosine Similarity between <하락> & <주춤> : 0.5109283328056335
# ***2019-01-02 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-02 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-01-02 Cosine Similarity between <하락> & <저하> : 0.5286632776260376
# ***2019-01-02 Cosine Similarity between <하락> & <급락> : 0.6878489255905151
# ***2019-01-02 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2019-01-02 Cosine Similarity between <과적> & <차량> : 0.5693626403808594
# ***2019-01-02 Cosine Similarity between <혼란> & <불안> : 0.513291597366333
# ***2019-01-02 Cosine Similarity between <과적> & <선박> : 0.5064859390258789
# ***2019-01-02 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-02 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-02 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-01-02 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-02 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-02 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-02 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-02 Cosine Similarity between <침체> & <위기> : 0.5072819590568542
# ***2019-01-02 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-02 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-02 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-01-02 Cosine Similarity between <과적> & <차량> : 0.5693626403808594
# ***2019-01-02 Cosine Similarity between <둔화> & <침체> : 0.5701860189437866
# ***2019-01-02 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-01-02 Cosine Similarity between <침체> & <침체> : 0.9999999403953552
# ***2019-01-02 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-02 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2019-01-02 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-02 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-01-02 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-02 Cosine Similarity between <침체> & <업황> : 0.5205409526824951
# ***2019-01-02 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-02 Cosine Similarity between <실패> & <실패> : 0.9999999403953552
# ***2019-01-02 Cosine Similarity between <침체> & <위기> : 0.5072819590568542
# ***2019-01-02 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-02 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-01-02 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2019-01-02 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-02 Cosine Similarity between <하락> & <약세> : 0.5661998987197876
# ***2019-01-02 Cosine Similarity between <하락> & <등락> : 0.573682427406311
# ***2019-01-02 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-03 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2019-01-03 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-03 Cosine Similarity between <하락> & <약세> : 0.5661998987197876
# ***2019-01-03 Cosine Similarity between <과적> & <차량> : 0.5693626403808594
# ***2019-01-03 Cosine Similarity between <둔화> & <침체> : 0.5701860189437866
# ***2019-01-03 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2019-01-03 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-01-03 Cosine Similarity between <실패> & <성공> : 0.7068131566047668
# ***2019-01-03 Cosine Similarity between <실패> & <실패> : 0.9999999403953552
# ***2019-01-03 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-01-03 Cosine Similarity between <침체> & <침체> : 0.9999999403953552
# ***2019-01-03 Cosine Similarity between <침체> & <폭락> : 0.510413646697998
# ***2019-01-03 Cosine Similarity between <침체> & <급감> : 0.504062831401825
# ***2019-01-03 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-03 Cosine Similarity between <하락> & <폭락> : 0.5914363861083984
# ***2019-01-03 Cosine Similarity between <하락> & <급감> : 0.5196216106414795
# ***2019-01-03 Cosine Similarity between <하락> & <약세> : 0.5661998987197876
# ***2019-01-03 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-01-03 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-03 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-03 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-03 Cosine Similarity between <침체> & <위기> : 0.5072819590568542
# ***2019-01-03 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-03 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-03 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2019-01-03 Cosine Similarity between <둔화> & <침체> : 0.5701860189437866
# ***2019-01-03 Cosine Similarity between <실패> & <실패> : 0.9999999403953552
# ***2019-01-03 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-03 Cosine Similarity between <침체> & <불황> : 0.6393564939498901
# ***2019-01-03 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-03 Cosine Similarity between <침체> & <침체> : 0.9999999403953552
# ***2019-01-03 Cosine Similarity between <침체> & <위기> : 0.5072819590568542
# ***2019-01-03 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-03 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-03 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-03 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-03 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-01-03 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2019-01-03 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2019-01-03 Cosine Similarity between <둔화> & <반등> : 0.5092458128929138
# ***2019-01-03 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-03 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-03 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-03 Cosine Similarity between <침체> & <호황> : 0.6176011562347412
# ***2019-01-03 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-03 Cosine Similarity between <침체> & <업황> : 0.5205409526824951
# ***2019-01-03 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-03 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-03 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-01-03 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-03 Cosine Similarity between <하락> & <급락> : 0.6878489255905151
# ***2019-01-03 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2019-01-03 Cosine Similarity between <둔화> & <악화> : 0.5065980553627014
# ***2019-01-03 Cosine Similarity between <실패> & <실패> : 0.9999999403953552
# ***2019-01-03 Cosine Similarity between <약화> & <악화> : 0.5064777731895447
# ***2019-01-03 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2019-01-03 Cosine Similarity between <의혹> & <연루> : 0.5164746046066284
# ***2019-01-03 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-01-03 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-03 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-03 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-01-03 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2019-01-03 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-03 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-03 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-01-03 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-03 Cosine Similarity between <하락> & <급락> : 0.6878489255905151
# ***2019-01-03 Cosine Similarity between <과적> & <차량> : 0.5693626403808594
# ***2019-01-03 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2019-01-03 Cosine Similarity between <침체> & <호황> : 0.6176011562347412
# ***2019-01-03 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-01-03 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-01-03 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-03 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2019-01-03 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-03 Cosine Similarity between <침체> & <호황> : 0.6176011562347412
# ***2019-01-03 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-03 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-03 Cosine Similarity between <둔화> & <위축> : 0.6352296471595764
# ***2019-01-03 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2019-01-03 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-03 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-03 Cosine Similarity between <약화> & <위축> : 0.5172011256217957
# ***2019-01-03 Cosine Similarity between <침체> & <위축> : 0.5503976345062256
# ***2019-01-03 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-03 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-03 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-03 Cosine Similarity between <하락> & <약세> : 0.5661998987197876
# ***2019-01-03 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-03 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2019-01-03 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2019-01-03 Cosine Similarity between <둔화> & <위축> : 0.6352296471595764
# ***2019-01-03 Cosine Similarity between <둔화> & <악화> : 0.5065980553627014
# ***2019-01-03 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-03 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-03 Cosine Similarity between <약화> & <위축> : 0.5172011256217957
# ***2019-01-03 Cosine Similarity between <약화> & <악화> : 0.5064777731895447
# ***2019-01-03 Cosine Similarity between <침체> & <업황> : 0.5205409526824951
# ***2019-01-03 Cosine Similarity between <침체> & <위축> : 0.5503976345062256
# ***2019-01-03 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-03 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-03 Cosine Similarity between <과적> & <차량> : 0.5693626403808594
# ***2019-01-03 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-01-03 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-01-03 Cosine Similarity between <둔화> & <악화> : 0.5065980553627014
# ***2019-01-03 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-03 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-03 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2019-01-03 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2019-01-03 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-03 Cosine Similarity between <약화> & <악화> : 0.5064777731895447
# ***2019-01-03 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-03 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-03 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-03 Cosine Similarity between <침체> & <업황> : 0.5205409526824951
# ***2019-01-03 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-03 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-03 Cosine Similarity between <하락> & <등락> : 0.573682427406311
# ***2019-01-03 Cosine Similarity between <하락> & <급락> : 0.6878489255905151
# ***2019-01-04 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-04 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2019-01-04 Cosine Similarity between <둔화> & <반등> : 0.5092458128929138
# ***2019-01-04 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-04 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-04 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-04 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-04 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-04 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2019-01-04 Cosine Similarity between <하락> & <급락> : 0.6878489255905151
# ***2019-01-04 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2019-01-04 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-01-04 Cosine Similarity between <침체> & <호황> : 0.6176011562347412
# ***2019-01-04 Cosine Similarity between <침체> & <위기> : 0.5072819590568542
# ***2019-01-04 Cosine Similarity between <과적> & <차량> : 0.5693626403808594
# ***2019-01-04 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2019-01-04 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-04 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-04 Cosine Similarity between <침체> & <업황> : 0.5205409526824951
# ***2019-01-04 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-04 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-04 Cosine Similarity between <둔화> & <반등> : 0.5092458128929138
# ***2019-01-04 Cosine Similarity between <실패> & <실패> : 0.9999999403953552
# ***2019-01-04 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2019-01-04 Cosine Similarity between <둔화> & <침체> : 0.5701860189437866
# ***2019-01-04 Cosine Similarity between <둔화> & <악화> : 0.5065980553627014
# ***2019-01-04 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-04 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2019-01-04 Cosine Similarity between <둔화> & <반등> : 0.5092458128929138
# ***2019-01-04 Cosine Similarity between <약화> & <악화> : 0.5064777731895447
# ***2019-01-04 Cosine Similarity between <침체> & <침체> : 0.9999999403953552
# ***2019-01-04 Cosine Similarity between <하락> & <등락> : 0.573682427406311
# ***2019-01-04 Cosine Similarity between <하락> & <급락> : 0.6878489255905151
# ***2019-01-04 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2019-01-04 Cosine Similarity between <혼란> & <불안> : 0.513291597366333
# ***2019-01-04 Cosine Similarity between <둔화> & <악화> : 0.5065980553627014
# ***2019-01-04 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-04 Cosine Similarity between <약화> & <악화> : 0.5064777731895447
# ***2019-01-04 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-04 Cosine Similarity between <하락> & <등락> : 0.573682427406311
# ***2019-01-04 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-04 Cosine Similarity between <혼란> & <불안> : 0.513291597366333
# ***2019-01-04 Cosine Similarity between <과적> & <차량> : 0.5693626403808594
# ***2019-01-04 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2019-01-04 Cosine Similarity between <약점> & <강점> : 0.5741010904312134
# ***2019-01-04 Cosine Similarity between <배상> & <보상> : 0.5126209259033203
# ***2019-01-04 Cosine Similarity between <실패> & <성공> : 0.7068131566047668
# ***2019-01-04 Cosine Similarity between <실패> & <실패> : 0.9999999403953552
# ***2019-01-04 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-04 Cosine Similarity between <마이너스> & <플러스> : 0.5253470540046692
# ***2019-01-04 Cosine Similarity between <마이너스> & <플러스> : 0.5253470540046692
# ***2019-01-07 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-07 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2019-01-07 Cosine Similarity between <둔화> & <반등> : 0.5092458128929138
# ***2019-01-07 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-07 Cosine Similarity between <여파> & <역풍> : 0.5024392008781433
# ***2019-01-07 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-07 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-07 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-07 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-07 Cosine Similarity between <하락> & <급락> : 0.6878489255905151
# ***2019-01-07 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2019-01-07 Cosine Similarity between <혼란> & <불안> : 0.513291597366333
# ***2019-01-07 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2019-01-07 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-07 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-07 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-01-07 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-07 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-07 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-07 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-07 Cosine Similarity between <하락> & <약세> : 0.5661998987197876
# ***2019-01-07 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-07 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-01-07 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-01-07 Cosine Similarity between <실패> & <성공> : 0.7068131566047668
# ***2019-01-07 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-01-07 Cosine Similarity between <혼란> & <불안> : 0.513291597366333
# ***2019-01-07 Cosine Similarity between <둔화> & <침체> : 0.5701860189437866
# ***2019-01-07 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-07 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2019-01-07 Cosine Similarity between <침체> & <침체> : 0.9999999403953552
# ***2019-01-07 Cosine Similarity between <침체> & <위기> : 0.5072819590568542
# ***2019-01-07 Cosine Similarity between <하락> & <급락> : 0.6878489255905151
# ***2019-01-07 Cosine Similarity between <과적> & <차량> : 0.5693626403808594
# ***2019-01-07 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2019-01-07 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-07 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-01-07 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-07 Cosine Similarity between <침체> & <위기> : 0.5072819590568542
# ***2019-01-07 Cosine Similarity between <침체> & <업황> : 0.5205409526824951
# ***2019-01-07 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-07 Cosine Similarity between <둔화> & <위축> : 0.6352296471595764
# ***2019-01-07 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-07 Cosine Similarity between <실패> & <실패> : 0.9999999403953552
# ***2019-01-07 Cosine Similarity between <약화> & <위축> : 0.5172011256217957
# ***2019-01-07 Cosine Similarity between <침체> & <위축> : 0.5503976345062256
# ***2019-01-07 Cosine Similarity between <침체> & <위기> : 0.5072819590568542
# ***2019-01-07 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-07 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-07 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-01-07 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2019-01-07 Cosine Similarity between <둔화> & <반등> : 0.5092458128929138
# ***2019-01-07 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-07 Cosine Similarity between <침체> & <불황> : 0.6393564939498901
# ***2019-01-07 Cosine Similarity between <침체> & <호황> : 0.6176011562347412
# ***2019-01-07 Cosine Similarity between <침체> & <업황> : 0.5205409526824951
# ***2019-01-07 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-07 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-01-07 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2019-01-07 Cosine Similarity between <과적> & <차량> : 0.5693626403808594
# ***2019-01-07 Cosine Similarity between <실패> & <성공> : 0.7068131566047668
# ***2019-01-07 Cosine Similarity between <둔화> & <침체> : 0.5701860189437866
# ***2019-01-07 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-07 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2019-01-07 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-07 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-07 Cosine Similarity between <침체> & <호황> : 0.6176011562347412
# ***2019-01-07 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-07 Cosine Similarity between <침체> & <침체> : 0.9999999403953552
# ***2019-01-07 Cosine Similarity between <침체> & <업황> : 0.5205409526824951
# ***2019-01-07 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-07 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-07 Cosine Similarity between <의심> & <의심> : 0.9999998807907104
# ***2019-01-07 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-07 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-07 Cosine Similarity between <둔화> & <악화> : 0.5065980553627014
# ***2019-01-07 Cosine Similarity between <악화> & <병세> : 0.5025599002838135
# ***2019-01-07 Cosine Similarity between <약화> & <악화> : 0.5064777731895447
# ***2019-01-07 Cosine Similarity between <둔화> & <침체> : 0.5701860189437866
# ***2019-01-07 Cosine Similarity between <침체> & <침체> : 0.9999999403953552
# ***2019-01-07 Cosine Similarity between <둔화> & <위축> : 0.6352296471595764
# ***2019-01-07 Cosine Similarity between <둔화> & <반등> : 0.5092458128929138
# ***2019-01-07 Cosine Similarity between <약화> & <위축> : 0.5172011256217957
# ***2019-01-07 Cosine Similarity between <침체> & <위축> : 0.5503976345062256
# ***2019-01-07 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-07 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-07 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2019-01-07 Cosine Similarity between <과적> & <화물> : 0.5248162746429443
# ***2019-01-07 Cosine Similarity between <과적> & <차량> : 0.5693626403808594
# ***2019-01-07 Cosine Similarity between <둔화> & <침체> : 0.5701860189437866
# ***2019-01-07 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-07 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-07 Cosine Similarity between <침체> & <침체> : 0.9999999403953552
# ***2019-01-07 Cosine Similarity between <침체> & <위기> : 0.5072819590568542
# ***2019-01-07 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-07 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-07 Cosine Similarity between <과적> & <차량> : 0.5693626403808594
# ***2019-01-07 Cosine Similarity between <둔화> & <위축> : 0.6352296471595764
# ***2019-01-07 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-07 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-07 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-01-07 Cosine Similarity between <약화> & <위축> : 0.5172011256217957
# ***2019-01-07 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-07 Cosine Similarity between <침체> & <위축> : 0.5503976345062256
# ***2019-01-07 Cosine Similarity between <침체> & <호황> : 0.6176011562347412
# ***2019-01-07 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-07 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-01-07 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-07 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-01-07 Cosine Similarity between <여파> & <악재> : 0.5317699313163757
# ***2019-01-07 Cosine Similarity between <침체> & <불황> : 0.6393564939498901
# ***2019-01-07 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-01-07 Cosine Similarity between <실패> & <성공> : 0.7068131566047668
# ***2019-01-07 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-01-07 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-01-07 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2019-01-07 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-07 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-07 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-07 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-07 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-07 Cosine Similarity between <하락> & <약세> : 0.5661998987197876
# ***2019-01-07 Cosine Similarity between <하락> & <급등> : 0.6149086356163025
# ***2019-01-07 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-07 Cosine Similarity between <과적> & <차량> : 0.5693626403808594
# ***2019-01-08 Cosine Similarity between <과적> & <차량> : 0.5693626403808594
# ***2019-01-08 Cosine Similarity between <마이너스> & <플러스> : 0.5253470540046692
# ***2019-01-08 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-01-08 Cosine Similarity between <과적> & <차량> : 0.5693626403808594
# ***2019-01-08 Cosine Similarity between <약점> & <강점> : 0.5741010904312134
# ***2019-01-08 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-01-08 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2019-01-08 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-08 Cosine Similarity between <둔화> & <반등> : 0.5092458128929138
# ***2019-01-08 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-08 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-08 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-08 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-08 Cosine Similarity between <하락> & <약세> : 0.5661998987197876
# ***2019-01-08 Cosine Similarity between <하락> & <급등> : 0.6149086356163025
# ***2019-01-08 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-08 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2019-01-08 Cosine Similarity between <마이너스> & <플러스> : 0.5253470540046692
# ***2019-01-08 Cosine Similarity between <약점> & <강점> : 0.5741010904312134
# ***2019-01-08 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2019-01-08 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-08 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-08 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-01-08 Cosine Similarity between <둔화> & <반등> : 0.5092458128929138
# ***2019-01-08 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-08 Cosine Similarity between <여파> & <악재> : 0.5317699313163757
# ***2019-01-08 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-08 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-01-08 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2019-01-08 Cosine Similarity between <둔화> & <악화> : 0.5065980553627014
# ***2019-01-08 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-08 Cosine Similarity between <약화> & <악화> : 0.5064777731895447
# ***2019-01-08 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-08 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-08 Cosine Similarity between <침체> & <위기> : 0.5072819590568542
# ***2019-01-08 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-08 Cosine Similarity between <혼란> & <불안> : 0.513291597366333
# ***2019-01-08 Cosine Similarity between <약점> & <강점> : 0.5741010904312134
# ***2019-01-08 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-01-08 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2019-01-08 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-08 Cosine Similarity between <침체> & <업황> : 0.5205409526824951
# ***2019-01-08 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-01-08 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-08 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-01-08 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-08 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-01-08 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-08 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-08 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-01-08 Cosine Similarity between <약화> & <저하> : 0.5494821071624756
# ***2019-01-08 Cosine Similarity between <하락> & <저하> : 0.5286632776260376
# ***2019-01-08 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-08 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-08 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-01-08 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2019-01-08 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-08 Cosine Similarity between <침체> & <호황> : 0.6176011562347412
# ***2019-01-08 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-08 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-01-08 Cosine Similarity between <하락> & <급락> : 0.6878489255905151
# ***2019-01-08 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2019-01-08 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-08 Cosine Similarity between <하락> & <약세> : 0.5661998987197876
# ***2019-01-08 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-08 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2019-01-08 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-08 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-08 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2019-01-08 Cosine Similarity between <둔화> & <반등> : 0.5092458128929138
# ***2019-01-08 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-08 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-08 Cosine Similarity between <침체> & <급감> : 0.504062831401825
# ***2019-01-08 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-08 Cosine Similarity between <침체> & <업황> : 0.5205409526824951
# ***2019-01-08 Cosine Similarity between <하락> & <급감> : 0.5196216106414795
# ***2019-01-08 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-08 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-08 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-08 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2019-01-08 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-08 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-08 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2019-01-08 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2019-01-08 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-08 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-08 Cosine Similarity between <침체> & <업황> : 0.5205409526824951
# ***2019-01-08 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-08 Cosine Similarity between <하락> & <급락> : 0.6878489255905151
# ***2019-01-08 Cosine Similarity between <과적> & <선박> : 0.5064859390258789
# ***2019-01-08 Cosine Similarity between <과적> & <차량> : 0.5693626403808594
# ***2019-01-08 Cosine Similarity between <둔화> & <침체> : 0.5701860189437866
# ***2019-01-08 Cosine Similarity between <둔화> & <호전> : 0.5174993872642517
# ***2019-01-08 Cosine Similarity between <둔화> & <위축> : 0.6352296471595764
# ***2019-01-08 Cosine Similarity between <배상> & <보상> : 0.5126209259033203
# ***2019-01-08 Cosine Similarity between <실패> & <성공> : 0.7068131566047668
# ***2019-01-08 Cosine Similarity between <악화> & <호전> : 0.5666260719299316
# ***2019-01-08 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-01-08 Cosine Similarity between <약화> & <위축> : 0.5172011256217957
# ***2019-01-08 Cosine Similarity between <조치> & <금수> : 0.5127856731414795
# ***2019-01-08 Cosine Similarity between <침체> & <불황> : 0.6393564939498901
# ***2019-01-08 Cosine Similarity between <침체> & <침체> : 0.9999999403953552
# ***2019-01-08 Cosine Similarity between <침체> & <위기> : 0.5072819590568542
# ***2019-01-08 Cosine Similarity between <침체> & <위축> : 0.5503976345062256
# ***2019-01-08 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-08 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-08 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-08 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-01-08 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2019-01-08 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-08 Cosine Similarity between <약화> & <저하> : 0.5494821071624756
# ***2019-01-08 Cosine Similarity between <침체> & <업황> : 0.5205409526824951
# ***2019-01-08 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-08 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-01-08 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-08 Cosine Similarity between <하락> & <저하> : 0.5286632776260376
# ***2019-01-09 Cosine Similarity between <둔화> & <침체> : 0.5701860189437866
# ***2019-01-09 Cosine Similarity between <둔화> & <악화> : 0.5065980553627014
# ***2019-01-09 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-09 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-01-09 Cosine Similarity between <약화> & <악화> : 0.5064777731895447
# ***2019-01-09 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-09 Cosine Similarity between <침체> & <침체> : 0.9999999403953552
# ***2019-01-09 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-09 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-01-09 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-09 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2019-01-09 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-09 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-09 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-09 Cosine Similarity between <침체> & <불황> : 0.6393564939498901
# ***2019-01-09 Cosine Similarity between <하락> & <약세> : 0.5661998987197876
# ***2019-01-09 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-09 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-09 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2019-01-09 Cosine Similarity between <둔화> & <침체> : 0.5701860189437866
# ***2019-01-09 Cosine Similarity between <둔화> & <악화> : 0.5065980553627014
# ***2019-01-09 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-09 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-09 Cosine Similarity between <둔화> & <반등> : 0.5092458128929138
# ***2019-01-09 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-09 Cosine Similarity between <약화> & <악화> : 0.5064777731895447
# ***2019-01-09 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-09 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-09 Cosine Similarity between <침체> & <호황> : 0.6176011562347412
# ***2019-01-09 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-09 Cosine Similarity between <침체> & <침체> : 0.9999999403953552
# ***2019-01-09 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-09 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-09 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2019-01-09 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-09 Cosine Similarity between <침체> & <위기> : 0.5072819590568542
# ***2019-01-09 Cosine Similarity between <실패> & <성공> : 0.7068131566047668
# ***2019-01-09 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-09 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-09 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-01-09 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2019-01-09 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-09 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-09 Cosine Similarity between <약화> & <저하> : 0.5494821071624756
# ***2019-01-09 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-09 Cosine Similarity between <침체> & <호황> : 0.6176011562347412
# ***2019-01-09 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-09 Cosine Similarity between <침체> & <위기> : 0.5072819590568542
# ***2019-01-09 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-09 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-09 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-01-09 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-09 Cosine Similarity between <하락> & <저하> : 0.5286632776260376
# ***2019-01-09 Cosine Similarity between <하락> & <급락> : 0.6878489255905151
# ***2019-01-09 Cosine Similarity between <약화> & <저하> : 0.5494821071624756
# ***2019-01-09 Cosine Similarity between <하락> & <저하> : 0.5286632776260376
# ***2019-01-09 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-09 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-09 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-01-09 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2019-01-09 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-09 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-09 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-09 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-09 Cosine Similarity between <침체> & <업황> : 0.5205409526824951
# ***2019-01-09 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-09 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-09 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-01-09 Cosine Similarity between <둔화> & <악화> : 0.5065980553627014
# ***2019-01-09 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-09 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-09 Cosine Similarity between <둔화> & <반등> : 0.5092458128929138
# ***2019-01-09 Cosine Similarity between <약화> & <악화> : 0.5064777731895447
# ***2019-01-09 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-09 Cosine Similarity between <약화> & <저하> : 0.5494821071624756
# ***2019-01-09 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-09 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-09 Cosine Similarity between <하락> & <저하> : 0.5286632776260376
# ***2019-01-09 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2019-01-09 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-09 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-09 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-01-09 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2019-01-09 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-09 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-09 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-09 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-09 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-09 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-01-09 Cosine Similarity between <하락> & <급락> : 0.6878489255905151
# ***2019-01-09 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-09 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-01-09 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-09 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-09 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-01-09 Cosine Similarity between <과적> & <차량> : 0.5693626403808594
# ***2019-01-09 Cosine Similarity between <과적> & <차량> : 0.5693626403808594
# ***2019-01-09 Cosine Similarity between <약점> & <강점> : 0.5741010904312134
# ***2019-01-09 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-01-09 Cosine Similarity between <둔화> & <악화> : 0.5065980553627014
# ***2019-01-09 Cosine Similarity between <약화> & <악화> : 0.5064777731895447
# ***2019-01-09 Cosine Similarity between <침체> & <호황> : 0.6176011562347412
# ***2019-01-09 Cosine Similarity between <침체> & <위기> : 0.5072819590568542
# ***2019-01-09 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-01-09 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-09 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-01-09 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-09 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-09 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2019-01-09 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-01-09 Cosine Similarity between <과적> & <차량> : 0.5693626403808594
# ***2019-01-09 Cosine Similarity between <약점> & <강점> : 0.5741010904312134
# ***2019-01-09 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-01-09 Cosine Similarity between <악화> & <병세> : 0.5025599002838135
# ***2019-01-10 Cosine Similarity between <과적> & <선박> : 0.5064859390258789
# ***2019-01-10 Cosine Similarity between <둔화> & <침체> : 0.5701860189437866
# ***2019-01-10 Cosine Similarity between <둔화> & <악화> : 0.5065980553627014
# ***2019-01-10 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-10 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-01-10 Cosine Similarity between <약화> & <악화> : 0.5064777731895447
# ***2019-01-10 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-10 Cosine Similarity between <침체> & <급감> : 0.504062831401825
# ***2019-01-10 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-01-10 Cosine Similarity between <침체> & <호황> : 0.6176011562347412
# ***2019-01-10 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-10 Cosine Similarity between <침체> & <침체> : 0.9999999403953552
# ***2019-01-10 Cosine Similarity between <하락> & <급감> : 0.5196216106414795
# ***2019-01-10 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-01-10 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-10 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-01-10 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-01-10 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-01-10 Cosine Similarity between <악화> & <약화> : 0.5064777731895447
# ***2019-01-10 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-01-10 Cosine Similarity between <약화> & <약화> : 0.9999999403953552
# ***2019-01-10 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-01-10 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-01-10 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ...
# ***2019-11-14 Cosine Similarity between <약화> & <위축> : 0.5172011256217957
# ***2019-11-14 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-11-14 Cosine Similarity between <여파> & <악재> : 0.5317699313163757
# ***2019-11-14 Cosine Similarity between <의심> & <의심> : 0.9999998807907104
# ***2019-11-14 Cosine Similarity between <침체> & <위축> : 0.5503976345062256
# ***2019-11-14 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-11-14 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-11-14 Cosine Similarity between <혼란> & <불안> : 0.513291597366333
# ***2019-11-15 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-11-15 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-11-15 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-11-15 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-11-15 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-11-15 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-11-15 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-11-15 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-11-15 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-11-15 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-11-15 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-11-15 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-11-15 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-11-15 Cosine Similarity between <둔화> & <반등> : 0.5092458128929138
# ***2019-11-15 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-11-15 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-11-15 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2019-11-15 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-11-15 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-11-15 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-11-15 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2019-11-15 Cosine Similarity between <과적> & <차량> : 0.5693626403808594
# ***2019-11-15 Cosine Similarity between <약점> & <강점> : 0.5741010904312134
# ***2019-11-15 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-11-15 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-11-15 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-11-15 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-11-15 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-11-15 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-11-15 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-11-15 Cosine Similarity between <실패> & <실패> : 0.9999999403953552
# ***2019-11-15 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-11-15 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-11-15 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-11-15 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2019-11-15 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-11-15 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-11-15 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-11-15 Cosine Similarity between <하락> & <급락> : 0.6878489255905151
# ***2019-11-15 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-11-15 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-11-15 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-11-15 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2019-11-15 Cosine Similarity between <둔화> & <반등> : 0.5092458128929138
# ***2019-11-15 Cosine Similarity between <마이너스> & <플러스> : 0.5253470540046692
# ***2019-11-15 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-11-15 Cosine Similarity between <약점> & <강점> : 0.5741010904312134
# ***2019-11-15 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-11-15 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-11-15 Cosine Similarity between <침체> & <업황> : 0.5205409526824951
# ***2019-11-15 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-11-15 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-11-15 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-11-15 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-11-15 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2019-11-15 Cosine Similarity between <실패> & <성공> : 0.7068131566047668
# ***2019-11-15 Cosine Similarity between <약점> & <강점> : 0.5741010904312134
# ***2019-11-15 Cosine Similarity between <과적> & <선박> : 0.5064859390258789
# ***2019-11-15 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-11-15 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-11-15 Cosine Similarity between <여파> & <역풍> : 0.5024392008781433
# ***2019-11-15 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2019-11-15 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-11-15 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2019-11-18 Cosine Similarity between <과적> & <선박> : 0.5064859390258789
# ***2019-11-18 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-11-18 Cosine Similarity between <둔화> & <반등> : 0.5092458128929138
# ***2019-11-18 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-11-18 Cosine Similarity between <여파> & <역풍> : 0.5024392008781433
# ***2019-11-18 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2019-11-18 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-11-18 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2019-11-18 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2019-11-18 Cosine Similarity between <실패> & <성공> : 0.7068131566047668
# ***2019-11-18 Cosine Similarity between <약점> & <강점> : 0.5741010904312134
# ***2019-11-18 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-11-18 Cosine Similarity between <실패> & <성공> : 0.7068131566047668
# ***2019-11-18 Cosine Similarity between <약점> & <강점> : 0.5741010904312134
# ***2019-11-18 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-11-18 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-11-18 Cosine Similarity between <침체> & <불황> : 0.6393564939498901
# ***2019-11-18 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-11-18 Cosine Similarity between <실패> & <성공> : 0.7068131566047668
# ***2019-11-18 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-11-18 Cosine Similarity between <침체> & <급감> : 0.504062831401825
# ***2019-11-18 Cosine Similarity between <하락> & <급감> : 0.5196216106414795
# ***2019-11-18 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2019-11-18 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-11-18 Cosine Similarity between <하락> & <급락> : 0.6878489255905151
# ***2019-11-18 Cosine Similarity between <둔화> & <침체> : 0.5701860189437866
# ***2019-11-18 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-11-18 Cosine Similarity between <실패> & <성공> : 0.7068131566047668
# ***2019-11-18 Cosine Similarity between <약점> & <강점> : 0.5741010904312134
# ***2019-11-18 Cosine Similarity between <침체> & <침체> : 0.9999999403953552
# ***2019-11-18 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-11-18 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-11-18 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-11-18 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-11-18 Cosine Similarity between <악화> & <둔화> : 0.5065980553627014
# ***2019-11-18 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2019-11-18 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2019-11-18 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-11-18 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-11-18 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-11-18 Cosine Similarity between <약점> & <강점> : 0.5741010904312134
# ***2019-11-18 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-11-18 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2019-11-18 Cosine Similarity between <약점> & <강점> : 0.5741010904312134
# ***2019-11-18 Cosine Similarity between <의심> & <의심> : 0.9999998807907104
# ***2019-11-18 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2019-11-18 Cosine Similarity between <의혹> & <연루> : 0.5164746046066284
# ***2019-11-18 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-11-18 Cosine Similarity between <마이너스> & <플러스> : 0.5253470540046692
# ***2019-11-18 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-11-18 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2019-11-18 Cosine Similarity between <하락> & <급락> : 0.6878489255905151
# ***2019-11-18 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-11-18 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-11-18 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2019-11-18 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-11-18 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-11-18 Cosine Similarity between <침체> & <업황> : 0.5205409526824951
# ***2019-11-18 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-11-18 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-11-18 Cosine Similarity between <둔화> & <위축> : 0.6352296471595764
# ***2019-11-18 Cosine Similarity between <둔화> & <침체> : 0.5701860189437866
# ***2019-11-18 Cosine Similarity between <둔화> & <악화> : 0.5065980553627014
# ***2019-11-18 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-11-18 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2019-11-18 Cosine Similarity between <약화> & <위축> : 0.5172011256217957
# ***2019-11-18 Cosine Similarity between <약화> & <악화> : 0.5064777731895447
# ***2019-11-18 Cosine Similarity between <침체> & <위축> : 0.5503976345062256
# ***2019-11-18 Cosine Similarity between <침체> & <호황> : 0.6176011562347412
# ***2019-11-18 Cosine Similarity between <침체> & <침체> : 0.9999999403953552
# ***2019-11-18 Cosine Similarity between <침체> & <위기> : 0.5072819590568542
# ***2019-11-18 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-11-18 Cosine Similarity between <하락> & <급락> : 0.6878489255905151
# ***2019-11-18 Cosine Similarity between <둔화> & <위축> : 0.6352296471595764
# ***2019-11-18 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-11-18 Cosine Similarity between <약화> & <위축> : 0.5172011256217957
# ***2019-11-18 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-11-18 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2019-11-18 Cosine Similarity between <침체> & <위축> : 0.5503976345062256
# ***2019-11-18 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-11-19 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-11-19 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-11-19 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-11-19 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-11-19 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-11-19 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-11-19 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-11-19 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2019-11-19 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-11-19 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-11-19 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2019-11-19 Cosine Similarity between <하락> & <급락> : 0.6878489255905151
# ***2019-11-19 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-11-19 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2019-11-19 Cosine Similarity between <둔화> & <반등> : 0.5092458128929138
# ***2019-11-19 Cosine Similarity between <둔화> & <악화> : 0.5065980553627014
# ***2019-11-19 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-11-19 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-11-19 Cosine Similarity between <악화> & <약화> : 0.5064777731895447
# ***2019-11-19 Cosine Similarity between <약화> & <약화> : 0.9999999403953552
# ***2019-11-19 Cosine Similarity between <약화> & <악화> : 0.5064777731895447
# ***2019-11-19 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-11-19 Cosine Similarity between <침체> & <업황> : 0.5205409526824951
# ***2019-11-19 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-11-19 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-11-19 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2019-11-19 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-11-19 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-11-19 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-11-19 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-11-19 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-11-19 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2019-11-19 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-11-19 Cosine Similarity between <하락> & <약세> : 0.5661998987197876
# ***2019-11-19 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-11-19 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-11-19 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-11-19 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-11-19 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-11-19 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-11-19 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-11-19 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2019-11-19 Cosine Similarity between <침체> & <업황> : 0.5205409526824951
# ***2019-11-19 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-11-19 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-11-19 Cosine Similarity between <침체> & <경기> : 0.5360627174377441
# ***2019-11-19 Cosine Similarity between <침체> & <위기> : 0.5072819590568542
# ***2019-11-20 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-11-20 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-11-20 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-11-20 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-11-20 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-11-20 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-11-20 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-11-20 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-11-20 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861
# ***2019-11-20 Cosine Similarity between <약화> & <감소> : 0.551184892654419
# ***2019-11-20 Cosine Similarity between <하락> & <감소> : 0.575989305973053
# ***2019-11-20 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2019-11-20 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2019-11-20 Cosine Similarity between <둔화> & <반등> : 0.5092458128929138
# ***2019-11-20 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2019-11-20 Cosine Similarity between <하락> & <등락> : 0.573682427406311
# ***2019-11-20 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2019-11-20 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2019-11-20 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2019-11-20 Cosine Similarity between <둔화> & <증가> : 0.5041859149932861

# %%
neg_lexicon_2019
# Out:
#              date news_num KOSELF_neg_word news_word  cosine_similarity  \
# 0      2019-01-02        1              악화        둔화           0.506598
# 1      2019-01-02        1              의혹        논란           0.519006
# 2      2019-01-02        1              침체        경기           0.536063
# 3      2019-01-02        1              침체        둔화           0.570186
# 4      2019-01-02        1              하락        둔화           0.526078
# ...           ...      ...             ...       ...                ...
# 25398  2020-01-02     8456              하락        급감           0.519622
# 25399  2020-01-02     8456              하락        감소           0.575989
# 25400  2020-01-02     8456              하락        증가           0.553474
# 25401  2020-01-02     8456              하락        급락           0.687849
# 25402  2020-01-02     8456              하락        반등           0.575454
#
#       frequency
# 0             1
# 1            43
# 2             1
# 3             1
# 4             1
# ...         ...
# 25398         6
# 25399         4
# 25400        21
# 25401         1
# 25402         1
#
# [25403 rows x 6 columns]

# %%
neg_lexicon_2019.to_csv('../../../../Code/Data/Test/Stock-Year/neg_samsung_2019.csv', index=False)

# %%
a = list(set(list(neg_lexicon_2019['news_word'])))

a
# Out:
# ['보상',
#  '불황',
#  '폭로',
#  '끝내',
#  '참패',
#  '급감',
#  '화물',
#  '위축',
#  '금수',
#  '어센던트',
#  '운항',
#  '특혜',
#  '외압',
#  '둔화',
#  '약세',
#  '성공',
#  '호황',
#  '주춤',
#  '경기',
#  '부도',
#  '견조',
#  '급유',
#  '플러스',
#  '침체',
#  '위기',
#  '쿨런트펌프',
#  '엔드픽처',
#  '청탁',
#  '내통',
#  '악화',
#  '결항',
#  '하락',
#  '학연',
#  '갈란츠',
#  '감소',
#  '차량',
#  '불안',
#  '선박',
#  '금값',
#  '의심',
#  '급등',
#  '누전',
#  '쥴랩스',
#  '마이너스제로',
#  '당혹',
#  '강화',
#  '뎁스비전',
#  '약화',
#  '증가',
#  '비리',
#  '쇠퇴',
#  '조처',
#  '추징',
#  '합선',
#  '좌절',
#  '엄벌',
#  '강점',
#  '무마',
#  '손해배상',
#  '유발',
#  '등락',
#  '경색',
#  '우발',
#  '논란',
#  '상승',
#  '텍드림텍',
#  '호전',
#  '작태',
#  '보합',
#  '스캔들',
#  '머락비',
#  '갓길',
#  '저하',
#  '역풍',
#  '악재',
#  '폭등',
#  '체르빈',
#  '리밸린싱',
#  '피슬러',
#  '업황',
#  '급락',
#  '손배',
#  '절상',
#  '르쿨르트',
#  '폐업',
#  '폭락',
#  '실패',
#  '응우옌부뚜',
#  '텅빈채',
#  '혼돈',
#  '병세',
#  '반등',
#  '연루',
#  '질책']

# %%
b = list(set(list(neg_lexicon_2019[neg_lexicon_2019['cosine_similarity']>=0.7]['news_word'])))

b
# Out:
# ['성공', '의심', '침체', '스캔들', '약화', '상승', '실패']

# %%
c = list(set(list(neg_lexicon_2019[neg_lexicon_2019['cosine_similarity']>=0.65]['news_word'])))

c
# Out:
# ['성공', '조처', '의심', '침체', '급락', '약화', '스캔들', '상승', '실패']
