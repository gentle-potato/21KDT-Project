# %% [markdown]
# # **Lexicon**

# %%
import numpy as np
import pandas as pd

### Visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

### DB 연결
# !pip install pymysql
import pymysql

### DB에 저장
import sqlalchemy
from sqlalchemy import create_engine

### 실시간 주식가격 데이터
# !pip install finance-datareader
import FinanceDataReader as fdr

### 텍스트 분석
## KoNLPy
# 1) JAVA 설치, 2) Python 버전과 맞는 JPype1-py3 설치, 3) !pip install konlpy, 4) 설치 경로에서 jvm.py 파일 코드 67번 줄 주석 처리 
from konlpy.tag import Okt
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import re
## FastText
# !pip install gensim
# !pip install fasttext
import fasttext
import fasttext.util
# Facebook 한국어 Embedding 모델 다운로드 → 한 번만 설치하면 됨
# fasttext.util.download_model('ko', if_exists='ignore')   # FastText 모델 사용 시에만 필요
# 유사도 계산
from gensim import models

### 모델 학습 및 평가
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.metrics import precision_score, recall_score, f1_score

### 모델 저장 및 로드
import joblib

### 기타
import datetime
from collections import Counter
import sys
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## **Read Data**

# %% [markdown]
# ### **① Media News**

# %%
corp_list = ['samsung', 'hyundai', 'lg', 'sk', 'celltrion']
years = ['2018', '2019', '2020', '2021']

for i in range(len(corp_list)):
    # 종목별 리스트 생성
    globals()[corp_list[i] + '_years'] = []
    
    # 연도별 뉴스 기사
    for j in range(len(years)):
        globals()[corp_list[i] + '_' + years[j]] = pd.read_csv('../../../../Code/Data/Test/Stock-Year/{}_{}.csv'.format(years[j], corp_list[i]))
        globals()[corp_list[i] + '_years'].append(globals()[corp_list[i] + '_' + years[j]])
    
    # 전체 기간 통합
    globals()[corp_list[i] + '_news'] = pd.concat(globals()[corp_list[i] + '_years'], axis=0).reset_index(drop=True)

# %% [markdown]
# ### **② Giro Dict**

# %%
corp_list = ['samsung', 'hyundai', 'lg', 'sk', 'celltrion']
similar = ['50', '60', '65', '70']

for i in range(len(corp_list)):
    for j in range(len(similar)):
        
        # 긍정어 사전
        with open('../../../../Code/Lexicon/lexicon_{}_pos_{}.txt'.format(corp_list[i], similar[j])) as positive:
            globals()['lexicon_' + corp_list[i] + '_pos_' + similar[j]] = positive.readlines()
        globals()['lexicon_' + corp_list[i] + '_pos_' + similar[j]] = [positive.replace('\n', '') for positive in globals()['lexicon_' + corp_list[i] + '_pos_' + similar[j]]]
        
        # 부정어 사전
        with open('../../../../Code/Lexicon/lexicon_{}_neg_{}.txt'.format(corp_list[i], similar[j])) as negative:
            globals()['lexicon_' + corp_list[i] + '_neg_' + similar[j]] = negative.readlines()
        globals()['lexicon_' + corp_list[i] + '_neg_' + similar[j]] = [negative.replace('\n', '') for negative in globals()['lexicon_' + corp_list[i] + '_neg_' + similar[j]]]

# %% [markdown]
# ## **Sentiment Score**

# %% [markdown]
# ### **① Samsung**

# %%
samsung_news.head(1)
# Out:
#    st_n  st_cd  news    datetime                   title  \
# 0  삼성전자   5930  매일경제  2018010100  스마트베타ETF 고공행진 새해도 이어질까
#
#                                                  url  \
# 0  http://news.mk.co.kr/newsRead.php?year=2018&no=29
#
#                                                 text        date  time   Open  \
# 0  \n\n\n 수수료가 싼 상장지수펀드(ETF)에 펀드매니저가 종목을 고르는 액티브 ...  2018-01-02     0  51380
#
#     High    Low  Close  Volume    Change  UpDown  Extremely_Changed  \
# 0  51400  50780  51020  169485  0.001177       1                  0
#
#                                         Tokenization
# 0  수수료 상장 지수 펀드 펀드매니저 종목 액티브 펀드 특성 가미 스마트 베타 대한 목...

# %%
samsung_news.isna().sum()
# Out:
# st_n                 0
# st_cd                0
# news                 0
# datetime             0
# title                0
# url                  0
# text                 0
# date                 0
# time                 0
# Open                 0
# High                 0
# Low                  0
# Close                0
# Volume               0
# Change               0
# UpDown               0
# Extremely_Changed    0
# Tokenization         2
# dtype: int64

# %%
samsung_news[samsung_news['Tokenization'].isna()]
# Out:
#        st_n  st_cd  news    datetime  \
# 4144   삼성전자   5930  매일경제  2018121204
# 25699  삼성전자   5930  매일경제  2021040516
#
#                                                    title  \
# 4144              [2018 대한민국 지식재산대전] 일상의 불편함 없앤 발명품 한자리에
# 25699  QLED·OLED·미니LED… 복잡한 TV 제품, 삼성·LG TV 제품별 기능 차이...
#
#                                                      url  \
# 4144   http://news.mk.co.kr/newsRead.php?year=2018&no...
# 25699  http://news.mk.co.kr/newsRead.php?no=325040&ye...
#
#                                                     text        date  time  \
# 4144   \n\n\nДыХыЗЩЛѓРЛ МіЛѓЧб КЅУГБтОї ОЦГЏЗЮБзЧУЗЏН...  2018-12-12     4
# 25699  ¿ÃÇØ¿¡µµ ´Ù½Ã ÇÑ ¹ø »ï¼ºÀüÀÚ¿Í LGÀüÀÚÀÇ ¡®TV À...  2021-04-06    16
#
#         Open   High    Low  Close    Volume    Change  UpDown  \
# 4144   40250  40700  40150  40450  12024279  0.004969       1
# 25699  86200  86200  85100  86000  19042023  0.007026       1
#
#        Extremely_Changed Tokenization
# 4144                   0          NaN
# 25699                  0          NaN

# %%
# NaN 제거
for i in range(len(corp_list)):
    globals()[corp_list[i] + '_news'].dropna(inplace=True)
    globals()[corp_list[i] + '_news'] = globals()[corp_list[i] + '_news'].reset_index(drop=True)

# %%
corp_list = ['samsung', 'hyundai', 'lg', 'sk', 'celltrion']
similar = ['50', '60', '65', '70']

# iteration limit 조정
limit_number = 15000
sys.setrecursionlimit(limit_number)

for i in range(len(corp_list)):
    globals()[corp_list[i] + '_news']['Positive_Score'] = 0
    globals()[corp_list[i] + '_news']['Negative_Score'] = 0
    globals()[corp_list[i] + '_news']['Ratio'] = 0.1
    globals()[corp_list[i] + '_news']['Pred'] = 0
    
    for j in range(len(similar)):
        globals()[corp_list[i] + '_news_' + similar[j]] = globals()[corp_list[i] + '_news'].copy()
    
        for k in range(len(globals()[corp_list[i] + '_news_' + similar[j]]['Tokenization'])):
            pos_score = 0 ; neg_score = 0
            
            for l in range(len(globals()[corp_list[i] + '_news_' + similar[j]]['Tokenization'][k].split())):
                if globals()[corp_list[i] + '_news_' + similar[j]]['Tokenization'][k].split()[l] in globals()['lexicon_' + corp_list[i] + '_pos_' + similar[j]]:
                    pos_score += 1
                elif globals()[corp_list[i] + '_news_' + similar[j]]['Tokenization'][k].split()[l] in globals()['lexicon_' + corp_list[i] + '_neg_' + similar[j]]:
                    neg_score += 1
                else:
                    pass

            globals()[corp_list[i] + '_news_' + similar[j]]['Positive_Score'][k] = pos_score
            globals()[corp_list[i] + '_news_' + similar[j]]['Negative_Score'][k] = neg_score
            
            # 긍정과 부정의 비율
            if (pos_score==0) or (neg_score==0):
                globals()[corp_list[i] + '_news_' + similar[j]]['Ratio'][k] = 0.5   # 사전에 포함되는 단어가 없으면 주가가 상승할 확률을 0.5로 가정
            else:
                globals()[corp_list[i] + '_news_' + similar[j]]['Ratio'][k] = pos_score / (pos_score + neg_score)
            
            # 예측 결과
            if globals()[corp_list[i] + '_news_' + similar[j]]['Ratio'][k]>=0.5:
                globals()[corp_list[i] + '_news_' + similar[j]]['Pred'][k] = 1
            else:
                globals()[corp_list[i] + '_news_' + similar[j]]['Pred'][k] = -1
            
        # CSV로 저장
        globals()[corp_list[i] + '_news_' + similar[j]].to_csv('../../../../Code/Lexicon/{}_news_{}.csv'.format(corp_list[i], similar[j]), index=False)
        
        print('... {}번째 종목의 {}/4 완료 ...'.format(i+1, j+1))
    
    print('===== {}번째 종목 완료! =====\n'.format(i+1))

print('####### 전부 완료-! #######')
# Out:
# ... 1번째 종목의 1/4 완료 ...
# ... 1번째 종목의 2/4 완료 ...
# ... 1번째 종목의 3/4 완료 ...
# ... 1번째 종목의 4/4 완료 ...
# ===== 1번째 종목 완료! =====
#
# ... 2번째 종목의 1/4 완료 ...
# ... 2번째 종목의 2/4 완료 ...
# ... 2번째 종목의 3/4 완료 ...
# ... 2번째 종목의 4/4 완료 ...
# ===== 2번째 종목 완료! =====
#
# ... 3번째 종목의 1/4 완료 ...
# ... 3번째 종목의 2/4 완료 ...
# ... 3번째 종목의 3/4 완료 ...
# ... 3번째 종목의 4/4 완료 ...
# ===== 3번째 종목 완료! =====
#
# ... 4번째 종목의 1/4 완료 ...
# ... 4번째 종목의 2/4 완료 ...
# ... 4번째 종목의 3/4 완료 ...
# ... 4번째 종목의 4/4 완료 ...
# ===== 4번째 종목 완료! =====
#
# ... 5번째 종목의 1/4 완료 ...
# ... 5번째 종목의 2/4 완료 ...
# ... 5번째 종목의 3/4 완료 ...
# ... 5번째 종목의 4/4 완료 ...
# ===== 5번째 종목 완료! =====
#
# ####### 전부 완료-! #######

# %%
# # NaN 제거
# for i in range(len(corp_list)):
#     for j in range(len(similar)):
#         globals()[corp_list[i] + '_news_' + similar[j]].dropna(inplace=True)
#         globals()[corp_list[i] + '_news_' + similar[j]] = globals()[corp_list[i] + '_news_' + similar[j]].reset_index(drop=True)

# %%
# Accuracy 확인
for i in range(len(corp_list)):
    if corp_list[i] == 'samsung':
        corp = 'SAMSUNG'
    elif corp_list[i] == 'hyundai':
        corp = 'HYUNDAI'
    elif corp_list[i] == 'lg':
        corp = 'LG'
    elif corp_list[i] == 'sk':
        corp = 'SK'
    else:
        corp = 'CELLTRION'
        
    for j in range(len(similar)):
        print("Lexicon of {}({}%)'s Accuracy : {}".format(corp, similar[j], (len(globals()[corp_list[i] + '_news_' + similar[j]][(globals()[corp_list[i] + '_news_' + similar[j]]['UpDown']>=0) & (globals()[corp_list[i] + '_news_' + similar[j]]['Pred']>=0)]) + len(globals()[corp_list[i] + '_news_' + similar[j]][(globals()[corp_list[i] + '_news_' + similar[j]]['UpDown']<0) & (globals()[corp_list[i] + '_news_' + similar[j]]['Pred']<0)])) / len(globals()[corp_list[i] + '_news_' + similar[j]]['Pred'])))
    
    print('\n==================================================\n')
# Out:
# Lexicon of SAMSUNG(50%)'s Accuracy : 0.4962393774623124
# Lexicon of SAMSUNG(60%)'s Accuracy : 0.4963696154722756
# Lexicon of SAMSUNG(65%)'s Accuracy : 0.4968905675121284
# Lexicon of SAMSUNG(70%)'s Accuracy : 0.4989092566665581
#
# ==================================================
#
# Lexicon of HYUNDAI(50%)'s Accuracy : 0.46895886889460153
# Lexicon of HYUNDAI(60%)'s Accuracy : 0.46503856041131103
# Lexicon of HYUNDAI(65%)'s Accuracy : 0.462853470437018
# Lexicon of HYUNDAI(70%)'s Accuracy : 0.4645886889460154
#
# ==================================================
#
# Lexicon of LG(50%)'s Accuracy : 0.5165836298932385
# Lexicon of LG(60%)'s Accuracy : 0.511459074733096
# Lexicon of LG(65%)'s Accuracy : 0.5079003558718861
# Lexicon of LG(70%)'s Accuracy : 0.5047686832740214
#
# ==================================================
#
# Lexicon of SK(50%)'s Accuracy : 0.49957654033453314
# Lexicon of SK(60%)'s Accuracy : 0.5003175947491002
# Lexicon of SK(65%)'s Accuracy : 0.49978827016726657
# Lexicon of SK(70%)'s Accuracy : 0.49576540334533137
#
# ==================================================
#
# Lexicon of CELLTRION(50%)'s Accuracy : 0.4913294797687861
# Lexicon of CELLTRION(60%)'s Accuracy : 0.4977979631158822
# Lexicon of CELLTRION(65%)'s Accuracy : 0.49421965317919075
# Lexicon of CELLTRION(70%)'s Accuracy : 0.4993118634737132
#
# ==================================================

# %%
# # 부호 확인
# np.sign(0)

# %%
samsung_news_50[samsung_news_50['Positive_Score'] != samsung_news_70['Positive_Score']]
# Out:
#        st_n  st_cd   news    datetime  \
# 0      삼성전자   5930   매일경제  2018010100
# 1      삼성전자   5930   매일경제  2018010100
# 2      삼성전자   5930   매일경제  2018010100
# 3      삼성전자   5930   매일경제  2018010104
# 4      삼성전자   5930   매일경제  2018010104
# ...     ...    ...    ...         ...
# 30708  삼성전자   5930  아시아경제  2021091512
# 30709  삼성전자   5930  아시아경제  2021091513
# 30710  삼성전자   5930  아시아경제  2021091513
# 30711  삼성전자   5930  아시아경제  2021091516
# 30712  삼성전자   5930  아시아경제  2021091516
#
#                                               title  \
# 0                            스마트베타ETF 고공행진 새해도 이어질까
# 1                               동원산업·휠라코리아 "생큐 트럼프"
# 2                             매경춘추 새 필진과 새해 아침을 여세요
# 3      [2018 경제기상도] `1월효과` 기대 커진 증시…반도체·바이오株 계속 달릴듯
# 4        [2018 국내 업종별 전망] 가전, OLED TV `올림픽·월드컵 겹호재`
# ...                                             ...
# 30708                   국민연금, 하반기 실적주로 '반도체·게임' 늘렸다
# 30709                       코스피, 오후들어 상승전환…3160선 거래
# 30710                       코스피, 오후들어 상승전환…3160선 거래
# 30711                         외국인 순매수세에 코스피 소폭 상승마감
# 30712                         외국인 순매수세에 코스피 소폭 상승마감
#
#                                                      url  \
# 0      http://news.mk.co.kr/newsRead.php?year=2018&no=29
# 1      http://news.mk.co.kr/newsRead.php?year=2018&no=30
# 2      http://news.mk.co.kr/newsRead.php?year=2018&no=18
# 3      http://news.mk.co.kr/newsRead.php?year=2018&no...
# 4      http://news.mk.co.kr/newsRead.php?year=2018&no...
# ...                                                  ...
# 30708  https://view.asiae.co.kr/article/2021091510161...
# 30709  https://view.asiae.co.kr/article/2021091513394...
# 30710  https://view.asiae.co.kr/article/2021091513394...
# 30711  https://view.asiae.co.kr/article/2021091516084...
# 30712  https://view.asiae.co.kr/article/2021091516084...
#
#                                                     text        date  time  \
# 0      \n\n\n 수수료가 싼 상장지수펀드(ETF)에 펀드매니저가 종목을 고르는 액티브 ...  2018-01-02     0
# 1      ■ 2018 美법인세인하 수혜株 \n\n\n 올해 1월부터 법인세 인하를 골자로 한...  2018-01-02     0
# 2      \n\n\n 명품 에세이 매경춘추가 새해를 맞아 새 필진을 소개합니다. 유독 다사다...  2018-01-02     0
# 3      \n\n\n 지난해 연말 조정장세는 올해 초 코스피와 코스닥시장 '1월 효과'의 기...  2018-01-02     4
# 4      \n\n\n 지난해 글로벌 TV 수요가 전반적으로 감소한 가운데 새해 가전시장에서는...  2018-01-02     4
# ...                                                  ...         ...   ...
# 30708  8월부터 테스나·고려아연·효성·위메이드 4개사 지분 늘려업황 호조·실적 기대감......  2021-09-15    12
# 30709  외국인 순매수로 전환中 부양책 기대감 증시 유입 [이미지출처=연합뉴스]썝蹂몃낫湲 븘...  2021-09-15    13
# 30710  외국인 순매수로 전환中 부양책 기대감 증시 유입 [이미지출처=연합뉴스]썝蹂몃낫湲 븘...  2021-09-15    13
# 30711  중국 정부 부양책 기대감 반영셀트리온 3형제 3%대 상승 마감 [이미지출처=연합뉴스...  2021-09-16    16
# 30712  중국 정부 부양책 기대감 반영셀트리온 3형제 3%대 상승 마감 [이미지출처=연합뉴스...  2021-09-16    16
#
#         Open  ...  Close    Volume    Change  UpDown  Extremely_Changed  \
# 0      51380  ...  51020    169485  0.001177       1                  0
# 1      51380  ...  51020    169485  0.001177       1                  0
# 2      51380  ...  51020    169485  0.001177       1                  0
# 3      51380  ...  51020    169485  0.001177       1                  0
# 4      51380  ...  51020    169485  0.001177       1                  0
# ...      ...  ...    ...       ...       ...     ...                ...
# 30708  77400  ...  77000  12829128  0.005222       1                  0
# 30709  77400  ...  77000  12829128  0.005222       1                  0
# 30710  77400  ...  77000  12829128  0.005222       1                  0
# 30711  77300  ...  76100  12877239 -0.011688      -1                  0
# 30712  77300  ...  76100  12877239 -0.011688      -1                  0
#
#                                             Tokenization  Positive_Score  \
# 0      수수료 상장 지수 펀드 펀드매니저 종목 액티브 펀드 특성 가미 스마트 베타 대한 목...               6
# 1      법인세 인하 수혜 올해 법인세 인하 골자 미국 세제 개혁 법안 현실 국내 증시 관련...              10
# 2      명품 에세이 춘추 새해 소개 유독 다사 마음 무술년 독자 여러분 법률 경영 의료 과...               3
# 3      지난해 연말 정장 올해 코스피 코스닥시장 효과 폭제 전망 장사 실적 단기 급상승 우...              29
# 4      지난해 글로벌 수요 전반 감소 가운데 새해 가전 시장 프리미엄 돌파구 마련 올해 평...               9
# ...                                                  ...             ...
# 30708  테스 고려아연 효성 위메이드 개사 업황 호조 실적 대감 철강 의류 제약 업종 비중 ...              22
# 30709  외국인 수로 전환 부양책 대감 증시 유입 이미지 출처 연합뉴스 몃낫 븘씠 아시아 경...               2
# 30710  외국인 수로 전환 부양책 대감 증시 유입 이미지 출처 연합뉴스 몃낫 븘씠 아시아 경...               2
# 30711  중국 정부 부양책 대감 반영 셀트리온 형제 상승 마감 이미지 출처 연합뉴스 몃낫 븘...              11
# 30712  중국 정부 부양책 대감 반영 셀트리온 형제 상승 마감 이미지 출처 연합뉴스 몃낫 븘...              11
#
#       Negative_Score     Ratio  Pred
# 0                  0  0.500000     1
# 1                  4  0.714286     1
# 2                  1  0.750000     1
# 3                 17  0.630435     1
# 4                  0  0.500000     1
# ...              ...       ...   ...
# 30708             10  0.687500     1
# 30709             35  0.054054    -1
# 30710             35  0.054054    -1
# 30711             37  0.229167    -1
# 30712             37  0.229167    -1
#
# [27688 rows x 22 columns]

# %%
samsung_news_50.shape, samsung_news_70.shape
# Out:
# ((30713, 22), (30713, 22))

# %%
samsung_news_50.head(1)
# Out:
#    st_n  st_cd  news    datetime                   title  \
# 0  삼성전자   5930  매일경제  2018010100  스마트베타ETF 고공행진 새해도 이어질까
#
#                                                  url  \
# 0  http://news.mk.co.kr/newsRead.php?year=2018&no=29
#
#                                                 text        date  time   Open  \
# 0  \n\n\n 수수료가 싼 상장지수펀드(ETF)에 펀드매니저가 종목을 고르는 액티브 ...  2018-01-02     0  51380
#
#    ...  Close  Volume    Change  UpDown  Extremely_Changed  \
# 0  ...  51020  169485  0.001177       1                  0
#
#                                         Tokenization  Positive_Score  \
# 0  수수료 상장 지수 펀드 펀드매니저 종목 액티브 펀드 특성 가미 스마트 베타 대한 목...               6
#
#   Negative_Score  Ratio  Pred
# 0              0    0.5     1
#
# [1 rows x 22 columns]

# %%
samsung_news_70.head(1)
# Out:
#    st_n  st_cd  news    datetime                   title  \
# 0  삼성전자   5930  매일경제  2018010100  스마트베타ETF 고공행진 새해도 이어질까
#
#                                                  url  \
# 0  http://news.mk.co.kr/newsRead.php?year=2018&no=29
#
#                                                 text        date  time   Open  \
# 0  \n\n\n 수수료가 싼 상장지수펀드(ETF)에 펀드매니저가 종목을 고르는 액티브 ...  2018-01-02     0  51380
#
#    ...  Close  Volume    Change  UpDown  Extremely_Changed  \
# 0  ...  51020  169485  0.001177       1                  0
#
#                                         Tokenization  Positive_Score  \
# 0  수수료 상장 지수 펀드 펀드매니저 종목 액티브 펀드 특성 가미 스마트 베타 대한 목...               2
#
#   Negative_Score  Ratio  Pred
# 0              0    0.5     1
#
# [1 rows x 22 columns]
