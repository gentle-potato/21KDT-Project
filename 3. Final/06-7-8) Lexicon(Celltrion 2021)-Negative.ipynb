# %% [markdown]
# # **Lexicon**

# %%
import numpy as np
import pandas as pd

### Visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

### DB 연결
# !pip install pymysql
import pymysql

### DB에 저장
import sqlalchemy
from sqlalchemy import create_engine

### 실시간 주식가격 데이터
# !pip install finance-datareader
import FinanceDataReader as fdr

### 텍스트 분석
## KoNLPy
# 1) JAVA 설치, 2) Python 버전과 맞는 JPype1-py3 설치, 3) !pip install konlpy, 4) 설치 경로에서 jvm.py 파일 코드 67번 줄 주석 처리 
from konlpy.tag import Okt
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import re
## FastText
# !pip install gensim
# !pip install fasttext
import fasttext
import fasttext.util
# Facebook 한국어 Embedding 모델 다운로드 → 한 번만 설치하면 됨
fasttext.util.download_model('ko', if_exists='ignore')
# 유사도 계산
from gensim import models

### 모델 학습 및 평가
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.metrics import precision_score, recall_score, f1_score

### 모델 저장 및 로드
import joblib

### 기타
import datetime
from collections import Counter
import sys
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow as tf

print('GPU', '사용 가능' if tf.config.experimental.list_physical_devices('GPU') else '사용 불가능')
# Out:
# GPU 사용 불가능

# %%
# !nvidia-smi
# Out:
# Mon Sep 20 00:41:57 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 457.49       Driver Version: 457.49       CUDA Version: 11.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 1650   WDDM  | 00000000:01:00.0  On |                  N/A |
# | N/A   45C    P8     2W /  N/A |    546MiB /  4096MiB |     25%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      4512    C+G   ...cw5n1h2txyewy\LockApp.exe    N/A      |
# |    0   N/A  N/A      7592    C+G   ...bbwe\Microsoft.Photos.exe    N/A      |
# |    0   N/A  N/A      8624    C+G   ...y\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A      8940    C+G   C:\Windows\explorer.exe         N/A      |
# |    0   N/A  N/A     10660    C+G   Insufficient Permissions        N/A      |
# |    0   N/A  N/A     11908    C+G   ...5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A     12124    C+G   ...urrent\LogiOptionsMgr.exe    N/A      |
# |    0   N/A  N/A     16996    C+G   ...ropbox\Client\Dropbox.exe    N/A      |
# |    0   N/A  N/A     18264    C+G   ...nputApp\TextInputHost.exe    N/A      |
# |    0   N/A  N/A     18940    C+G   ...e\Current\LogiOverlay.exe    N/A      |
# |    0   N/A  N/A     22380    C+G   ...me\Application\chrome.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## **Read KOSELF & Test Data**

# %% [markdown]
# ### **① KOSELF 감성 어휘 사전**

# %%
# 블로그에서 가져온 기본적인 한국어 긍부정 텍스트 목록
with open('positive_words_self.txt', encoding='utf-8') as pos_blog:
    positive_blog = pos_blog.readlines()
positive_blog = [pos_blog.replace('\n', '') for pos_blog in positive_blog]
with open('negative_words_self.txt', encoding='utf-8') as neg_blog:
    negative_blog = neg_blog.readlines()
negative_blog = [neg_blog.replace('\n', '') for neg_blog in negative_blog]

# KOSELF 감성 어휘 사전
with open('KOSELF_pos.txt', encoding='utf-8') as pos:
    positive = pos.readlines()
positive = [pos.replace('\n', '') for pos in positive]
with open('KOSELF_neg.txt', encoding='utf-8') as neg:
    negative = neg.readlines()
negative = [neg.replace('\n', '') for neg in negative]

# %% [markdown]
# ### **② 2021년 Celltrion Data**

# %%
lexicon_2021 = pd.read_csv('../../../../Code/Data/Test/Stock-Year/2021_celltrion.csv')

lexicon_2021.head(1)
# Out:
#    st_n  st_cd  news    datetime                               title  \
# 0  셀트리온  68270  매일경제  2021010106  [돈터뷰] 슈퍼개미에게 묻는다! 사야하는 주식 안되는 주식은?
#
#                                                  url  \
# 0  http://news.mk.co.kr/newsRead.php?no=433&year=...
#
#                                                 text        date  time  \
# 0   \n\n\n '보컬'로 알려진 슈퍼개미 김형준 대표는 매일경제 '돈터뷰'에 출연해...  2021-01-04     6
#
#      Open    High     Low   Close   Volume    Change  UpDown  \
# 0  351500  354500  343000  347500  2006483 -0.032033      -1
#
#    Extremely_Changed                                       Tokenization
# 0                  0  보컬 슈퍼 개미 김형준 대표 매일경제 돈터뷰 출연 자신 투자 철학 방법 공개 대표 ...

# %%
lexicon_2021[lexicon_2021['text'].isna()]
# Out:
# Empty DataFrame
# Columns: [st_n, st_cd, news, datetime, title, url, text, date, time, Open, High, Low, Close, Volume, Change, UpDown, Extremely_Changed, Tokenization]
# Index: []

# %%
lexicon_2021.dropna(axis=0, inplace=True)
lexicon_2021 = lexicon_2021.reset_index(drop=True)
lexicon_2021.isna().sum()
# Out:
# st_n                 0
# st_cd                0
# news                 0
# datetime             0
# title                0
# url                  0
# text                 0
# date                 0
# time                 0
# Open                 0
# High                 0
# Low                  0
# Close                0
# Volume               0
# Change               0
# UpDown               0
# Extremely_Changed    0
# Tokenization         0
# dtype: int64

# %% [markdown]
# ## **Calculate Cosine Similarity**

# %%
# 이미 학습된 FastText 내장 한국어 모델
try:
    print(ko_model, '모델 로드 불필요')
except:
    ko_model = models.fasttext.load_facebook_model('cc.ko.300.bin')

# %%
limit_number = 15000
sys.setrecursionlimit(limit_number)

# %%
neg_lexicon_2021 = pd.DataFrame(columns=['date', 'news_num', 'KOSELF_neg_word', 'news_word', 'cosine_similarity', 'frequency'])   # 'frequency' 구현할 방법은 추후 생각...ㅠㅠ

# KOSELF_neg와의 Cosine Similarity 계산
for x in range(len(lexicon_2021['Tokenization'])):
    news_num = x+1
    for y in range(len(negative)):
        for z in range(len(list(set(lexicon_2021['Tokenization'][x].split())))):
            if (ko_model.wv.similarity(negative[y], list(set(lexicon_2021['Tokenization'][x].split()))[z]) >= 0.5) and (ko_model.wv.similarity(negative[y], list(set(lexicon_2021['Tokenization'][x].split()))[z]) != 1.0):
                freq = 0
                for w in range(len(lexicon_2021['Tokenization'][x].split())):
                    if lexicon_2021['Tokenization'][x].split()[w] == list(set(lexicon_2021['Tokenization'][x].split()))[z]:
                        freq += 1
                data = {
                    'date': lexicon_2021['date'][x],
                    'news_num': news_num,
                    'KOSELF_neg_word': negative[y],
                    'news_word': list(set(lexicon_2021['Tokenization'][x].split()))[z],
                    'cosine_similarity': ko_model.wv.similarity(negative[y], list(set(lexicon_2021['Tokenization'][x].split()))[z]),
                    'frequency': freq
                    }
                neg_lexicon_2021 = neg_lexicon_2021.append(data, ignore_index=True)
                print("***{0} Cosine Similarity between <{1}> & <{2}> : {3}".format(lexicon_2021['date'][x], negative[y], list(set(lexicon_2021['Tokenization'][x].split()))[z], ko_model.wv.similarity(negative[y], list(set(lexicon_2021['Tokenization'][x].split()))[z])))
# Out:
# ***2021-01-04 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-01-04 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2021-01-04 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-01-04 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-01-04 Cosine Similarity between <하락> & <급락> : 0.6878489851951599
# ***2021-01-04 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-01-04 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2021-01-04 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-01-04 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-01-04 Cosine Similarity between <하락> & <급락> : 0.6878489851951599
# ***2021-01-04 Cosine Similarity between <침체> & <위기> : 0.507282018661499
# ***2021-01-04 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-01-04 Cosine Similarity between <과적> & <차량> : 0.5693625807762146
# ***2021-01-04 Cosine Similarity between <둔화> & <위축> : 0.6352296471595764
# ***2021-01-04 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-01-04 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-01-04 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-01-04 Cosine Similarity between <약화> & <위축> : 0.5172010660171509
# ***2021-01-04 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-01-04 Cosine Similarity between <조치> & <조치> : 0.9999999403953552
# ***2021-01-04 Cosine Similarity between <침체> & <위축> : 0.550397515296936
# ***2021-01-04 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-01-04 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-01-04 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-01-04 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-01-04 Cosine Similarity between <과적> & <차량> : 0.5693625807762146
# ***2021-01-04 Cosine Similarity between <둔화> & <위축> : 0.6352296471595764
# ***2021-01-04 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-01-04 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-01-04 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-01-04 Cosine Similarity between <약화> & <위축> : 0.5172010660171509
# ***2021-01-04 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-01-04 Cosine Similarity between <조치> & <조치> : 0.9999999403953552
# ***2021-01-04 Cosine Similarity between <침체> & <위축> : 0.550397515296936
# ***2021-01-04 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-01-04 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-01-04 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-01-04 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-01-04 Cosine Similarity between <침체> & <위기> : 0.507282018661499
# ***2021-01-04 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-01-04 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-01-04 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-01-04 Cosine Similarity between <배상> & <보상> : 0.5126209259033203
# ***2021-01-04 Cosine Similarity between <혼란> & <혼돈> : 0.5298054218292236
# ***2021-01-04 Cosine Similarity between <배상> & <보상> : 0.5126209259033203
# ***2021-01-04 Cosine Similarity between <혼란> & <혼돈> : 0.5298054218292236
# ***2021-01-05 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-01-05 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-01-05 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-01-05 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-01-05 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-01-06 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-01-06 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-01-06 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-01-06 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-01-06 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-01-06 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-01-06 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-01-06 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-01-06 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-01-06 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-01-06 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-01-06 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-01-06 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-01-06 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-01-06 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-01-06 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-01-06 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-01-06 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-01-06 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-01-06 Cosine Similarity between <침체> & <호황> : 0.6176010966300964
# ***2021-01-06 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-01-06 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-01-06 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-01-06 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-01-06 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-01-06 Cosine Similarity between <혼란> & <불안> : 0.513291597366333
# ***2021-01-12 Cosine Similarity between <배상> & <보상> : 0.5126209259033203
# ***2021-01-12 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-01-12 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-01-12 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-01-12 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-01-12 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-01-12 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-01-12 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2021-01-12 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-01-12 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-01-12 Cosine Similarity between <침체> & <업황> : 0.5205410122871399
# ***2021-01-12 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-01-12 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2021-01-12 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-01-12 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-01-12 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-01-12 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2021-01-12 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-01-12 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-01-12 Cosine Similarity between <침체> & <업황> : 0.5205410122871399
# ***2021-01-12 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-01-12 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2021-01-12 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-01-12 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-01-12 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-01-12 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2021-01-12 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-01-12 Cosine Similarity between <하락> & <약세> : 0.5661999583244324
# ***2021-01-12 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-01-13 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2021-01-13 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-01-13 Cosine Similarity between <하락> & <약세> : 0.5661999583244324
# ***2021-01-13 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-01-13 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-01-13 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-01-13 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2021-01-13 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-01-13 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2021-01-13 Cosine Similarity between <악화> & <약화> : 0.5064777731895447
# ***2021-01-13 Cosine Similarity between <약화> & <약화> : 0.9999999403953552
# ***2021-01-13 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2021-01-13 Cosine Similarity between <조치> & <조치> : 0.9999999403953552
# ***2021-01-13 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-01-13 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-01-13 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-01-13 Cosine Similarity between <하락> & <약세> : 0.5661999583244324
# ***2021-01-13 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-01-13 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-01-13 Cosine Similarity between <하락> & <급락> : 0.6878489851951599
# ***2021-01-13 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-01-13 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2021-01-13 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-01-13 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2021-01-13 Cosine Similarity between <악화> & <약화> : 0.5064777731895447
# ***2021-01-13 Cosine Similarity between <약화> & <약화> : 0.9999999403953552
# ***2021-01-13 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2021-01-13 Cosine Similarity between <조치> & <조치> : 0.9999999403953552
# ***2021-01-13 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-01-13 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-01-13 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-01-13 Cosine Similarity between <하락> & <약세> : 0.5661999583244324
# ***2021-01-13 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-01-13 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-01-13 Cosine Similarity between <하락> & <급락> : 0.6878489851951599
# ***2021-01-14 Cosine Similarity between <둔화> & <악화> : 0.5065981149673462
# ***2021-01-14 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-01-14 Cosine Similarity between <약화> & <악화> : 0.5064777731895447
# ***2021-01-14 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-01-14 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-01-14 Cosine Similarity between <둔화> & <악화> : 0.5065981149673462
# ***2021-01-14 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-01-14 Cosine Similarity between <약화> & <악화> : 0.5064777731895447
# ***2021-01-14 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-01-14 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-01-14 Cosine Similarity between <둔화> & <악화> : 0.5065981149673462
# ***2021-01-14 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-01-14 Cosine Similarity between <약화> & <악화> : 0.5064777731895447
# ***2021-01-14 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-01-14 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-01-14 Cosine Similarity between <둔화> & <악화> : 0.5065981149673462
# ***2021-01-14 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-01-14 Cosine Similarity between <약화> & <악화> : 0.5064777731895447
# ***2021-01-14 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-01-14 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-01-14 Cosine Similarity between <실패> & <성공> : 0.7068130970001221
# ***2021-01-14 Cosine Similarity between <실패> & <성공> : 0.7068130970001221
# ***2021-01-15 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-01-15 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-01-15 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-01-15 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-01-15 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-01-15 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-01-15 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-01-15 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-01-15 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2021-01-15 Cosine Similarity between <실패> & <성공> : 0.7068130970001221
# ***2021-01-15 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-01-15 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-01-15 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-01-15 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-01-15 Cosine Similarity between <하락> & <급락> : 0.6878489851951599
# ***2021-01-15 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-01-15 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-01-15 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2021-01-15 Cosine Similarity between <실패> & <성공> : 0.7068130970001221
# ***2021-01-15 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-01-15 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-01-15 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-01-15 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-01-15 Cosine Similarity between <하락> & <급락> : 0.6878489851951599
# ***2021-01-15 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-01-15 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-01-15 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2021-01-15 Cosine Similarity between <실패> & <성공> : 0.7068130970001221
# ***2021-01-15 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-01-15 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-01-15 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-01-15 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-01-15 Cosine Similarity between <하락> & <급락> : 0.6878489851951599
# ***2021-01-15 Cosine Similarity between <둔화> & <악화> : 0.5065981149673462
# ***2021-01-15 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-01-15 Cosine Similarity between <둔화> & <호전> : 0.5174993872642517
# ***2021-01-15 Cosine Similarity between <악화> & <호전> : 0.5666260123252869
# ***2021-01-15 Cosine Similarity between <약화> & <악화> : 0.5064777731895447
# ***2021-01-15 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-01-15 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2021-01-15 Cosine Similarity between <침체> & <업황> : 0.5205410122871399
# ***2021-01-15 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-01-15 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-01-15 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-01-18 Cosine Similarity between <실패> & <성공> : 0.7068130970001221
# ***2021-01-18 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-01-18 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-01-18 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-01-18 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2021-01-18 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-01-18 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-01-18 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-01-19 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-01-19 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2021-01-19 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-01-19 Cosine Similarity between <하락> & <급락> : 0.6878489851951599
# ***2021-01-19 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-01-19 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2021-01-19 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-01-19 Cosine Similarity between <하락> & <급락> : 0.6878489851951599
# ***2021-01-19 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-01-19 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-01-19 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-01-19 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-01-19 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-01-19 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-01-19 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2021-01-19 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-01-19 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-01-19 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-01-19 Cosine Similarity between <여파> & <악재> : 0.5317699313163757
# ***2021-01-19 Cosine Similarity between <하락> & <약세> : 0.5661999583244324
# ***2021-01-19 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-01-19 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-01-19 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-01-19 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2021-01-19 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-01-19 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-01-19 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-01-19 Cosine Similarity between <여파> & <악재> : 0.5317699313163757
# ***2021-01-19 Cosine Similarity between <하락> & <약세> : 0.5661999583244324
# ***2021-01-19 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-01-19 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-01-19 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-01-20 Cosine Similarity between <둔화> & <위축> : 0.6352296471595764
# ***2021-01-20 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-01-20 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-01-20 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2021-01-20 Cosine Similarity between <약화> & <위축> : 0.5172010660171509
# ***2021-01-20 Cosine Similarity between <여파> & <악재> : 0.5317699313163757
# ***2021-01-20 Cosine Similarity between <침체> & <위기> : 0.507282018661499
# ***2021-01-20 Cosine Similarity between <침체> & <위축> : 0.550397515296936
# ***2021-01-20 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-01-20 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2021-01-20 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-01-20 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-01-20 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-01-20 Cosine Similarity between <하락> & <급락> : 0.6878489851951599
# ***2021-01-20 Cosine Similarity between <둔화> & <악화> : 0.5065981149673462
# ***2021-01-20 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-01-20 Cosine Similarity between <약화> & <악화> : 0.5064777731895447
# ***2021-01-20 Cosine Similarity between <지연> & <지연> : 0.9999999403953552
# ***2021-01-20 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-01-20 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-01-20 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-01-20 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-01-20 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-01-20 Cosine Similarity between <침체> & <폭락> : 0.5104137063026428
# ***2021-01-20 Cosine Similarity between <하락> & <폭락> : 0.5914363861083984
# ***2021-01-20 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-01-20 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-01-22 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-01-22 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-01-22 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2021-01-22 Cosine Similarity between <여파> & <악재> : 0.5317699313163757
# ***2021-01-22 Cosine Similarity between <침체> & <폭락> : 0.5104137063026428
# ***2021-01-22 Cosine Similarity between <하락> & <폭락> : 0.5914363861083984
# ***2021-01-22 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-01-22 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-01-22 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-01-22 Cosine Similarity between <하락> & <급락> : 0.6878489851951599
# ***2021-01-25 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-01-25 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2021-01-25 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2021-01-25 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-01-25 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-01-25 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-01-25 Cosine Similarity between <침체> & <폭락> : 0.5104137063026428
# ***2021-01-25 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-01-25 Cosine Similarity between <하락> & <폭락> : 0.5914363861083984
# ***2021-01-25 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-01-25 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-01-25 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-01-25 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2021-01-25 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-01-26 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2021-01-26 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2021-01-26 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-01-26 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-01-26 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2021-01-26 Cosine Similarity between <하락> & <등락> : 0.5736824870109558
# ***2021-01-26 Cosine Similarity between <하락> & <약세> : 0.5661999583244324
# ***2021-01-26 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-01-26 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-01-26 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-01-26 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-01-26 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-01-26 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2021-01-26 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-01-26 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-01-26 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-01-27 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-01-27 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-01-27 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-01-27 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-02-01 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2021-02-01 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-02-01 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2021-02-01 Cosine Similarity between <침체> & <업황> : 0.5205410122871399
# ***2021-02-01 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-02-01 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-02-01 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-02-01 Cosine Similarity between <하락> & <급락> : 0.6878489851951599
# ***2021-02-01 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2021-02-01 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-02-01 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-02-01 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2021-02-01 Cosine Similarity between <침체> & <업황> : 0.5205410122871399
# ***2021-02-01 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-02-01 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-02-01 Cosine Similarity between <하락> & <주춤> : 0.5109282732009888
# ***2021-02-01 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-02-01 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-02-01 Cosine Similarity between <하락> & <급락> : 0.6878489851951599
# ***2021-02-01 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-02-01 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-02-01 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-02-01 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-02-01 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-02-01 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-02-01 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-02-02 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-02-02 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-02-02 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-02-02 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2021-02-02 Cosine Similarity between <의혹> & <연루> : 0.5164745450019836
# ***2021-02-02 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-02-02 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-02-02 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-02-02 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2021-02-02 Cosine Similarity between <의혹> & <연루> : 0.5164745450019836
# ***2021-02-02 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-02-02 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-02-02 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2021-02-02 Cosine Similarity between <조치> & <조치> : 0.9999999403953552
# ***2021-02-02 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-02-02 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-02-02 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-02-02 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-02-02 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-02-02 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2021-02-02 Cosine Similarity between <조치> & <조치> : 0.9999999403953552
# ***2021-02-02 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-02-02 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-02-02 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-02-02 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-02-02 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2021-02-02 Cosine Similarity between <둔화> & <위축> : 0.6352296471595764
# ***2021-02-02 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-02-02 Cosine Similarity between <악화> & <약화> : 0.5064777731895447
# ***2021-02-02 Cosine Similarity between <악화> & <둔화> : 0.5065981149673462
# ***2021-02-02 Cosine Similarity between <약화> & <약화> : 0.9999999403953552
# ***2021-02-02 Cosine Similarity between <약화> & <위축> : 0.5172010660171509
# ***2021-02-02 Cosine Similarity between <지연> & <지연> : 0.9999999403953552
# ***2021-02-02 Cosine Similarity between <침체> & <위축> : 0.550397515296936
# ***2021-02-02 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2021-02-02 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-02-02 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-02-02 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2021-02-02 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-02-02 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-02-02 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-02-02 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2021-02-02 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-02-02 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-02-02 Cosine Similarity between <하락> & <약세> : 0.5661999583244324
# ***2021-02-03 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-02-03 Cosine Similarity between <의심> & <의심> : 0.9999999403953552
# ***2021-02-03 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-02-03 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-02-03 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-02-03 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2021-02-03 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2021-02-03 Cosine Similarity between <하락> & <약세> : 0.5661999583244324
# ***2021-02-03 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-02-03 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-02-03 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-02-03 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2021-02-03 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-02-03 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-02-03 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-02-03 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-02-03 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-02-03 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-02-03 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-02-04 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-02-04 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-02-04 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-02-04 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-02-04 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-02-04 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-02-04 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-02-04 Cosine Similarity between <조치> & <조치> : 0.9999999403953552
# ***2021-02-04 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-02-04 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-02-04 Cosine Similarity between <조치> & <조치> : 0.9999999403953552
# ***2021-02-04 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-02-05 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-02-05 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-02-05 Cosine Similarity between <악화> & <둔화> : 0.5065981149673462
# ***2021-02-05 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-02-05 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2021-02-05 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2021-02-05 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-02-05 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-02-05 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2021-02-05 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-02-05 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2021-02-05 Cosine Similarity between <조치> & <조치> : 0.9999999403953552
# ***2021-02-05 Cosine Similarity between <지연> & <지연> : 0.9999999403953552
# ***2021-02-05 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-02-05 Cosine Similarity between <하락> & <약세> : 0.5661999583244324
# ***2021-02-05 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-02-05 Cosine Similarity between <하락> & <급락> : 0.6878489851951599
# ***2021-02-05 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-02-05 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-02-05 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-02-08 Cosine Similarity between <실패> & <성공> : 0.7068130970001221
# ***2021-02-08 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-02-08 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-02-08 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-02-08 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-02-08 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-02-08 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-02-08 Cosine Similarity between <둔화> & <악화> : 0.5065981149673462
# ***2021-02-08 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-02-08 Cosine Similarity between <약화> & <악화> : 0.5064777731895447
# ***2021-02-08 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-02-08 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-02-08 Cosine Similarity between <둔화> & <위축> : 0.6352296471595764
# ***2021-02-08 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-02-08 Cosine Similarity between <약화> & <위축> : 0.5172010660171509
# ***2021-02-08 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2021-02-08 Cosine Similarity between <침체> & <위축> : 0.550397515296936
# ***2021-02-08 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-02-08 Cosine Similarity between <실패> & <성공> : 0.7068130970001221
# ***2021-02-08 Cosine Similarity between <실패> & <성공> : 0.7068130970001221
# ***2021-02-09 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-02-09 Cosine Similarity between <침체> & <호황> : 0.6176010966300964
# ***2021-02-09 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2021-02-09 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-02-15 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-02-15 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-02-15 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-02-15 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-02-15 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-02-15 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-02-15 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2021-02-15 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-02-15 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-02-15 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-02-15 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-02-15 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-02-15 Cosine Similarity between <저해> & <유발> : 0.5002310872077942
# ***2021-02-15 Cosine Similarity between <저해> & <유발> : 0.5002310872077942
# ***2021-02-16 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-02-16 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-02-16 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-02-17 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-02-17 Cosine Similarity between <여파> & <악재> : 0.5317699313163757
# ***2021-02-17 Cosine Similarity between <하락> & <주춤> : 0.5109282732009888
# ***2021-02-17 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-02-17 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-02-17 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-02-17 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-02-17 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-02-17 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-02-17 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-02-17 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-02-17 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2021-02-17 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-02-19 Cosine Similarity between <의혹> & <의혹> : 0.9999999403953552
# ***2021-02-22 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-02-22 Cosine Similarity between <실패> & <성공> : 0.7068130970001221
# ***2021-02-22 Cosine Similarity between <침체> & <폭락> : 0.5104137063026428
# ***2021-02-22 Cosine Similarity between <하락> & <폭락> : 0.5914363861083984
# ***2021-02-22 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-02-22 Cosine Similarity between <결국> & <끝내> : 0.5792427659034729
# ***2021-02-22 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-02-23 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-02-23 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-02-23 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-02-23 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-02-23 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-02-23 Cosine Similarity between <둔화> & <견조> : 0.5073744058609009
# ***2021-02-23 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-02-23 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-02-23 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-02-23 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-02-23 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-02-23 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-02-23 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-02-25 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-02-25 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2021-02-25 Cosine Similarity between <여파> & <악재> : 0.5317699313163757
# ***2021-02-25 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-02-25 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2021-02-25 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-02-25 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-02-25 Cosine Similarity between <하락> & <급락> : 0.6878489851951599
# ***2021-02-25 Cosine Similarity between <혼란> & <불안> : 0.513291597366333
# ***2021-02-25 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-02-25 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-02-25 Cosine Similarity between <둔화> & <위축> : 0.6352296471595764
# ***2021-02-25 Cosine Similarity between <둔화> & <악화> : 0.5065981149673462
# ***2021-02-25 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2021-02-25 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-02-25 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-02-25 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2021-02-25 Cosine Similarity between <약화> & <위축> : 0.5172010660171509
# ***2021-02-25 Cosine Similarity between <약화> & <악화> : 0.5064777731895447
# ***2021-02-25 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-02-25 Cosine Similarity between <침체> & <위축> : 0.550397515296936
# ***2021-02-25 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-02-25 Cosine Similarity between <하락> & <약세> : 0.5661999583244324
# ***2021-02-25 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-02-25 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-02-25 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-02-25 Cosine Similarity between <하락> & <급락> : 0.6878489851951599
# ***2021-02-25 Cosine Similarity between <침체> & <위기> : 0.507282018661499
# ***2021-02-25 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-02-25 Cosine Similarity between <침체> & <위기> : 0.507282018661499
# ***2021-02-25 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-02-25 Cosine Similarity between <침체> & <위기> : 0.507282018661499
# ***2021-02-25 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-02-25 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-02-25 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2021-02-25 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-02-25 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2021-02-26 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-02-26 Cosine Similarity between <실패> & <성공> : 0.7068130970001221
# ***2021-02-26 Cosine Similarity between <약점> & <강점> : 0.5741011500358582
# ***2021-02-26 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-02-26 Cosine Similarity between <침체> & <위기> : 0.507282018661499
# ***2021-02-26 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-02-26 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2021-02-26 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-02-26 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2021-02-26 Cosine Similarity between <침체> & <폭락> : 0.5104137063026428
# ***2021-02-26 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-02-26 Cosine Similarity between <하락> & <폭락> : 0.5914363861083984
# ***2021-02-26 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-02-26 Cosine Similarity between <하락> & <급락> : 0.6878489851951599
# ***2021-02-26 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-02-26 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-02-26 Cosine Similarity between <의혹> & <논란> : 0.5190056562423706
# ***2021-02-26 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-02-26 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-02-26 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-02-26 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-02-26 Cosine Similarity between <하락> & <등락> : 0.5736824870109558
# ***2021-02-26 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-02-26 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-02-26 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-02-26 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-02-26 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-02-26 Cosine Similarity between <침체> & <위기> : 0.507282018661499
# ***2021-02-26 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-02-26 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-02-26 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-02-26 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-03-03 Cosine Similarity between <둔화> & <업황> : 0.5578197240829468
# ***2021-03-03 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-03-03 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-03-03 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2021-03-03 Cosine Similarity between <침체> & <업황> : 0.5205410122871399
# ***2021-03-03 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-03-03 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-03-03 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-03-03 Cosine Similarity between <하락> & <급락> : 0.6878489851951599
# ***2021-03-03 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-03-03 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-03-04 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2021-03-04 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-03-04 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2021-03-04 Cosine Similarity between <하락> & <약세> : 0.5661999583244324
# ***2021-03-04 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-03-04 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-03-04 Cosine Similarity between <하락> & <급락> : 0.6878489851951599
# ***2021-03-05 Cosine Similarity between <둔화> & <견조> : 0.5073744058609009
# ***2021-03-05 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-03-05 Cosine Similarity between <실패> & <성공> : 0.7068130970001221
# ***2021-03-05 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-03-05 Cosine Similarity between <악화> & <둔화> : 0.5065981149673462
# ***2021-03-05 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2021-03-05 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2021-03-05 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-03-05 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2021-03-05 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-03-05 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2021-03-05 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-03-05 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-03-05 Cosine Similarity between <하락> & <약세> : 0.5661999583244324
# ***2021-03-05 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-03-05 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-03-05 Cosine Similarity between <하락> & <급락> : 0.6878489851951599
# ***2021-03-08 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-03-08 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-03-08 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2021-03-08 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-03-08 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-03-08 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-03-08 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-03-08 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2021-03-08 Cosine Similarity between <조치> & <조치> : 0.9999999403953552
# ***2021-03-08 Cosine Similarity between <침체> & <폭락> : 0.5104137063026428
# ***2021-03-08 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-03-08 Cosine Similarity between <하락> & <급등> : 0.6149086952209473
# ***2021-03-08 Cosine Similarity between <하락> & <폭락> : 0.5914363861083984
# ***2021-03-08 Cosine Similarity between <하락> & <폭등> : 0.5558099746704102
# ***2021-03-08 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-03-09 Cosine Similarity between <둔화> & <위축> : 0.6352296471595764
# ***2021-03-09 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-03-09 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-03-09 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-03-09 Cosine Similarity between <약화> & <위축> : 0.5172010660171509
# ***2021-03-09 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-03-09 Cosine Similarity between <의혹> & <의혹> : 0.9999999403953552
# ***2021-03-09 Cosine Similarity between <조치> & <조치> : 0.9999999403953552
# ***2021-03-09 Cosine Similarity between <침체> & <위축> : 0.550397515296936
# ***2021-03-09 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-03-09 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-03-09 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-03-09 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-03-09 Cosine Similarity between <둔화> & <악화> : 0.5065981149673462
# ***2021-03-09 Cosine Similarity between <약화> & <악화> : 0.5064777731895447
# ***2021-03-09 Cosine Similarity between <둔화> & <침체> : 0.5701860189437866
# ***2021-03-09 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-03-09 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2021-03-09 Cosine Similarity between <침체> & <침체> : 1.0000001192092896
# ***2021-03-09 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-03-09 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-03-09 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-03-09 Cosine Similarity between <하락> & <급락> : 0.6878489851951599
# ***2021-03-09 Cosine Similarity between <둔화> & <악화> : 0.5065981149673462
# ...
# ***2021-09-07 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-09-07 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-09-07 Cosine Similarity between <혼란> & <불안> : 0.513291597366333
# ***2021-09-07 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-09-07 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-09-07 Cosine Similarity between <악화> & <둔화> : 0.5065981149673462
# ***2021-09-07 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2021-09-07 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-09-07 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2021-09-07 Cosine Similarity between <하락> & <등락> : 0.5736824870109558
# ***2021-09-07 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2021-09-07 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-09-07 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-09-07 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-09-08 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-09-08 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-09-08 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2021-09-08 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-09-08 Cosine Similarity between <악화> & <둔화> : 0.5065981149673462
# ***2021-09-08 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2021-09-08 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-09-08 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2021-09-08 Cosine Similarity between <하락> & <등락> : 0.5736824870109558
# ***2021-09-08 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2021-09-08 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-09-08 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-09-08 Cosine Similarity between <하락> & <약세> : 0.5661999583244324
# ***2021-09-08 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-09-08 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-09-08 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-09-08 Cosine Similarity between <실패> & <성공> : 0.7068130970001221
# ***2021-09-08 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-09-08 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-09-08 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2021-09-08 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-09-08 Cosine Similarity between <악화> & <둔화> : 0.5065981149673462
# ***2021-09-08 Cosine Similarity between <지연> & <지연> : 0.9999999403953552
# ***2021-09-08 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2021-09-08 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-09-08 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2021-09-08 Cosine Similarity between <하락> & <등락> : 0.5736824870109558
# ***2021-09-08 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2021-09-08 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-09-08 Cosine Similarity between <하락> & <약세> : 0.5661999583244324
# ***2021-09-08 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-09-08 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-09-08 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-09-08 Cosine Similarity between <둔화> & <견조> : 0.5073744058609009
# ***2021-09-08 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-09-08 Cosine Similarity between <악화> & <둔화> : 0.5065981149673462
# ***2021-09-08 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2021-09-08 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-09-08 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2021-09-08 Cosine Similarity between <하락> & <등락> : 0.5736824870109558
# ***2021-09-08 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2021-09-08 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-09-08 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-09-08 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-09-08 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-09-08 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2021-09-08 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-09-08 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2021-09-08 Cosine Similarity between <악화> & <둔화> : 0.5065981149673462
# ***2021-09-08 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2021-09-08 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-09-08 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2021-09-08 Cosine Similarity between <하락> & <등락> : 0.5736824870109558
# ***2021-09-08 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2021-09-08 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-09-08 Cosine Similarity between <하락> & <약세> : 0.5661999583244324
# ***2021-09-08 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-09-08 Cosine Similarity between <하락> & <급락> : 0.6878489851951599
# ***2021-09-09 Cosine Similarity between <둔화> & <위축> : 0.6352296471595764
# ***2021-09-09 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-09-09 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-09-09 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2021-09-09 Cosine Similarity between <악화> & <둔화> : 0.5065981149673462
# ***2021-09-09 Cosine Similarity between <약화> & <위축> : 0.5172010660171509
# ***2021-09-09 Cosine Similarity between <약화> & <강화> : 0.5141976475715637
# ***2021-09-09 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2021-09-09 Cosine Similarity between <침체> & <위축> : 0.550397515296936
# ***2021-09-09 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-09-09 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2021-09-09 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2021-09-09 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-09-09 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-09-09 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-09-09 Cosine Similarity between <하락> & <급락> : 0.6878489851951599
# ***2021-09-10 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-09-10 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-09-10 Cosine Similarity between <악화> & <둔화> : 0.5065981149673462
# ***2021-09-10 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2021-09-10 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-09-10 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2021-09-10 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2021-09-10 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-09-10 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-09-10 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-09-10 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-09-10 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-09-10 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2021-09-10 Cosine Similarity between <악화> & <둔화> : 0.5065981149673462
# ***2021-09-10 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2021-09-10 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-09-10 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2021-09-10 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2021-09-10 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-09-10 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-09-10 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-09-10 Cosine Similarity between <하락> & <급락> : 0.6878489851951599
# ***2021-09-10 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-09-10 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-09-10 Cosine Similarity between <악화> & <둔화> : 0.5065981149673462
# ***2021-09-10 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2021-09-10 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-09-10 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2021-09-10 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2021-09-10 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-09-10 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-09-10 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-09-13 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-09-13 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-09-13 Cosine Similarity between <둔화> & <급락> : 0.5491443276405334
# ***2021-09-13 Cosine Similarity between <악화> & <둔화> : 0.5065981149673462
# ***2021-09-13 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2021-09-13 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-09-13 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2021-09-13 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2021-09-13 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-09-13 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-09-13 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-09-13 Cosine Similarity between <하락> & <급락> : 0.6878489851951599
# ***2021-09-13 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-09-13 Cosine Similarity between <둔화> & <증가> : 0.5041859745979309
# ***2021-09-13 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2021-09-13 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-09-13 Cosine Similarity between <악화> & <둔화> : 0.5065981149673462
# ***2021-09-13 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2021-09-13 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-09-13 Cosine Similarity between <침체> & <호황> : 0.6176010966300964
# ***2021-09-13 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2021-09-13 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2021-09-13 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-09-13 Cosine Similarity between <하락> & <증가> : 0.553473711013794
# ***2021-09-13 Cosine Similarity between <하락> & <약세> : 0.5661999583244324
# ***2021-09-13 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-09-13 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-09-13 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-09-13 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2021-09-13 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-09-13 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-09-13 Cosine Similarity between <악화> & <둔화> : 0.5065981149673462
# ***2021-09-13 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-09-13 Cosine Similarity between <여파> & <악재> : 0.5317699313163757
# ***2021-09-13 Cosine Similarity between <저해> & <유발> : 0.5002310872077942
# ***2021-09-13 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2021-09-13 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-09-13 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2021-09-13 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2021-09-13 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-09-13 Cosine Similarity between <하락> & <약세> : 0.5661999583244324
# ***2021-09-13 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-09-13 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-09-13 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-09-13 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-09-13 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2021-09-13 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-09-13 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-09-13 Cosine Similarity between <악화> & <약화> : 0.5064777731895447
# ***2021-09-13 Cosine Similarity between <악화> & <둔화> : 0.5065981149673462
# ***2021-09-13 Cosine Similarity between <약화> & <약화> : 0.9999999403953552
# ***2021-09-13 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-09-13 Cosine Similarity between <저해> & <유발> : 0.5002310872077942
# ***2021-09-13 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2021-09-13 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-09-13 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2021-09-13 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2021-09-13 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-09-13 Cosine Similarity between <하락> & <약세> : 0.5661999583244324
# ***2021-09-13 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-09-13 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-09-13 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-09-14 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-09-14 Cosine Similarity between <둔화> & <약세> : 0.5189449787139893
# ***2021-09-14 Cosine Similarity between <둔화> & <감소> : 0.5349085330963135
# ***2021-09-14 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-09-14 Cosine Similarity between <악화> & <약화> : 0.5064777731895447
# ***2021-09-14 Cosine Similarity between <악화> & <둔화> : 0.5065981149673462
# ***2021-09-14 Cosine Similarity between <약화> & <약화> : 0.9999999403953552
# ***2021-09-14 Cosine Similarity between <약화> & <감소> : 0.5511848330497742
# ***2021-09-14 Cosine Similarity between <저해> & <유발> : 0.5002310872077942
# ***2021-09-14 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2021-09-14 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-09-14 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2021-09-14 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-09-14 Cosine Similarity between <하락> & <약세> : 0.5661999583244324
# ***2021-09-14 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-09-14 Cosine Similarity between <하락> & <감소> : 0.5759893655776978
# ***2021-09-14 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-09-14 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-09-14 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-09-14 Cosine Similarity between <악화> & <둔화> : 0.5065981149673462
# ***2021-09-14 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2021-09-14 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-09-14 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2021-09-14 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-09-14 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-09-14 Cosine Similarity between <하락> & <하락> : 0.9999999403953552
# ***2021-09-15 Cosine Similarity between <둔화> & <반등> : 0.5092458724975586
# ***2021-09-15 Cosine Similarity between <둔화> & <하락> : 0.5260781049728394
# ***2021-09-15 Cosine Similarity between <악화> & <둔화> : 0.5065981149673462
# ***2021-09-15 Cosine Similarity between <침체> & <둔화> : 0.5701860189437866
# ***2021-09-15 Cosine Similarity between <침체> & <경기> : 0.5360626578330994
# ***2021-09-15 Cosine Similarity between <하락> & <보합> : 0.6176052689552307
# ***2021-09-15 Cosine Similarity between <하락> & <둔화> : 0.5260781049728394
# ***2021-09-15 Cosine Similarity between <하락> & <반등> : 0.5754541158676147
# ***2021-09-15 Cosine Similarity between <하락> & <주춤> : 0.5109282732009888
# ***2021-09-15 Cosine Similarity between <하락> & <상승> : 0.7126480340957642
# ***2021-09-15 Cosine Similarity between <하락> & <하락> : 0.9999999403953552

# %%
neg_lexicon_2021
# Out:
#             date news_num KOSELF_neg_word news_word  cosine_similarity  \
# 0     2021-01-04        1              둔화        하락           0.526078
# 1     2021-01-04        1              둔화        급락           0.549144
# 2     2021-01-04        1              하락        상승           0.712648
# 3     2021-01-04        1              하락        하락           1.000000
# 4     2021-01-04        1              하락        급락           0.687849
# ...          ...      ...             ...       ...                ...
# 9261  2021-09-15     1299              하락        둔화           0.526078
# 9262  2021-09-15     1299              하락        반등           0.575454
# 9263  2021-09-15     1299              하락        주춤           0.510928
# 9264  2021-09-15     1299              하락        상승           0.712648
# 9265  2021-09-15     1299              하락        하락           1.000000
#
#      frequency
# 0            2
# 1            2
# 2            3
# 3            2
# 4            2
# ...        ...
# 9261         2
# 9262         1
# 9263         1
# 9264         9
# 9265         7
#
# [9266 rows x 6 columns]

# %%
neg_lexicon_2021.to_csv('../../../../Code/Data/Test/Stock-Year/neg_celltrion_2021.csv', index=False)

# %%
a = list(set(list(neg_lexicon_2021['news_word'])))

a
# Out:
# ['지연',
#  '위기',
#  '조아연',
#  '견조',
#  '주춤',
#  '참패',
#  '조치',
#  '불안',
#  '선박',
#  '급등',
#  '차량',
#  '정체',
#  '호전',
#  '의심',
#  '화물',
#  '특혜',
#  '급감',
#  '감소',
#  '증가',
#  '논란',
#  '등락',
#  '보상',
#  '호황',
#  '업황',
#  '의혹',
#  '혼돈',
#  '안트로젠안트로젠',
#  '유발',
#  '약화',
#  '침체',
#  '경기',
#  '하락',
#  '강화',
#  '부도',
#  '끝내',
#  '폭락',
#  '위축',
#  '둔화',
#  '플러스',
#  '약세',
#  '반등',
#  '강점',
#  '급락',
#  '연루',
#  '저하',
#  '좌절',
#  '폭등',
#  '스탁액티브',
#  '악화',
#  '악재',
#  '보합',
#  '성공',
#  '손해배상',
#  '상승']

# %%
b = list(set(list(neg_lexicon_2021[neg_lexicon_2021['cosine_similarity']>=0.7]['news_word'])))

b
# Out:
# ['지연', '약화', '침체', '조치', '하락', '정체', '의심', '의혹', '성공', '상승']

# %%
c = list(set(list(neg_lexicon_2021[neg_lexicon_2021['cosine_similarity']>=0.65]['news_word'])))

c
# Out:
# ['지연', '급락', '약화', '침체', '조치', '하락', '정체', '의심', '의혹', '성공', '상승']
