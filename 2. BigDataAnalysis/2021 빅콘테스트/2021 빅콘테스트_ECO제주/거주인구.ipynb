# %% [markdown]
# # **거주인구 EDA**

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import font_manager, rc
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = True
import seaborn as sns

import datetime

import warnings
warnings.filterwarnings('ignore')
# pd.set_option('display.max_rows', None)

# %%
pop = pd.read_csv('../../../../../Source/2021 빅콘테스트/2021 빅콘테스트_ECO제주/01_제공데이터_update(210811)/03_거주인구_RESIDENT_POP.csv', encoding='cp949')
pop['base_year_month'] = pop['base_year'].astype(str) + '년 ' + pop['base_month'].astype(str) + '월'   # 이렇게 하면 오름차순 정렬 시 1월보다 10월이 먼저 나타남

pop
# Out:
#       base_year  base_month  city    emd_cd emd_nm sex  resid_reg_pop  \
# 0          2018           1   제주시  50110590    건입동  남성           5085
# 1          2018           1   제주시  50110590    건입동  여성           4715
# 2          2018           1   제주시  50110256    구좌읍  남성           7965
# 3          2018           1   제주시  50110256    구좌읍  여성           7609
# 4          2018           1  서귀포시  50130253    남원읍  남성           9806
# ...         ...         ...   ...       ...    ...  ..            ...
# 3607       2021           6   제주시  50110250    한림읍  여성          10341
# 3608       2021           6   제주시  50110600    화북동  남성          12062
# 3609       2021           6   제주시  50110600    화북동  여성          12238
# 3610       2021           6  서귀포시  50130550    효돈동  남성           2660
# 3611       2021           6  서귀포시  50130550    효돈동  여성           2597
#
#       foreign_pop  total_pop base_year_month
# 0             146       5231        2018년 1월
# 1              82       4797        2018년 1월
# 2             368       8333        2018년 1월
# 3             184       7793        2018년 1월
# 4             428      10234        2018년 1월
# ...           ...        ...             ...
# 3607         1140      11481        2021년 6월
# 3608          169      12231        2021년 6월
# 3609          161      12399        2021년 6월
# 3610           39       2699        2021년 6월
# 3611           18       2615        2021년 6월
#
# [3612 rows x 10 columns]

# %% [markdown]
# ## **연도별 구분**

# %%
# 연도별 구분
pop_2018 = pop[pop['base_year']==2018]
pop_2019 = pop[pop['base_year']==2019]
pop_2020 = pop[pop['base_year']==2020]
pop_2021 = pop[pop['base_year']==2021]

pop_2018
# Out:
#       base_year  base_month  city    emd_cd emd_nm sex  resid_reg_pop  \
# 0          2018           1   제주시  50110590    건입동  남성           5085
# 1          2018           1   제주시  50110590    건입동  여성           4715
# 2          2018           1   제주시  50110256    구좌읍  남성           7965
# 3          2018           1   제주시  50110256    구좌읍  여성           7609
# 4          2018           1  서귀포시  50130253    남원읍  남성           9806
# ...         ...         ...   ...       ...    ...  ..            ...
# 1027       2018          12   제주시  50110250    한림읍  여성          10319
# 1028       2018          12   제주시  50110600    화북동  남성          12458
# 1029       2018          12   제주시  50110600    화북동  여성          12527
# 1030       2018          12  서귀포시  50130550    효돈동  남성           2683
# 1031       2018          12  서귀포시  50130550    효돈동  여성           2595
#
#       foreign_pop  total_pop base_year_month
# 0             146       5231        2018년 1월
# 1              82       4797        2018년 1월
# 2             368       8333        2018년 1월
# 3             184       7793        2018년 1월
# 4             428      10234        2018년 1월
# ...           ...        ...             ...
# 1027         1347      11666       2018년 12월
# 1028          228      12686       2018년 12월
# 1029          178      12705       2018년 12월
# 1030           57       2740       2018년 12월
# 1031           30       2625       2018년 12월
#
# [1032 rows x 10 columns]

# %%
# 2021년은 6개월까지만
pop_2021
# Out:
#       base_year  base_month  city    emd_cd emd_nm sex  resid_reg_pop  \
# 3096       2021           1   제주시  50110590    건입동  남성           4610
# 3097       2021           1   제주시  50110590    건입동  여성           4432
# 3098       2021           1   제주시  50110256    구좌읍  남성           7970
# 3099       2021           1   제주시  50110256    구좌읍  여성           7542
# 3100       2021           1  서귀포시  50130253    남원읍  남성           9689
# ...         ...         ...   ...       ...    ...  ..            ...
# 3607       2021           6   제주시  50110250    한림읍  여성          10341
# 3608       2021           6   제주시  50110600    화북동  남성          12062
# 3609       2021           6   제주시  50110600    화북동  여성          12238
# 3610       2021           6  서귀포시  50130550    효돈동  남성           2660
# 3611       2021           6  서귀포시  50130550    효돈동  여성           2597
#
#       foreign_pop  total_pop base_year_month
# 3096          149       4759        2021년 1월
# 3097           88       4520        2021년 1월
# 3098          409       8379        2021년 1월
# 3099          178       7720        2021년 1월
# 3100          463      10152        2021년 1월
# ...           ...        ...             ...
# 3607         1140      11481        2021년 6월
# 3608          169      12231        2021년 6월
# 3609          161      12399        2021년 6월
# 3610           39       2699        2021년 6월
# 3611           18       2615        2021년 6월
#
# [516 rows x 10 columns]

# %%
# 행정동별 인구
pop_2018_dong = (pop_2018.groupby('emd_nm')['resid_reg_pop', 'foreign_pop', 'total_pop'].sum() / 12).reset_index()   # 12개월
pop_2019_dong = (pop_2019.groupby('emd_nm')['resid_reg_pop', 'foreign_pop', 'total_pop'].sum() / 12).reset_index()   # 12개월
pop_2020_dong = (pop_2020.groupby('emd_nm')['resid_reg_pop', 'foreign_pop', 'total_pop'].sum() / 12).reset_index()   # 12개월
pop_2021_dong = (pop_2021.groupby('emd_nm')['resid_reg_pop', 'foreign_pop', 'total_pop'].sum() / 6).reset_index()    # 6개월

pop_2018_dong
# Out:
#    emd_nm  resid_reg_pop  foreign_pop     total_pop
# 0     건입동    9749.750000   243.416667   9993.166667
# 1     구좌읍   15647.916667   585.416667  16233.333333
# 2     남원읍   19156.750000   680.833333  19837.583333
# 3     노형동   53596.333333  1950.000000  55546.333333
# 4     대륜동   13777.166667   187.500000  13964.666667
# 5     대정읍   21290.583333  1600.500000  22891.083333
# 6     대천동   13445.250000   245.833333  13691.083333
# 7     도두동    3060.750000   124.333333   3185.083333
# 8     동홍동   22779.583333  1258.166667  24037.750000
# 9     봉개동    4086.750000    81.583333   4168.333333
# 10   삼도1동   14309.083333   209.166667  14518.250000
# 11   삼도2동    8562.166667   251.500000   8813.666667
# 12    삼양동   24407.000000   248.416667  24655.416667
# 13    서홍동   10631.333333   125.000000  10756.333333
# 14    성산읍   15464.583333  1642.083333  17106.666667
# 15    송산동    4429.083333   556.416667   4985.500000
# 16    아라동   32203.166667  1107.666667  33310.833333
# 17    안덕면   11731.333333   610.000000  12341.333333
# 18    애월읍   34882.750000  1038.666667  35921.416667
# 19     연동   41464.833333  1713.916667  43178.750000
# 20    영천동    5218.000000   181.000000   5399.000000
# 21    예래동    4041.583333   204.833333   4246.416667
# 22    오라동   14183.083333   211.000000  14394.083333
# 23    외도동   21190.333333   284.666667  21475.000000
# 24   용담1동    7652.083333    84.500000   7736.583333
# 25   용담2동   15560.833333   231.083333  15791.916667
# 26    우도면    1870.833333    35.500000   1906.333333
# 27   이도1동    7893.416667   126.750000   8020.166667
# 28   이도2동   49810.666667   633.250000  50443.916667
# 29    이호동    4360.000000   146.916667   4506.916667
# 30   일도1동    2960.416667   100.916667   3061.333333
# 31   일도2동   34763.250000   288.416667  35051.666667
# 32    정방동    2394.583333   106.750000   2501.333333
# 33    조천읍   23811.500000   569.750000  24381.250000
# 34    중문동   10979.583333   295.083333  11274.666667
# 35    중앙동    3932.416667   106.833333   4039.250000
# 36    천지동    3555.000000   106.500000   3661.500000
# 37    추자면    1831.666667   347.000000   2178.666667
# 38    표선면   12340.166667   420.750000  12760.916667
# 39    한경면    9047.083333   337.500000   9384.583333
# 40    한림읍   21113.250000  3634.500000  24747.750000
# 41    화북동   25047.500000   382.166667  25429.666667
# 42    효돈동    5316.083333    82.833333   5398.916667

# %%
pop_2018_dong.to_csv('2018년 행정동별 거주인구.csv', index=False)
pop_2019_dong.to_csv('2019년 행정동별 거주인구.csv', index=False)
pop_2020_dong.to_csv('2020년 행정동별 거주인구.csv', index=False)
pop_2021_dong.to_csv('2021년 행정동별 거주인구.csv', index=False)

# %% [markdown]
# **'음식 관련 카드 소비.ipynb'에서 이어서 EDA 진행**

# %% [markdown]
# ## **월/행정동별 거주인구 변동 추이**

# %%
pop_month_dong = pop.sort_values(by=['emd_nm', 'base_year', 'base_month']).reset_index(drop=True)

pop_month_dong
# Out:
#       base_year  base_month  city    emd_cd emd_nm sex  resid_reg_pop  \
# 0          2018           1   제주시  50110590    건입동  남성           5085
# 1          2018           1   제주시  50110590    건입동  여성           4715
# 2          2018           2   제주시  50110590    건입동  남성           5090
# 3          2018           2   제주시  50110590    건입동  여성           4724
# 4          2018           3   제주시  50110590    건입동  남성           5072
# ...         ...         ...   ...       ...    ...  ..            ...
# 3607       2021           4  서귀포시  50130550    효돈동  여성           2607
# 3608       2021           5  서귀포시  50130550    효돈동  남성           2661
# 3609       2021           5  서귀포시  50130550    효돈동  여성           2605
# 3610       2021           6  서귀포시  50130550    효돈동  남성           2660
# 3611       2021           6  서귀포시  50130550    효돈동  여성           2597
#
#       foreign_pop  total_pop base_year_month
# 0             146       5231        2018년 1월
# 1              82       4797        2018년 1월
# 2             142       5232        2018년 2월
# 3              82       4806        2018년 2월
# 4             141       5213        2018년 3월
# ...           ...        ...             ...
# 3607           19       2626        2021년 4월
# 3608           41       2702        2021년 5월
# 3609           19       2624        2021년 5월
# 3610           39       2699        2021년 6월
# 3611           18       2615        2021년 6월
#
# [3612 rows x 10 columns]

# %%
sns.pairplot(pop_month_dong[['resid_reg_pop', 'foreign_pop', 'total_pop', 'base_year']], hue='base_year', palette='husl')
plt.show()

# %%
# 남성 거주인구 DataFrame
pop_month_dong_male = pop_month_dong[pop_month_dong['sex']=='남성'].reset_index(drop=True)

pop_month_dong_male
# Out:
#       base_year  base_month  city    emd_cd emd_nm sex  resid_reg_pop  \
# 0          2018           1   제주시  50110590    건입동  남성           5085
# 1          2018           2   제주시  50110590    건입동  남성           5090
# 2          2018           3   제주시  50110590    건입동  남성           5072
# 3          2018           4   제주시  50110590    건입동  남성           5070
# 4          2018           5   제주시  50110590    건입동  남성           5070
# ...         ...         ...   ...       ...    ...  ..            ...
# 1801       2021           2  서귀포시  50130550    효돈동  남성           2673
# 1802       2021           3  서귀포시  50130550    효돈동  남성           2653
# 1803       2021           4  서귀포시  50130550    효돈동  남성           2660
# 1804       2021           5  서귀포시  50130550    효돈동  남성           2661
# 1805       2021           6  서귀포시  50130550    효돈동  남성           2660
#
#       foreign_pop  total_pop base_year_month
# 0             146       5231        2018년 1월
# 1             142       5232        2018년 2월
# 2             141       5213        2018년 3월
# 3             143       5213        2018년 4월
# 4             148       5218        2018년 5월
# ...           ...        ...             ...
# 1801           44       2717        2021년 2월
# 1802           41       2694        2021년 3월
# 1803           40       2700        2021년 4월
# 1804           41       2702        2021년 5월
# 1805           39       2699        2021년 6월
#
# [1806 rows x 10 columns]

# %%
# 여성 거주인구 DataFrame
pop_month_dong_female = pop_month_dong[pop_month_dong['sex']=='여성'].reset_index(drop=True)

pop_month_dong_female
# Out:
#       base_year  base_month  city    emd_cd emd_nm sex  resid_reg_pop  \
# 0          2018           1   제주시  50110590    건입동  여성           4715
# 1          2018           2   제주시  50110590    건입동  여성           4724
# 2          2018           3   제주시  50110590    건입동  여성           4711
# 3          2018           4   제주시  50110590    건입동  여성           4718
# 4          2018           5   제주시  50110590    건입동  여성           4730
# ...         ...         ...   ...       ...    ...  ..            ...
# 1801       2021           2  서귀포시  50130550    효돈동  여성           2616
# 1802       2021           3  서귀포시  50130550    효돈동  여성           2609
# 1803       2021           4  서귀포시  50130550    효돈동  여성           2607
# 1804       2021           5  서귀포시  50130550    효돈동  여성           2605
# 1805       2021           6  서귀포시  50130550    효돈동  여성           2597
#
#       foreign_pop  total_pop base_year_month
# 0              82       4797        2018년 1월
# 1              82       4806        2018년 2월
# 2              81       4792        2018년 3월
# 3              86       4804        2018년 4월
# 4              90       4820        2018년 5월
# ...           ...        ...             ...
# 1801           21       2637        2021년 2월
# 1802           20       2629        2021년 3월
# 1803           19       2626        2021년 4월
# 1804           19       2624        2021년 5월
# 1805           18       2615        2021년 6월
#
# [1806 rows x 10 columns]

# %%
# 남성+여성 거주인구 DataFrame
# pop_month_dong_total = pd.merge(pop_month_dong_male, pop_month_dong_female, how='left', left_on='base_year_month', right_on='base_year_month')
pop_month_dong_total = pop_month_dong_male
pop_month_dong_total['sex'] = '남성+여성'
pop_month_dong_total['resid_reg_pop'] = pop_month_dong_male['resid_reg_pop'] + pop_month_dong_female['resid_reg_pop']
pop_month_dong_total['foreign_pop'] = pop_month_dong_male['foreign_pop'] + pop_month_dong_female['foreign_pop']
pop_month_dong_total['total_pop'] = pop_month_dong_male['total_pop'] + pop_month_dong_female['total_pop']

pop_month_dong_total
# Out:
#       base_year  base_month  city    emd_cd emd_nm    sex  resid_reg_pop  \
# 0          2018           1   제주시  50110590    건입동  남성+여성           9800
# 1          2018           2   제주시  50110590    건입동  남성+여성           9814
# 2          2018           3   제주시  50110590    건입동  남성+여성           9783
# 3          2018           4   제주시  50110590    건입동  남성+여성           9788
# 4          2018           5   제주시  50110590    건입동  남성+여성           9800
# ...         ...         ...   ...       ...    ...    ...            ...
# 1801       2021           2  서귀포시  50130550    효돈동  남성+여성           5289
# 1802       2021           3  서귀포시  50130550    효돈동  남성+여성           5262
# 1803       2021           4  서귀포시  50130550    효돈동  남성+여성           5267
# 1804       2021           5  서귀포시  50130550    효돈동  남성+여성           5266
# 1805       2021           6  서귀포시  50130550    효돈동  남성+여성           5257
#
#       foreign_pop  total_pop base_year_month
# 0             228      10028        2018년 1월
# 1             224      10038        2018년 2월
# 2             222      10005        2018년 3월
# 3             229      10017        2018년 4월
# 4             238      10038        2018년 5월
# ...           ...        ...             ...
# 1801           65       5354        2021년 2월
# 1802           61       5323        2021년 3월
# 1803           59       5326        2021년 4월
# 1804           60       5326        2021년 5월
# 1805           57       5314        2021년 6월
#
# [1806 rows x 10 columns]

# %%
pop_month_dong_total.to_csv('2018~2021년 행정동-월별 거주인구.csv', index=False)

# %%
pop_month_total = pop_month_dong_total.groupby('base_year_month').sum()

# %%
plt.figure(figsize=(18, 3))
# sns.set(rc={'figure.figsize':(18, 3)})   # 한글 깨짐

sns.lineplot(data=pop_month_total, x='base_year_month', y='resid_reg_pop')
# sns.lineplot(data=pop_month_total, x='base_year_month', y='foreign_pop')
sns.lineplot(data=pop_month_total, x='base_year_month', y='total_pop')
plt.xticks(rotation=45)
plt.ylabel('거주인구')
plt.title('제주도 전체 거주인구 변동 추이')
# plt.legend(labels=['주민등록 거주인구', '외국인 거주인구', '총 거주인구'])
plt.legend(labels=['주민등록 거주인구', '총 거주인구'])

plt.show()

# %%
### 뒤에 초록색으로 나오는 영역은 뭐지...? ###

# %% [markdown]
# **전체 비율로 볼 때 수가 적은 외국인 거주인구는 쓰레기 배출량에 큰 영향을 미치지 않을 것으로 생각**

# %%
# 행정동 리스트
dong_list = list(pop.emd_nm.unique())

dong_list
# Out:
# ['건입동',
#  '구좌읍',
#  '남원읍',
#  '노형동',
#  '대륜동',
#  '대정읍',
#  '대천동',
#  '도두동',
#  '동홍동',
#  '봉개동',
#  '삼도1동',
#  '삼도2동',
#  '삼양동',
#  '서홍동',
#  '성산읍',
#  '송산동',
#  '아라동',
#  '안덕면',
#  '애월읍',
#  '연동',
#  '영천동',
#  '예래동',
#  '오라동',
#  '외도동',
#  '용담1동',
#  '용담2동',
#  '우도면',
#  '이도1동',
#  '이도2동',
#  '이호동',
#  '일도1동',
#  '일도2동',
#  '정방동',
#  '조천읍',
#  '중문동',
#  '중앙동',
#  '천지동',
#  '추자면',
#  '표선면',
#  '한경면',
#  '한림읍',
#  '화북동',
#  '효돈동']

# %%
for i in range(len(dong_list)):
    dong = dong_list[i]
    
    plt.figure(figsize=(18, 3))
    
    sns.lineplot(data=pop_month_dong_total[i*42:i*42+42], x='base_year_month', y='resid_reg_pop')
    # sns.lineplot(data=pop_month_dong_total[i*42:i*42+42], x='base_year_month', y='foreign_pop')   # 외국인 거주인구는 그래프에서 제외
    sns.lineplot(data=pop_month_dong_total[i*42:i*42+42], x='base_year_month', y='total_pop')
    plt.xticks(rotation=45)
    plt.ylabel('거주인구')
    plt.title(dong + ' ' + '거주인구 변동 추이')
    plt.legend(labels=['주민등록 거주인구', '총 거주인구'])
    
    plt.show()

# %% [markdown]
# **<span style="color:orange">행정동별로 거주인구 증가 or 감소 여부 확인해서 분석 적용할 방법 고려</span>**
