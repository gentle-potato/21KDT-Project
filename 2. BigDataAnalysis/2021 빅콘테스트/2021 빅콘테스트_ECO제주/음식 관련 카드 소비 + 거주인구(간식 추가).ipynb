# %% [markdown]
# # **음식 관련 카드 소비 + 거주인구 EDA**

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import font_manager, rc
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = True
import seaborn as sns

import datetime

import warnings
warnings.filterwarnings('ignore')
# pd.set_option('display.max_rows', None)

# %%
food = pd.read_csv('../../../../../Source/2021 빅콘테스트/2021 빅콘테스트_ECO제주/01_제공데이터_update(210811)/04_음식관련 카드소비_CARD_SPENDING_encoded.csv')

food
# Out:
#          base_date  city    emd_cd emd_nm mct_cat_cd mct_cat_nm  use_cnt  \
# 0       2018-01-06   제주시  50110650     연동     C00100         한식     3643
# 1       2018-01-09   제주시  50110650     연동     C00500      패스트푸드      432
# 2       2018-01-15   제주시  50110650     연동     C01200      농축수산물      236
# 3       2018-01-15   제주시  50110650     연동     A00200    마트/슈퍼마켓     4031
# 4       2018-01-20   제주시  50110650     연동     C01000         식품      633
# ...            ...   ...       ...    ...        ...        ...      ...
# 544800  2020-10-16   제주시  XXXXXXXX   알수없음     C01400         배달        5
# 544801  2019-08-31  서귀포시  XXXXXXXX   알수없음     C01400         배달        5
# 544802  2020-10-03  서귀포시  XXXXXXXX   알수없음     C01400         배달       10
# 544803  2020-10-23  서귀포시  XXXXXXXX   알수없음     C01400         배달        5
# 544804  2020-12-21   제주시  XXXXXXXX   알수없음     C01400         배달       10
#
#           use_amt
# 0       127777300
# 1         6711675
# 2        16089579
# 3       121979867
# 4        30410674
# ...           ...
# 544800     127250
# 544801      39974
# 544802     329832
# 544803      68715
# 544804     187452
#
# [544805 rows x 8 columns]

# %%
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 544805 entries, 0 to 544804
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   base_date   544805 non-null  object
#  1   city        544805 non-null  object
#  2   emd_cd      544805 non-null  object
#  3   emd_nm      544805 non-null  object
#  4   mct_cat_cd  544805 non-null  object
#  5   mct_cat_nm  544805 non-null  object
#  6   use_cnt     544805 non-null  int64
#  7   use_amt     544805 non-null  int64
# dtypes: int64(2), object(6)
# memory usage: 33.3+ MB

# %%
type(food['base_date'][0])
# Out:
# str

# %%
food['base_date'] = pd.to_datetime(food['base_date'])

# %%
food.sort_values(by=['base_date', 'emd_nm'], inplace=True)
food.reset_index(drop=True, inplace=True)
food['year'] = food['base_date'].dt.year
food['month'] = food['base_date'].dt.month
food['day'] = food['base_date'].dt.day

food
# Out:
#         base_date  city    emd_cd emd_nm mct_cat_cd mct_cat_nm  use_cnt  \
# 0      2018-01-01   제주시  50110590    건입동     C00400         간식       79
# 1      2018-01-01   제주시  50110590    건입동     C00500      패스트푸드       93
# 2      2018-01-01   제주시  50110590    건입동     C01200      농축수산물       34
# 3      2018-01-01   제주시  50110590    건입동     A00200    마트/슈퍼마켓      589
# 4      2018-01-01   제주시  50110590    건입동     C00300      아시아음식       44
# ...           ...   ...       ...    ...        ...        ...      ...
# 544800 2021-06-30  서귀포시  50130550    효돈동     C01200      농축수산물       45
# 544801 2021-06-30  서귀포시  50130550    효돈동     C00100         한식      106
# 544802 2021-06-30  서귀포시  50130550    효돈동     C00300      아시아음식       25
# 544803 2021-06-30  서귀포시  50130550    효돈동     C00500      패스트푸드       30
# 544804 2021-06-30  서귀포시  50130550    효돈동     C01400         배달       15
#
#          use_amt  year  month  day
# 0         927990  2018      1    1
# 1        1802952  2018      1    1
# 2        1824556  2018      1    1
# 3       19891147  2018      1    1
# 4        1836340  2018      1    1
# ...          ...   ...    ...  ...
# 544800   4366442  2021      6   30
# 544801   2370891  2021      6   30
# 544802    596055  2021      6   30
# 544803    507024  2021      6   30
# 544804    291740  2021      6   30
#
# [544805 rows x 11 columns]

# %%
# 음식점 쓰레기는 분석에서 제외 → ['마트/슈퍼마켓', '식품', '농축수산물', '배달', '간식'] 5개만 남기고 제거
food.drop(food[food['mct_cat_nm']=='한식'].index, inplace=True)
food.drop(food[food['mct_cat_nm']=='패스트푸드'].index, inplace=True)
food.drop(food[food['mct_cat_nm']=='아시아음식'].index, inplace=True)
food.drop(food[food['mct_cat_nm']=='양식'].index, inplace=True)
food.drop(food[food['mct_cat_nm']=='주점및주류판매'].index, inplace=True)
food.drop(food[food['mct_cat_nm']=='부페'].index, inplace=True)

food
# Out:
#         base_date  city    emd_cd emd_nm mct_cat_cd mct_cat_nm  use_cnt  \
# 0      2018-01-01   제주시  50110590    건입동     C00400         간식       79
# 2      2018-01-01   제주시  50110590    건입동     C01200      농축수산물       34
# 3      2018-01-01   제주시  50110590    건입동     A00200    마트/슈퍼마켓      589
# 7      2018-01-01   제주시  50110590    건입동     C01000         식품      152
# 9      2018-01-01   제주시  50110590    건입동     C01400         배달        5
# ...           ...   ...       ...    ...        ...        ...      ...
# 544796 2021-06-30  서귀포시  50130550    효돈동     C01000         식품      151
# 544797 2021-06-30  서귀포시  50130550    효돈동     A00200    마트/슈퍼마켓      322
# 544798 2021-06-30  서귀포시  50130550    효돈동     C00400         간식       15
# 544800 2021-06-30  서귀포시  50130550    효돈동     C01200      농축수산물       45
# 544804 2021-06-30  서귀포시  50130550    효돈동     C01400         배달       15
#
#          use_amt  year  month  day
# 0         927990  2018      1    1
# 2        1824556  2018      1    1
# 3       19891147  2018      1    1
# 7        6831676  2018      1    1
# 9          54010  2018      1    1
# ...          ...   ...    ...  ...
# 544796   7113275  2021      6   30
# 544797  15563575  2021      6   30
# 544798    122229  2021      6   30
# 544800   4366442  2021      6   30
# 544804    291740  2021      6   30
#
# [274337 rows x 11 columns]

# %%
sns.pairplot(food[food['mct_cat_nm']=='간식'][['use_cnt', 'use_amt', 'year']], hue='year', palette='rainbow')
plt.title('간식')
plt.show()

# %%
sns.pairplot(food[food['mct_cat_nm']=='배달'][['use_cnt', 'use_amt', 'year']], hue='year', palette='rainbow')
plt.title('배달')
plt.show()

# %%
sns.pairplot(food[food['mct_cat_nm']=='마트/슈퍼마켓'][['use_cnt', 'use_amt', 'year']], hue='year', palette='rainbow')
plt.title('마트/슈퍼마켓')
plt.show()

# %%
sns.pairplot(food[food['mct_cat_nm']=='농축수산물'][['use_cnt', 'use_amt', 'year']], hue='year', palette='rainbow')
plt.title('농축수산물')
plt.show()

# %%
sns.pairplot(food[food['mct_cat_nm']=='식품'][['use_cnt', 'use_amt', 'year']], hue='year', palette='rainbow')
plt.title('식품')
plt.show()

# %% [markdown]
# ## **결제금액/건수 기준**

# %%
food['mct_cat_nm'].value_counts()
# Out:
# 마트/슈퍼마켓    57451
# 식품         56154
# 간식         55398
# 농축수산물      53569
# 배달         51765
# Name: mct_cat_nm, dtype: int64

# %%
category_amt = food.groupby('mct_cat_nm').sum().sort_values(by='use_amt', ascending=False)

category_amt
# Out:
#              use_cnt        use_amt       year   month     day
# mct_cat_nm
# 마트/슈퍼마켓     54032048  1860801386448  116009901  350161  902794
# 식품          17890849   685085950757  113391074  342232  882461
# 농축수산물        5269514   351475488512  108171323  326987  842504
# 배달           7392467   170647358144  104532172  317320  815390
# 간식          12226585   144865710255  111864351  337426  870622

# %%
category_cnt = food.groupby('mct_cat_nm').sum().sort_values(by='use_cnt', ascending=False)

category_cnt
# Out:
#              use_cnt        use_amt       year   month     day
# mct_cat_nm
# 마트/슈퍼마켓     54032048  1860801386448  116009901  350161  902794
# 식품          17890849   685085950757  113391074  342232  882461
# 간식          12226585   144865710255  111864351  337426  870622
# 배달           7392467   170647358144  104532172  317320  815390
# 농축수산물        5269514   351475488512  108171323  326987  842504

# %% [markdown]
# ## **행정동 기준**

# %%
food['emd_nm'].value_counts()
# Out:
# 알수없음    7989
# 노형동     6385
# 연동      6385
# 일도2동    6385
# 아라동     6385
# 화북동     6385
# 삼양동     6385
# 이도2동    6385
# 건입동     6384
# 동홍동     6384
# 용담2동    6384
# 삼도1동    6384
# 애월읍     6383
# 이도1동    6382
# 삼도2동    6382
# 외도동     6379
# 한림읍     6377
# 대천동     6376
# 대륜동     6375
# 대정읍     6374
# 조천읍     6372
# 오라동     6372
# 남원읍     6356
# 서홍동     6353
# 용담1동    6348
# 성산읍     6339
# 중문동     6334
# 안덕면     6313
# 표선면     6301
# 구좌읍     6270
# 일도1동    6263
# 한경면     6234
# 효돈동     6199
# 중앙동     6179
# 도두동     6173
# 송산동     6158
# 천지동     6157
# 이호동     6062
# 봉개동     6033
# 예래동     6033
# 영천동     6018
# 정방동     5971
# 우도면     4205
# 추자면     4046
# Name: emd_nm, dtype: int64

# %% [markdown]
# ***'알수없음'은 어떻게 처리? → <span style="color:red">제거 X</span>***

# %%
dong = food.groupby(['emd_nm', 'mct_cat_nm']).sum()

dong
# Out:
#                    use_cnt      use_amt     year  month    day
# emd_nm mct_cat_nm
# 건입동    간식           193332   2323951584  2578626   7783  20067
#        농축수산물         90610   8451532877  2578626   7783  20067
#        마트/슈퍼마켓      775608  25330854527  2578626   7783  20067
#        배달           118563   2754741956  2576608   7782  20065
#        식품           366413  16938141302  2578626   7783  20067
# ...                    ...          ...      ...    ...    ...
# 효돈동    간식            53249    617233645  2576608   7781  20051
#        농축수산물         29262   2252161588  2429250   7368  18938
#        마트/슈퍼마켓      358954  16255030677  2578626   7783  20067
#        배달            20875    415120299  2354588   7231  18341
#        식품           134649   3900833040  2578626   7783  20067
#
# [220 rows x 5 columns]

# %%
dong['use_cnt']
# Out:
# emd_nm  mct_cat_nm
# 건입동     간식            193332
#         농축수산물          90610
#         마트/슈퍼마켓       775608
#         배달            118563
#         식품            366413
#                        ...
# 효돈동     간식             53249
#         농축수산물          29262
#         마트/슈퍼마켓       358954
#         배달             20875
#         식품            134649
# Name: use_cnt, Length: 220, dtype: int64

# %%
dong.index[0]
# Out:
# ('건입동', '간식')

# %%
# 테스트
p = max(dong['use_cnt'])
print(dong[(dong['use_cnt']==p)==True])
# Out:
#                    use_cnt       use_amt     year  month    day
# emd_nm mct_cat_nm
# 노형동    마트/슈퍼마켓     6266351  196141268135  2578626   7783  20067

# %%
# # 업종 분류가 동별로 5개씩이므로
# for i in range(len(food['emd_nm'].value_counts())):
#     maximum = max(dong['use_cnt'][i*5:i*5+5])
#     print(dong[(dong['use_cnt']==maximum)==True])

# %% [markdown]
# **모든 행정동에서 마트/슈퍼마켓이 가장 큼...**

# %%
# 행정동/업종별 결제건수 순위
# 업종 분류가 동별로 5개씩이므로
for i in range(len(food['emd_nm'].value_counts())):
    rank = dong['use_cnt'][i*5:i*5+5].nlargest(5)
    print(rank)
    print('========================================')
# Out:
# emd_nm  mct_cat_nm
# 건입동     마트/슈퍼마켓       775608
#         식품            366413
#         간식            193332
#         배달            118563
#         농축수산물          90610
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 구좌읍     마트/슈퍼마켓       570964
#         식품            445599
#         간식            110244
#         농축수산물          88806
#         배달             38622
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 남원읍     마트/슈퍼마켓       653626
#         식품            435936
#         간식            135366
#         농축수산물          80559
#         배달             50853
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 노형동     마트/슈퍼마켓       6266351
#         식품            1652260
#         간식            1430565
#         배달            1056361
#         농축수산물          476695
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 대륜동     마트/슈퍼마켓       1162733
#         식품             257131
#         간식             249021
#         배달             131648
#         농축수산물           66412
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 대정읍     마트/슈퍼마켓       1466190
#         식품             434911
#         간식             405706
#         농축수산물          100086
#         배달              90319
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 대천동     마트/슈퍼마켓       1203750
#         간식             289251
#         식품             218691
#         배달             144599
#         농축수산물           56773
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 도두동     마트/슈퍼마켓       278481
#         식품             74702
#         간식             45998
#         배달             30427
#         농축수산물          21800
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 동홍동     마트/슈퍼마켓       2505186
#         식품             384810
#         간식             369443
#         배달             224064
#         농축수산물          124502
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 봉개동     마트/슈퍼마켓       292700
#         식품             88230
#         간식             62134
#         농축수산물          31994
#         배달             28421
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 삼도1동    마트/슈퍼마켓       1559852
#         식품             308432
#         간식             274713
#         배달             180698
#         농축수산물          109532
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 삼도2동    마트/슈퍼마켓       765075
#         식품            234436
#         간식            149204
#         배달            115764
#         농축수산물          77577
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 삼양동     마트/슈퍼마켓       1983855
#         농축수산물          553864
#         간식             530014
#         식품             499747
#         배달             325655
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 서홍동     마트/슈퍼마켓       1138697
#         간식             181693
#         식품             136251
#         배달              97980
#         농축수산물           75776
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 성산읍     마트/슈퍼마켓       759446
#         식품            309137
#         간식            112639
#         배달             51460
#         농축수산물          50840
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 송산동     마트/슈퍼마켓       321574
#         식품             53144
#         간식             49014
#         농축수산물          39507
#         배달             29209
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 아라동     마트/슈퍼마켓       2857914
#         간식             840702
#         식품             802236
#         배달             431700
#         농축수산물          349413
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 안덕면     마트/슈퍼마켓       512781
#         식품            341159
#         간식            144422
#         농축수산물          46452
#         배달             43241
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 알수없음    마트/슈퍼마켓       97207
#         식품            16941
#         간식            15909
#         배달             8761
#         농축수산물          6085
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 애월읍     마트/슈퍼마켓       1656703
#         식품            1380291
#         간식             489821
#         배달             210567
#         농축수산물          128345
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 연동      마트/슈퍼마켓       4778002
#         식품            1177387
#         배달            1018833
#         간식            1002186
#         농축수산물          285650
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 영천동     마트/슈퍼마켓       475466
#         식품             93782
#         간식             61892
#         농축수산물          27538
#         배달             24708
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 예래동     마트/슈퍼마켓       237303
#         식품            102521
#         간식             46965
#         배달             32227
#         농축수산물          13095
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 오라동     마트/슈퍼마켓       1487404
#         식품             442887
#         간식             307675
#         배달             165131
#         농축수산물          101248
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 외도동     마트/슈퍼마켓       2488452
#         식품             565090
#         간식             473216
#         배달             247142
#         농축수산물          100652
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 용담1동    마트/슈퍼마켓       686507
#         식품            162882
#         간식            118190
#         농축수산물          81873
#         배달             71544
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 용담2동    마트/슈퍼마켓       1648572
#         식품             309010
#         간식             276497
#         배달             177179
#         농축수산물          163366
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 우도면     마트/슈퍼마켓       57050
#         식품            27348
#         간식             6110
#         농축수산물          4429
#         배달             2780
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 이도1동    마트/슈퍼마켓       826808
#         식품            201850
#         간식            187968
#         배달            145836
#         농축수산물          91710
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 이도2동    마트/슈퍼마켓       4541070
#         식품            1469938
#         간식            1182374
#         배달             825944
#         농축수산물          669412
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 이호동     마트/슈퍼마켓       358083
#         식품            123086
#         간식             61768
#         배달             31657
#         농축수산물          21484
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 일도1동    마트/슈퍼마켓       247527
#         식품            118962
#         간식             55501
#         배달             37440
#         농축수산물          36880
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 일도2동    마트/슈퍼마켓       2626050
#         식품            1145376
#         간식             762761
#         배달             435088
#         농축수산물          333199
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 정방동     마트/슈퍼마켓       185788
#         간식             30209
#         식품             25497
#         농축수산물          20468
#         배달             20400
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 조천읍     식품            1142379
#         마트/슈퍼마켓       1056202
#         간식             352367
#         농축수산물          130152
#         배달             120005
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 중문동     마트/슈퍼마켓       631843
#         식품            435098
#         간식            171322
#         배달             95638
#         농축수산물          33667
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 중앙동     마트/슈퍼마켓       302898
#         간식             50986
#         식품             44360
#         농축수산물          43988
#         배달             26192
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 천지동     마트/슈퍼마켓       307214
#         식품             48224
#         간식             47012
#         농축수산물          34950
#         배달             31409
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 추자면     마트/슈퍼마켓       45573
#         식품             8466
#         배달             6564
#         간식             4831
#         농축수산물          4015
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 표선면     마트/슈퍼마켓       484665
#         식품            295028
#         간식             91298
#         농축수산물          50327
#         배달             43438
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 한경면     마트/슈퍼마켓       328307
#         식품            215862
#         간식             55290
#         농축수산물          26613
#         배달             19062
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 한림읍     마트/슈퍼마켓       867429
#         식품            611081
#         간식            213936
#         배달            105693
#         농축수산물          71038
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 화북동     마트/슈퍼마켓       2176188
#         식품             549629
#         간식             533791
#         농축수산물          318870
#         배달             278770
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 효돈동     마트/슈퍼마켓       358954
#         식품            134649
#         간식             53249
#         농축수산물          29262
#         배달             20875
# Name: use_cnt, dtype: int64
# ========================================

# %%
# 행정동/업종별 결제금액 순위
# 업종 분류가 동별로 5개씩이므로
for i in range(len(food['emd_nm'].value_counts())):
    rank = dong['use_cnt'][i*5:i*5+5].nlargest(5)
    print(rank)
    print('========================================')
# Out:
# emd_nm  mct_cat_nm
# 건입동     마트/슈퍼마켓       775608
#         식품            366413
#         간식            193332
#         배달            118563
#         농축수산물          90610
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 구좌읍     마트/슈퍼마켓       570964
#         식품            445599
#         간식            110244
#         농축수산물          88806
#         배달             38622
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 남원읍     마트/슈퍼마켓       653626
#         식품            435936
#         간식            135366
#         농축수산물          80559
#         배달             50853
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 노형동     마트/슈퍼마켓       6266351
#         식품            1652260
#         간식            1430565
#         배달            1056361
#         농축수산물          476695
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 대륜동     마트/슈퍼마켓       1162733
#         식품             257131
#         간식             249021
#         배달             131648
#         농축수산물           66412
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 대정읍     마트/슈퍼마켓       1466190
#         식품             434911
#         간식             405706
#         농축수산물          100086
#         배달              90319
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 대천동     마트/슈퍼마켓       1203750
#         간식             289251
#         식품             218691
#         배달             144599
#         농축수산물           56773
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 도두동     마트/슈퍼마켓       278481
#         식품             74702
#         간식             45998
#         배달             30427
#         농축수산물          21800
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 동홍동     마트/슈퍼마켓       2505186
#         식품             384810
#         간식             369443
#         배달             224064
#         농축수산물          124502
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 봉개동     마트/슈퍼마켓       292700
#         식품             88230
#         간식             62134
#         농축수산물          31994
#         배달             28421
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 삼도1동    마트/슈퍼마켓       1559852
#         식품             308432
#         간식             274713
#         배달             180698
#         농축수산물          109532
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 삼도2동    마트/슈퍼마켓       765075
#         식품            234436
#         간식            149204
#         배달            115764
#         농축수산물          77577
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 삼양동     마트/슈퍼마켓       1983855
#         농축수산물          553864
#         간식             530014
#         식품             499747
#         배달             325655
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 서홍동     마트/슈퍼마켓       1138697
#         간식             181693
#         식품             136251
#         배달              97980
#         농축수산물           75776
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 성산읍     마트/슈퍼마켓       759446
#         식품            309137
#         간식            112639
#         배달             51460
#         농축수산물          50840
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 송산동     마트/슈퍼마켓       321574
#         식품             53144
#         간식             49014
#         농축수산물          39507
#         배달             29209
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 아라동     마트/슈퍼마켓       2857914
#         간식             840702
#         식품             802236
#         배달             431700
#         농축수산물          349413
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 안덕면     마트/슈퍼마켓       512781
#         식품            341159
#         간식            144422
#         농축수산물          46452
#         배달             43241
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 알수없음    마트/슈퍼마켓       97207
#         식품            16941
#         간식            15909
#         배달             8761
#         농축수산물          6085
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 애월읍     마트/슈퍼마켓       1656703
#         식품            1380291
#         간식             489821
#         배달             210567
#         농축수산물          128345
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 연동      마트/슈퍼마켓       4778002
#         식품            1177387
#         배달            1018833
#         간식            1002186
#         농축수산물          285650
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 영천동     마트/슈퍼마켓       475466
#         식품             93782
#         간식             61892
#         농축수산물          27538
#         배달             24708
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 예래동     마트/슈퍼마켓       237303
#         식품            102521
#         간식             46965
#         배달             32227
#         농축수산물          13095
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 오라동     마트/슈퍼마켓       1487404
#         식품             442887
#         간식             307675
#         배달             165131
#         농축수산물          101248
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 외도동     마트/슈퍼마켓       2488452
#         식품             565090
#         간식             473216
#         배달             247142
#         농축수산물          100652
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 용담1동    마트/슈퍼마켓       686507
#         식품            162882
#         간식            118190
#         농축수산물          81873
#         배달             71544
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 용담2동    마트/슈퍼마켓       1648572
#         식품             309010
#         간식             276497
#         배달             177179
#         농축수산물          163366
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 우도면     마트/슈퍼마켓       57050
#         식품            27348
#         간식             6110
#         농축수산물          4429
#         배달             2780
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 이도1동    마트/슈퍼마켓       826808
#         식품            201850
#         간식            187968
#         배달            145836
#         농축수산물          91710
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 이도2동    마트/슈퍼마켓       4541070
#         식품            1469938
#         간식            1182374
#         배달             825944
#         농축수산물          669412
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 이호동     마트/슈퍼마켓       358083
#         식품            123086
#         간식             61768
#         배달             31657
#         농축수산물          21484
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 일도1동    마트/슈퍼마켓       247527
#         식품            118962
#         간식             55501
#         배달             37440
#         농축수산물          36880
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 일도2동    마트/슈퍼마켓       2626050
#         식품            1145376
#         간식             762761
#         배달             435088
#         농축수산물          333199
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 정방동     마트/슈퍼마켓       185788
#         간식             30209
#         식품             25497
#         농축수산물          20468
#         배달             20400
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 조천읍     식품            1142379
#         마트/슈퍼마켓       1056202
#         간식             352367
#         농축수산물          130152
#         배달             120005
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 중문동     마트/슈퍼마켓       631843
#         식품            435098
#         간식            171322
#         배달             95638
#         농축수산물          33667
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 중앙동     마트/슈퍼마켓       302898
#         간식             50986
#         식품             44360
#         농축수산물          43988
#         배달             26192
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 천지동     마트/슈퍼마켓       307214
#         식품             48224
#         간식             47012
#         농축수산물          34950
#         배달             31409
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 추자면     마트/슈퍼마켓       45573
#         식품             8466
#         배달             6564
#         간식             4831
#         농축수산물          4015
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 표선면     마트/슈퍼마켓       484665
#         식품            295028
#         간식             91298
#         농축수산물          50327
#         배달             43438
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 한경면     마트/슈퍼마켓       328307
#         식품            215862
#         간식             55290
#         농축수산물          26613
#         배달             19062
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 한림읍     마트/슈퍼마켓       867429
#         식품            611081
#         간식            213936
#         배달            105693
#         농축수산물          71038
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 화북동     마트/슈퍼마켓       2176188
#         식품             549629
#         간식             533791
#         농축수산물          318870
#         배달             278770
# Name: use_cnt, dtype: int64
# ========================================
# emd_nm  mct_cat_nm
# 효돈동     마트/슈퍼마켓       358954
#         식품            134649
#         간식             53249
#         농축수산물          29262
#         배달             20875
# Name: use_cnt, dtype: int64
# ========================================

# %% [markdown]
# ## **(종합) 연도/행정동별 결제건수/금액 기준**

# %%
# 연도별 구분
food_2018 = food[food['year']==2018]
food_2019 = food[food['year']==2019]
food_2020 = food[food['year']==2020]
food_2021 = food[food['year']==2021]

food_2018
# Out:
#         base_date  city    emd_cd emd_nm mct_cat_cd mct_cat_nm  use_cnt  \
# 0      2018-01-01   제주시  50110590    건입동     C00400         간식       79
# 2      2018-01-01   제주시  50110590    건입동     C01200      농축수산물       34
# 3      2018-01-01   제주시  50110590    건입동     A00200    마트/슈퍼마켓      589
# 7      2018-01-01   제주시  50110590    건입동     C01000         식품      152
# 9      2018-01-01   제주시  50110590    건입동     C01400         배달        5
# ...           ...   ...       ...    ...        ...        ...      ...
# 154621 2018-12-31  서귀포시  50130550    효돈동     C01200      농축수산물       20
# 154625 2018-12-31  서귀포시  50130550    효돈동     C01000         식품      136
# 154627 2018-12-31  서귀포시  50130550    효돈동     C00400         간식       70
# 154628 2018-12-31  서귀포시  50130550    효돈동     A00200    마트/슈퍼마켓      372
# 154630 2018-12-31  서귀포시  50130550    효돈동     C01400         배달       15
#
#          use_amt  year  month  day
# 0         927990  2018      1    1
# 2        1824556  2018      1    1
# 3       19891147  2018      1    1
# 7        6831676  2018      1    1
# 9          54010  2018      1    1
# ...          ...   ...    ...  ...
# 154621    985880  2018     12   31
# 154625   4229526  2018     12   31
# 154627   1222290  2018     12   31
# 154628  13304803  2018     12   31
# 154630    407430  2018     12   31
#
# [76527 rows x 11 columns]

# %%
# 업종/행정동별 분류
food_2018 = food_2018.groupby(['mct_cat_nm', 'emd_nm'])['use_cnt', 'use_amt'].sum()
food_2019 = food_2019.groupby(['mct_cat_nm', 'emd_nm'])['use_cnt', 'use_amt'].sum()
food_2020 = food_2020.groupby(['mct_cat_nm', 'emd_nm'])['use_cnt', 'use_amt'].sum()
food_2021 = food_2021.groupby(['mct_cat_nm', 'emd_nm'])['use_cnt', 'use_amt'].sum()

food_2018
# Out:
#                    use_cnt     use_amt
# mct_cat_nm emd_nm
# 간식         건입동       55554   669086962
#            구좌읍       27843   361778890
#            남원읍       36355   436121088
#            노형동      415604  4816143812
#            대륜동       68101   784500411
# ...                    ...         ...
# 식품         표선면       80350  2880753611
#            한경면       54895  1816853036
#            한림읍      152233  6531878869
#            화북동      140728  5947012629
#            효돈동       31051   813512211
#
# [220 rows x 2 columns]

# %% [markdown]
# ### **① 간식**

# %%
# 간식 소비
food_2018_간식 = food_2018[:44].reset_index()
food_2019_간식 = food_2019[:44].reset_index()
food_2020_간식 = food_2020[:44].reset_index()
food_2021_간식 = food_2021[:44].reset_index()

food_2018_간식.tail()
# Out:
#    mct_cat_nm emd_nm  use_cnt     use_amt
# 39         간식    표선면    24304   300987456
# 40         간식    한경면    13565   175478215
# 41         간식    한림읍    58083   755196279
# 42         간식    화북동   160793  1869797828
# 43         간식    효돈동    14400   168480308

# %%
# 연도/행정동별 결제건수 비교
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2018_간식, x='emd_nm', y='use_cnt')
plt.title('2018년 행정동별 간식 결제건수')
plt.ylim(0, 420000)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2019_간식, x='emd_nm', y='use_cnt')
plt.title('2019년 행정동별 간식 결제건수')
plt.ylim(0, 420000)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2020_간식, x='emd_nm', y='use_cnt')
plt.title('2020년 행정동별 간식 결제건수')
plt.ylim(0, 420000)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2021_간식, x='emd_nm', y='use_cnt')
plt.title('2021년 행정동별 간식 결제건수')
plt.ylim(0, 420000)
plt.xticks(rotation=90)
plt.show()

# %%
# 연도/행정동별 결제금액 비교
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2018_간식, x='emd_nm', y='use_amt')
plt.title('2018년 행정동별 간식 결제금액')
plt.ylim(0, 5*1e9)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2019_간식, x='emd_nm', y='use_amt')
plt.title('2019년 행정동별 간식 결제금액')
plt.ylim(0, 5*1e9)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2020_간식, x='emd_nm', y='use_amt')
plt.title('2020년 행정동별 간식 결제금액')
plt.ylim(0, 5*1e9)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2021_간식, x='emd_nm', y='use_amt')
plt.title('2021년 행정동별 간식 결제금액')
plt.ylim(0, 5*1e9)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### **② 농축수산물**

# %%
# 농축수산물 소비
food_2018_농축 = food_2018[44:88].reset_index()
food_2019_농축 = food_2019[44:88].reset_index()
food_2020_농축 = food_2020[44:88].reset_index()
food_2021_농축 = food_2021[44:88].reset_index()

food_2018_농축.tail()
# Out:
#    mct_cat_nm emd_nm  use_cnt     use_amt
# 39      농축수산물    표선면    13531  2130352875
# 40      농축수산물    한경면     6060   635625965
# 41      농축수산물    한림읍    18000  2121137722
# 42      농축수산물    화북동    78000  4097640697
# 43      농축수산물    효돈동     4434   394512547

# %%
# 연도/행정동별 결제건수 비교
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2018_농축, x='emd_nm', y='use_cnt')
plt.title('2018년 행정동별 농축수산물 결제건수')
plt.ylim(0, 225000)
plt.xticks(rotation=90)
plt.show()

# %%
# plt.figure(figsize=(16, 4))
# sns.barplot(data=food_2019_농축, x='emd_nm', y='use_cnt')
# plt.title('2019년 행정동별 농축수산물 결제건수')
# plt.ylim(0, 225000)
# plt.xticks(rotation=90)
# plt.show()

# %%
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2020_농축, x='emd_nm', y='use_cnt')
plt.title('2020년 행정동별 농축수산물 결제건수')
plt.ylim(0, 225000)
plt.xticks(rotation=90)
plt.show()

# %%
# plt.figure(figsize=(16, 4))
# sns.barplot(data=food_2021_농축, x='emd_nm', y='use_cnt')
# plt.title('2021년 행정동별 농축수산물 결제건수')
# plt.ylim(0, 225000)
# plt.xticks(rotation=90)
# plt.show()

# %% [markdown]
# **많은 농축수산물 결제건수가 발생하는 행정동은 ['노형동', '삼양동', '이도2동']<br>
# +) <span style="color:blue">코로나19 상황에도 불구하고 2020년의 결제건수가 가장 많음</span> → 해외여행 불가로 대신 제주도로?!<br>
# ++) <span style="color:red">2021년은 6개월 동안의 데이터만 있음에도 불구하고 2020년과 비슷한 양상</span>**

# %%
# 연도/행정동별 결제금액 비교
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2018_농축, x='emd_nm', y='use_amt')
plt.title('2018년 행정동별 농축수산물 결제금액')
plt.ylim(0, 9*1e9)
plt.xticks(rotation=90)
plt.show()

# %%
# plt.figure(figsize=(16, 4))
# sns.barplot(data=food_2019_농축, x='emd_nm', y='use_amt')
# plt.title('2019년 행정동별 농축수산물 결제금액')
# plt.ylim(0, 9*1e9)
# plt.xticks(rotation=90)
# plt.show()

# %%
# plt.figure(figsize=(16, 4))
# sns.barplot(data=food_2020_농축, x='emd_nm', y='use_amt')
# plt.title('2020년 행정동별 농축수산물 결제금액')
# plt.ylim(0, 9*1e9)
# plt.xticks(rotation=90)
# plt.show()

# %%
# plt.figure(figsize=(16, 4))
# sns.barplot(data=food_2021_농축, x='emd_nm', y='use_amt')
# plt.title('2021년 행정동별 농축수산물 결제금액')
# plt.ylim(0, 9*1e9)
# plt.xticks(rotation=90)
# plt.show()

# %% [markdown]
# **결제금액 기준으로 보면 ['연동', '일도2동', '화북동']이 추가로 결제금액이 많은 지역으로 나타나고, 연도마다 큰 차이는 없음**

# %% [markdown]
# ### **③ 마트/슈퍼마켓**

# %%
# 마트/슈퍼마켓 소비
food_2018_마트 = food_2018[88:132].reset_index()
food_2019_마트 = food_2019[88:132].reset_index()
food_2020_마트 = food_2020[88:132].reset_index()
food_2021_마트 = food_2021[88:132].reset_index()

food_2019_마트.tail()
# Out:
#    mct_cat_nm emd_nm  use_cnt      use_amt
# 39    마트/슈퍼마켓    표선면   134462   5131580320
# 40    마트/슈퍼마켓    한경면    95697   3661382980
# 41    마트/슈퍼마켓    한림읍   249593   9603000638
# 42    마트/슈퍼마켓    화북동   623857  16900617539
# 43    마트/슈퍼마켓    효돈동   103199   4688664450

# %%
# 연도/행정동별 결제건수 비교
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2018_마트, x='emd_nm', y='use_cnt')
plt.title('2018년 행정동별 마트/슈퍼마켓 결제건수')
plt.ylim(0, 2*1e6)
plt.xticks(rotation=90)
plt.show()

# %%
# plt.figure(figsize=(16, 4))
# sns.barplot(data=food_2019_마트, x='emd_nm', y='use_cnt')
# plt.title('2019년 행정동별 마트/슈퍼마켓 결제건수')
# plt.ylim(0, 2*1e6)
# plt.xticks(rotation=90)
# plt.show()

# %%
# plt.figure(figsize=(16, 4))
# sns.barplot(data=food_2020_마트, x='emd_nm', y='use_cnt')
# plt.title('2020년 행정동별 마트/슈퍼마켓 결제건수')
# plt.ylim(0, 2*1e6)
# plt.xticks(rotation=90)
# plt.show()

# %%
# plt.figure(figsize=(16, 4))
# sns.barplot(data=food_2021_마트, x='emd_nm', y='use_cnt')
# plt.title('2021년 행정동별 마트/슈퍼마켓 결제건수')
# plt.ylim(0, 2*1e6)
# plt.xticks(rotation=90)
# plt.show()

# %% [markdown]
# **많은 마트/슈퍼마켓 결제건수가 발생하는 행정동은 ['노형동', '연동', '이도2동']**

# %%
# 연도/행정동별 결제금액 비교
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2018_마트, x='emd_nm', y='use_amt')
plt.title('2018년 행정동별 마트 결제금액')
plt.ylim(0, 6*1e10)
plt.xticks(rotation=90)
plt.show()

# %%
# plt.figure(figsize=(16, 4))
# sns.barplot(data=food_2019_마트, x='emd_nm', y='use_amt')
# plt.title('2019년 행정동별 마트 결제금액')
# plt.ylim(0, 6*1e10)
# plt.xticks(rotation=90)
# plt.show()

# %%
# plt.figure(figsize=(16, 4))
# sns.barplot(data=food_2020_마트, x='emd_nm', y='use_amt')
# plt.title('2020년 행정동별 마트 결제금액')
# plt.ylim(0, 6*1e10)
# plt.xticks(rotation=90)
# plt.show()

# %%
# plt.figure(figsize=(16, 4))
# sns.barplot(data=food_2021_마트, x='emd_nm', y='use_amt')
# plt.title('2021년 행정동별 마트 결제금액')
# plt.ylim(0, 6*1e10)
# plt.xticks(rotation=90)
# plt.show()

# %% [markdown]
# **결제건수와 마찬가지로 ['노형동', '연동', '이도2동']이 결제금액이 많은 지역으로 나타나고, 연도마다 큰 차이는 없음**

# %% [markdown]
# ### **④ 배달**

# %%
# 배달 소비
food_2018_배달 = food_2018[132:176].reset_index()
food_2019_배달 = food_2019[132:176].reset_index()
food_2020_배달 = food_2020[132:176].reset_index()
food_2021_배달 = food_2021[132:176].reset_index()

food_2020_배달.tail()
# Out:
#    mct_cat_nm emd_nm  use_cnt     use_amt
# 39         배달    표선면    17024   382618802
# 40         배달    한경면     6783   146881069
# 41         배달    한림읍    41423   943855026
# 42         배달    화북동   114937  2712294851
# 43         배달    효돈동     6069   126242832

# %%
# 연도/행정동별 결제건수 비교
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2018_배달, x='emd_nm', y='use_cnt')
plt.title('2018년 행정동별 배달 결제건수')
plt.ylim(0, 450000)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2019_배달, x='emd_nm', y='use_cnt')
plt.title('2019년 행정동별 배달 결제건수')
plt.ylim(0, 450000)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2020_배달, x='emd_nm', y='use_cnt')
plt.title('2020년 행정동별 배달 결제건수')
plt.ylim(0, 450000)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2021_배달, x='emd_nm', y='use_cnt')
plt.title('2021년 행정동별 배달 결제건수')
plt.ylim(0, 450000)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **많은 배달 결제건수가 발생하는 행정동은 ['노형동', '연동', '이도2동']<br>
# +) <span style="color:red">해를 거듭할수록 배달 결제건수가 급증</span> → <span style="color:orange">분석할 때 고려해야할 듯</span>**

# %%
# 연도/행정동별 결제금액 비교
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2018_배달, x='emd_nm', y='use_amt')
plt.title('2018년 행정동별 배달 결제금액')
plt.ylim(0, 1.2*1e10)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2019_배달, x='emd_nm', y='use_amt')
plt.title('2019년 행정동별 배달 결제금액')
plt.ylim(0, 1.2*1e10)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2020_배달, x='emd_nm', y='use_amt')
plt.title('2020년 행정동별 배달 결제금액')
plt.ylim(0, 1.2*1e10)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2021_배달, x='emd_nm', y='use_amt')
plt.title('2021년 행정동별 배달 결제금액')
plt.ylim(0, 1.2*1e10)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **결제건수와 마찬가지로 ['노형동', '연동', '이도2동']이 결제금액이 많은 지역으로 나타나고, <span style="color:red">연도마다 급증</span>**

# %% [markdown]
# ### **⑤ 식품**

# %%
# 식품 소비
food_2018_식품 = food_2018[176:].reset_index()
food_2019_식품 = food_2019[176:].reset_index()
food_2020_식품 = food_2020[176:].reset_index()
food_2021_식품 = food_2021[176:].reset_index()

food_2021_식품.tail()
# Out:
#    mct_cat_nm emd_nm  use_cnt     use_amt
# 39         식품    표선면    42746  1483662889
# 40         식품    한경면    33249  1196127164
# 41         식품    한림읍    86049  3829216319
# 42         식품    화북동    80326  3431403956
# 43         식품    효돈동    24983   724432165

# %%
# 연도/행정동별 결제건수 비교
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2018_식품, x='emd_nm', y='use_cnt')
plt.title('2018년 행정동별 식품 결제건수')
plt.ylim(0, 550000)
plt.xticks(rotation=90)
plt.show()

# %%
# plt.figure(figsize=(16, 4))
# sns.barplot(data=food_2019_식품, x='emd_nm', y='use_cnt')
# plt.title('2019년 행정동별 식품 결제건수')
# plt.ylim(0, 550000)
# plt.xticks(rotation=90)
# plt.show()

# %%
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2020_식품, x='emd_nm', y='use_cnt')
plt.title('2020년 행정동별 식품 결제건수')
plt.ylim(0, 550000)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2021_식품, x='emd_nm', y='use_cnt')
plt.title('2021년 행정동별 식품 결제건수')
plt.ylim(0, 550000)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **많은 식품 결제건수가 발생하는 행정동은 ['노형동', '애월읍', '연동', '이도2동']<br>
# +) <span style="color:blue">2020년에 식품 결제건수가 어느 정도 증가했고, 이도2동의 경우 더욱 증가가 두드러짐</span>**

# %%
# 연도/행정동별 결제금액 비교
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2018_식품, x='emd_nm', y='use_amt')
plt.title('2018년 행정동별 식품 결제금액')
plt.ylim(0, 2*1e10)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2019_식품, x='emd_nm', y='use_amt')
plt.title('2019년 행정동별 식품 결제금액')
plt.ylim(0, 2*1e10)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2020_식품, x='emd_nm', y='use_amt')
plt.title('2020년 행정동별 식품 결제금액')
plt.ylim(0, 2*1e10)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(16, 4))
sns.barplot(data=food_2021_식품, x='emd_nm', y='use_amt')
plt.title('2021년 행정동별 식품 결제금액')
plt.ylim(0, 2*1e10)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **결제금액이 많은 지역은 ['노형동', '애월읍', '연동', '이도2동'], <span style="color:red">연도마다 조금씩 증가</span><br>
# +) <span style="color:green">2021년은 2020년과 비슷한 양상</span>**

# %% [markdown]
# ## **거주인구 데이터와 통합**

# %%
pop_2018_dong = pd.read_csv('2018년 행정동별 거주인구.csv')
pop_2019_dong = pd.read_csv('2019년 행정동별 거주인구.csv')
pop_2020_dong = pd.read_csv('2020년 행정동별 거주인구.csv')
pop_2021_dong = pd.read_csv('2021년 행정동별 거주인구.csv')

pop_2018_dong.tail()
# Out:
#    emd_nm  resid_reg_pop  foreign_pop     total_pop
# 38    표선면   12340.166667   420.750000  12760.916667
# 39    한경면    9047.083333   337.500000   9384.583333
# 40    한림읍   21113.250000  3634.500000  24747.750000
# 41    화북동   25047.500000   382.166667  25429.666667
# 42    효돈동    5316.083333    82.833333   5398.916667

# %%
# 행정동별 거주인구 데이터에는 '알수없음'이 없으므로 DataFrame 통합을 위해서 제거
food_2018_농축_pop = food_2018_농축[food_2018_농축['emd_nm']!='알수없음'].reset_index().drop('index', axis=1)

food_2018_농축_pop.tail()
# Out:
#    mct_cat_nm emd_nm  use_cnt     use_amt
# 38      농축수산물    표선면    13531  2130352875
# 39      농축수산물    한경면     6060   635625965
# 40      농축수산물    한림읍    18000  2121137722
# 41      농축수산물    화북동    78000  4097640697
# 42      농축수산물    효돈동     4434   394512547

# %%
# Merge 농축수산물 DataFrame
농축_2018 = pd.merge(food_2018_농축, pop_2018_dong, how='inner')
농축_2019 = pd.merge(food_2019_농축, pop_2019_dong, how='inner')
농축_2020 = pd.merge(food_2020_농축, pop_2020_dong, how='inner')
농축_2021 = pd.merge(food_2021_농축, pop_2021_dong, how='inner')

농축_2018
# Out:
#    mct_cat_nm emd_nm  use_cnt     use_amt  resid_reg_pop  foreign_pop  \
# 0       농축수산물    건입동    24604  2299389020    9749.750000   243.416667
# 1       농축수산물    구좌읍    23102  1438780972   15647.916667   585.416667
# 2       농축수산물    남원읍    18629  1836648037   19156.750000   680.833333
# 3       농축수산물    노형동   108442  7384786702   53596.333333  1950.000000
# 4       농축수산물    대륜동    18330  1628893752   13777.166667   187.500000
# 5       농축수산물    대정읍    26015  1948735809   21290.583333  1600.500000
# 6       농축수산물    대천동    14906  1238548288   13445.250000   245.833333
# 7       농축수산물    도두동     4800  1006448371    3060.750000   124.333333
# 8       농축수산물    동홍동    33330  2818955193   22779.583333  1258.166667
# 9       농축수산물    봉개동     6575   555950587    4086.750000    81.583333
# 10      농축수산물   삼도1동    27132  1930356445   14309.083333   209.166667
# 11      농축수산물   삼도2동    20830  1613369597    8562.166667   251.500000
# 12      농축수산물    삼양동   116921  4232525818   24407.000000   248.416667
# 13      농축수산물    서홍동    19740  1459710295   10631.333333   125.000000
# 14      농축수산물    성산읍    12606  1574693712   15464.583333  1642.083333
# 15      농축수산물    송산동     9213   950998787    4429.083333   556.416667
# 16      농축수산물    아라동    95903  3643085785   32203.166667  1107.666667
# 17      농축수산물    안덕면    10543   762985474   11731.333333   610.000000
# 18      농축수산물    애월읍    30686  2695386994   34882.750000  1038.666667
# 19      농축수산물     연동    75772  6653295132   41464.833333  1713.916667
# 20      농축수산물    영천동     5579   584431184    5218.000000   181.000000
# 21      농축수산물    예래동     3703   574262363    4041.583333   204.833333
# 22      농축수산물    오라동    28217  1468870561   14183.083333   211.000000
# 23      농축수산물    외도동    24650  1551297455   21190.333333   284.666667
# 24      농축수산물   용담1동    21069  1241774728    7652.083333    84.500000
# 25      농축수산물   용담2동    48447  4370733304   15560.833333   231.083333
# 26      농축수산물    우도면     1754   176391219    1870.833333    35.500000
# 27      농축수산물   이도1동    21899  1337651993    7893.416667   126.750000
# 28      농축수산물   이도2동   179982  8614747910   49810.666667   633.250000
# 29      농축수산물    이호동     5187   341334490    4360.000000   146.916667
# 30      농축수산물   일도1동     8754   706061230    2960.416667   100.916667
# 31      농축수산물   일도2동    83739  5445378988   34763.250000   288.416667
# 32      농축수산물    정방동     6810   699541244    2394.583333   106.750000
# 33      농축수산물    조천읍    29020  2473174255   23811.500000   569.750000
# 34      농축수산물    중문동     7230  1233185127   10979.583333   295.083333
# 35      농축수산물    중앙동    11510  1111175737    3932.416667   106.833333
# 36      농축수산물    천지동     9752  1149670706    3555.000000   106.500000
# 37      농축수산물    추자면     1065    81596084    1831.666667   347.000000
# 38      농축수산물    표선면    13531  2130352875   12340.166667   420.750000
# 39      농축수산물    한경면     6060   635625965    9047.083333   337.500000
# 40      농축수산물    한림읍    18000  2121137722   21113.250000  3634.500000
# 41      농축수산물    화북동    78000  4097640697   25047.500000   382.166667
# 42      농축수산물    효돈동     4434   394512547    5316.083333    82.833333
#
#        total_pop
# 0    9993.166667
# 1   16233.333333
# 2   19837.583333
# 3   55546.333333
# 4   13964.666667
# 5   22891.083333
# 6   13691.083333
# 7    3185.083333
# 8   24037.750000
# 9    4168.333333
# 10  14518.250000
# 11   8813.666667
# 12  24655.416667
# 13  10756.333333
# 14  17106.666667
# 15   4985.500000
# 16  33310.833333
# 17  12341.333333
# 18  35921.416667
# 19  43178.750000
# 20   5399.000000
# 21   4246.416667
# 22  14394.083333
# 23  21475.000000
# 24   7736.583333
# 25  15791.916667
# 26   1906.333333
# 27   8020.166667
# 28  50443.916667
# 29   4506.916667
# 30   3061.333333
# 31  35051.666667
# 32   2501.333333
# 33  24381.250000
# 34  11274.666667
# 35   4039.250000
# 36   3661.500000
# 37   2178.666667
# 38  12760.916667
# 39   9384.583333
# 40  24747.750000
# 41  25429.666667
# 42   5398.916667

# %%
# Merge 마트/슈퍼마켓 DataFrame
마트_2018 = pd.merge(food_2018_마트, pop_2018_dong, how='inner')
마트_2019 = pd.merge(food_2019_마트, pop_2019_dong, how='inner')
마트_2020 = pd.merge(food_2020_마트, pop_2020_dong, how='inner')
마트_2021 = pd.merge(food_2021_마트, pop_2021_dong, how='inner')

# %%
# Merge 배달 DataFrame
배달_2018 = pd.merge(food_2018_배달, pop_2018_dong, how='inner')
배달_2019 = pd.merge(food_2019_배달, pop_2019_dong, how='inner')
배달_2020 = pd.merge(food_2020_배달, pop_2020_dong, how='inner')
배달_2021 = pd.merge(food_2021_배달, pop_2021_dong, how='inner')

# %%
# Merge 식품 DataFrame
식품_2018 = pd.merge(food_2018_식품, pop_2018_dong, how='inner')
식품_2019 = pd.merge(food_2019_식품, pop_2019_dong, how='inner')
식품_2020 = pd.merge(food_2020_식품, pop_2020_dong, how='inner')
식품_2021 = pd.merge(food_2021_식품, pop_2021_dong, how='inner')

# %%
# Merge 간식 DataFrame
간식_2018 = pd.merge(food_2018_간식, pop_2018_dong, how='inner')
간식_2019 = pd.merge(food_2019_간식, pop_2019_dong, how='inner')
간식_2020 = pd.merge(food_2020_간식, pop_2020_dong, how='inner')
간식_2021 = pd.merge(food_2021_간식, pop_2021_dong, how='inner')

# %%
농축_2018.corr()
# Out:
#                 use_cnt   use_amt  resid_reg_pop  foreign_pop  total_pop
# use_cnt        1.000000  0.924262       0.842491     0.237590   0.830369
# use_amt        0.924262  1.000000       0.913197     0.378257   0.906372
# resid_reg_pop  0.842491  0.913197       1.000000     0.538511   0.999028
# foreign_pop    0.237590  0.378257       0.538511     1.000000   0.575127
# total_pop      0.830369  0.906372       0.999028     0.575127   1.000000

# %%
# 2018년 업종별 Correlation
plt.figure(figsize=(28, 4))

plt.subplot(151)
sns.heatmap(농축_2018.corr(), annot=True, cmap='Greys')
plt.title('2018년 농축수산물 Correlation')

plt.subplot(152)
sns.heatmap(마트_2018.corr(), annot=True, cmap='Greys')
plt.title('2018년 마트/슈퍼마켓 Correlation')

plt.subplot(153)
sns.heatmap(배달_2018.corr(), annot=True, cmap='Greys')
plt.title('2018년 배달 Correlation')

plt.subplot(154)
sns.heatmap(식품_2018.corr(), annot=True, cmap='Greys')
plt.title('2018년 식품 Correlation')

plt.subplot(155)
sns.heatmap(간식_2018.corr(), annot=True, cmap='Greys')
plt.title('2018년 간식 Correlation')

plt.show()

# %%
# 2019년 업종별 Correlation
plt.figure(figsize=(28, 4))

plt.subplot(151)
sns.heatmap(농축_2019.corr(), annot=True, cmap='Blues')
plt.title('2019년 농축수산물 Correlation')

plt.subplot(152)
sns.heatmap(마트_2019.corr(), annot=True, cmap='Blues')
plt.title('2019년 마트/슈퍼마켓 Correlation')

plt.subplot(153)
sns.heatmap(배달_2019.corr(), annot=True, cmap='Blues')
plt.title('2019년 배달 Correlation')

plt.subplot(154)
sns.heatmap(식품_2019.corr(), annot=True, cmap='Blues')
plt.title('2019년 식품 Correlation')

plt.subplot(155)
sns.heatmap(간식_2019.corr(), annot=True, cmap='Blues')
plt.title('2019년 간식 Correlation')

plt.show()

# %%
# 2020년 업종별 Correlation
plt.figure(figsize=(28, 4))

plt.subplot(151)
sns.heatmap(농축_2020.corr(), annot=True, cmap='Greens')
plt.title('2020년 농축수산물 Correlation')

plt.subplot(152)
sns.heatmap(마트_2020.corr(), annot=True, cmap='Greens')
plt.title('2020년 마트/슈퍼마켓 Correlation')

plt.subplot(153)
sns.heatmap(배달_2020.corr(), annot=True, cmap='Greens')
plt.title('2020년 배달 Correlation')

plt.subplot(154)
sns.heatmap(식품_2020.corr(), annot=True, cmap='Greens')
plt.title('2020년 식품 Correlation')

plt.subplot(155)
sns.heatmap(간식_2020.corr(), annot=True, cmap='Greens')
plt.title('2020년 간식 Correlation')

plt.show()

# %%
# 2021년 업종별 Correlation
plt.figure(figsize=(28, 4))

plt.subplot(151)
sns.heatmap(농축_2021.corr(), annot=True, cmap='Oranges')
plt.title('2021년 농축수산물 Correlation')

plt.subplot(152)
sns.heatmap(마트_2021.corr(), annot=True, cmap='Oranges')
plt.title('2021년 마트/슈퍼마켓 Correlation')

plt.subplot(153)
sns.heatmap(배달_2021.corr(), annot=True, cmap='Oranges')
plt.title('2021년 배달 Correlation')

plt.subplot(154)
sns.heatmap(식품_2021.corr(), annot=True, cmap='Oranges')
plt.title('2021년 식품 Correlation')

plt.subplot(155)
sns.heatmap(간식_2021.corr(), annot=True, cmap='Oranges')
plt.title('2021년 간식 Correlation')

plt.show()
