# %% [markdown]
# # **Exploratory Data Analysis**

# %%
import pandas as pd
import numpy as np

import folium

import warnings
warnings.filterwarnings('ignore')
# pd.set_option('display.max_rows', None)

# %% [markdown]
# ## **1. 신규 아파트 단지 정보**

# %%
new = pd.read_csv('../../../../../Source/2021 빅콘테스트/2021 빅콘테스트_지역활성화/금융-부동산/부동산 데이터_지인플러스/신규 아파트 단지 정보.csv', encoding='utf-8')

new.head()
# Out:
#    BLDID_ID     HSCPX_NM    LGDNG_CD   BUN   JI  TOTHH_CT         LA  \
# 0       118       덕진왈츠2차  4822031000  1203  0.0       191  34.886332
# 1       176        센트럴파크  4513013400   769  4.0       480  35.962803
# 2       454     통영해모로오션힐  4822011000   714  0.0      1023  34.852882
# 3       548  군산디오션시티푸르지오  4513013400  3943  0.0      1400  35.978804
# 4       549      힐스테이트은파  4513031000  1046  0.0       449  35.947328
#
#          LNGT CMPL_PARG_DATE
# 0  128.467934     2017-11-01
# 1  126.738385     2017-10-01
# 2  128.426743     2018-10-01
# 3  126.740314     2018-03-01
# 4  126.714438     2015-09-01

# %%
for i in range(len(new['LGDNG_CD'])):
    new['LGDNG_CD'][i] = str(new['LGDNG_CD'][i])[0:4]

new.tail()
# Out:
#     BLDID_ID    HSCPX_NM  LGDNG_CD   BUN    JI  TOTHH_CT         LA  \
# 40     12721   목포한양립스더포레      4611   986   0.0       648  34.827220
# 41     12874   더샵디오션시티2차      4513     2  28.0       771  35.981304
# 42     12895      한성필하우스      4513   806   3.0       892  35.967621
# 43     12952     디엘본S136      4822  1582   2.0       136  34.876258
# 44     13072  군산호수공원아이파크      4513    66   0.0       665  35.955118
#
#           LNGT CMPL_PARG_DATE
# 40  126.416791     2023-09-01
# 41  126.746077     2023-07-01
# 42  126.565768     2012-08-01
# 43  128.421003     2023-11-01
# 44  126.705160     2024-01-01

# %%
new['LGDNG_CD'].value_counts()
# Out:
# 4611    18
# 4513    16
# 4822    11
# Name: LGDNG_CD, dtype: int64

# %% [markdown]
# 군산 16개 / 목포 18개 / 통영 11개

# %%
new_apt = new.drop(['BLDID_ID', 'BUN', 'JI', 'CMPL_PARG_DATE'], axis=1)

new_apt.head()
# Out:
#       HSCPX_NM  LGDNG_CD  TOTHH_CT         LA        LNGT
# 0       덕진왈츠2차      4822       191  34.886332  128.467934
# 1        센트럴파크      4513       480  35.962803  126.738385
# 2     통영해모로오션힐      4822      1023  34.852882  128.426743
# 3  군산디오션시티푸르지오      4513      1400  35.978804  126.740314
# 4      힐스테이트은파      4513       449  35.947328  126.714438

# %%
type(new_apt.TOTHH_CT[0])
# Out:
# numpy.int64

# %%
new_apt.TOTHH_CT[0]*0.01
# Out:
# 1.9100000000000001

# %%
GunSan_new = new[new['LGDNG_CD'] == 4513]
GunSan_new = GunSan_new.reset_index()
GunSan_new.drop('index', axis=1, inplace=True)
MokPo_new = new[new['LGDNG_CD'] == 4611]
MokPo_new = MokPo_new.reset_index()
MokPo_new.drop('index', axis=1, inplace=True)
TongYeong_new = new[new['LGDNG_CD'] == 4822]
TongYeong_new = TongYeong_new.reset_index()
TongYeong_new.drop('index', axis=1, inplace=True)

# %% [markdown]
# ### **① GunSan**

# %%
# 지도 새로 띄우기
m_GunSan_new = folium.Map([np.mean(GunSan_new['LA']), np.mean(GunSan_new['LNGT'])], zoom_start=12)

for i in GunSan_new.index:
    sub_lat = GunSan_new.loc[i, 'LA']
    sub_long = GunSan_new.loc[i, 'LNGT']
    
    title = GunSan_new.loc[i, 'HSCPX_NM']
    
    color = 'red'
    
    # 지도에 동그라미로 데이터 찍기
    folium.CircleMarker([sub_lat, sub_long], color=color, radius=GunSan_new.TOTHH_CT[i]*0.02, tootip=title, fill=True).add_to(m_GunSan_new)

m_GunSan_new.save('apt_GunSan_new.html')

m_GunSan_new
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ### **② MokPo**

# %%
# 지도 새로 띄우기
m_MokPo_new = folium.Map([np.mean(MokPo_new['LA']), np.mean(MokPo_new['LNGT'])], zoom_start=12)

for i in MokPo_new.index:
    sub_lat = MokPo_new.loc[i, 'LA']
    sub_long = MokPo_new.loc[i, 'LNGT']
    
    title = MokPo_new.loc[i, 'HSCPX_NM']
    
    color = 'green'
    
    # 지도에 동그라미로 데이터 찍기
    folium.CircleMarker([sub_lat, sub_long], color=color, radius=MokPo_new.TOTHH_CT[i]*0.02, tootip=title, fill=True).add_to(m_MokPo_new)

m_MokPo_new.save('apt_MokPo_new.html')

m_MokPo_new
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ### **③ TongYeong**

# %%
# 지도 새로 띄우기
m_TongYeong_new = folium.Map([np.mean(TongYeong_new['LA']), np.mean(TongYeong_new['LNGT'])], zoom_start=12)

for i in TongYeong_new.index:
    sub_lat = TongYeong_new.loc[i, 'LA']
    sub_long = TongYeong_new.loc[i, 'LNGT']
    
    title = TongYeong_new.loc[i, 'HSCPX_NM']
    
    color = 'blue'
    
    # 지도에 동그라미로 데이터 찍기
    folium.CircleMarker([sub_lat, sub_long], color=color, radius=TongYeong_new.TOTHH_CT[i]*0.02, tootip=title, fill=True).add_to(m_TongYeong_new)

m_TongYeong_new.save('apt_TongYeong_new.html')

m_TongYeong_new
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ## **2. 아파트 단지 정보**

# %%
old = pd.read_csv('../../../../../Source/2021 빅콘테스트/2021 빅콘테스트_지역활성화/금융-부동산/부동산 데이터_지인플러스/아파트 단지 정보.csv', encoding='utf-8')

old.head()
# Out:
#    BLDID_ID HSCPX_NM    LGDNG_CD   BUN  JI  TOTDG_CT  \
# 0       628   푸르지오3차  4822034000  1575   0         6
# 1       650   한선파라디움  4822034000  1578   2         5
# 2      1714  양우비치팰리스  4611015800  1137  21         1
# 3      1881    신안비치2  4611010200  1259   0         3
# 4      1884   신안비치3차  4611010200  1259   3         3
#
#                                            DNGINF_CN  TOTHH_CT  MSR_RT  BLDLR  \
# 0  301/43/1104302/42/1104303/43/1104304/44/110430...       258   192.0   27.0
# 1  301동/112/1508302동/56/1504303동/56/1504304동/56/1...       336   214.0   22.0
# 2                                        1동/122/1806       122   657.0   62.0
# 3            201동/315/1523202동/180/1513203동/150/1511       645   285.0   22.0
# 4            301동/120/1509302동/165/1512303동/210/1515       495     0.0   23.0
#
#    TOP_FLCT  TOTPRK_ECCT  PHSHD_PRKG_ECCT         LA        LNGT  CMPL_DATE
# 0        11          296             1.15  34.881012  128.416495   20091101
# ...

# %%
for i in range(len(old['LGDNG_CD'])):
    old['LGDNG_CD'][i] = str(old['LGDNG_CD'][i])[0:4]

old.tail()
# Out:
#      BLDID_ID    HSCPX_NM  LGDNG_CD   BUN  JI  TOTDG_CT  \
# 694     75229     상동주공3단지      4611   740   0         8
# 695     75544      대경천사캐슬      4611   778   0         1
# 696     76216      송림비치맨션      4822    58  11         3
# 697     76219       대일아파트      4822   345   0         2
# 698     76346  목포산정대광로제비앙      4611  1840   0         8
#
#                                              DNGINF_CN  TOTHH_CT  MSR_RT  \
# 694  301동/149세대|302동/149세대|303동/150세대|304동/149세대|30...      1076     NaN
# 695                                            1동/81세대        76   477.0
# 696                         1호동/24세대|1호동/24세대|2호동/24세대        72     NaN
# 697                                    1동/20세대|1동/30세대        50     NaN
# 698  101동/29세대|102동/66세대|103동/58세대|104동/50세대|105동/9...       416   207.0
#
#      BLDLR  TOP_FLCT  TOTPRK_ECCT  PHSHD_PRKG_ECCT         LA        LNGT  \
# 694    NaN        15            0             0.00  34.815746  126.413525
# ...

# %%
old['LGDNG_CD'].value_counts()
# Out:
# 4611    267
# 4513    243
# 4822    189
# Name: LGDNG_CD, dtype: int64

# %% [markdown]
# 군산 257개 / 목포 270개 / 통영 172개

# %%
old_apt = old.drop(['BLDID_ID', 'BUN', 'JI', 'TOTDG_CT', 'DNGINF_CN', 'MSR_RT', 'BLDLR', 'TOP_FLCT', 'TOTPRK_ECCT', 'PHSHD_PRKG_ECCT', 'CMPL_DATE'], axis=1)

old_apt.head()
# Out:
#   HSCPX_NM  LGDNG_CD  TOTHH_CT         LA        LNGT
# 0   푸르지오3차      4822       258  34.881012  128.416495
# 1   한선파라디움      4822       336  34.878144  128.416949
# 2  양우비치팰리스      4611       122  34.796653  126.430692
# 3    신안비치2      4611       645  34.807088  126.368558
# 4   신안비치3차      4611       495  34.806302  126.367444

# %%
GunSan_old = old[old['LGDNG_CD'] == 4513]
GunSan_old = GunSan_old.reset_index()
GunSan_old.drop('index', axis=1, inplace=True)
MokPo_old = old[old['LGDNG_CD'] == 4611]
MokPo_old = MokPo_old.reset_index()
MokPo_old.drop('index', axis=1, inplace=True)
TongYeong_old = old[old['LGDNG_CD'] == 4822]
TongYeong_old = TongYeong_old.reset_index()
TongYeong_old.drop('index', axis=1, inplace=True)

# %% [markdown]
# ### **① GunSan**

# %%
# 지도 새로 띄우기
m_GunSan_old = folium.Map([np.mean(GunSan_new['LA']), np.mean(GunSan_new['LNGT'])], zoom_start=12)

for i in GunSan_old.index:
    sub_lat = GunSan_old.loc[i, 'LA']
    sub_long = GunSan_old.loc[i, 'LNGT']
    
    title = GunSan_old.loc[i, 'HSCPX_NM']
    
    color = 'red'
    
    # 지도에 동그라미로 데이터 찍기
    folium.CircleMarker([sub_lat, sub_long], color=color, radius=5, tootip=title, fill=True).add_to(m_GunSan_old)

m_GunSan_old.save('apt_GunSan_old.html')

m_GunSan_old
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ### **② MokPo**

# %%
# 지도 새로 띄우기
m_MokPo_old = folium.Map([np.mean(MokPo_new['LA']), np.mean(MokPo_new['LNGT'])], zoom_start=12)

for i in MokPo_old.index:
    sub_lat = MokPo_old.loc[i, 'LA']
    sub_long = MokPo_old.loc[i, 'LNGT']
    
    title = MokPo_old.loc[i, 'HSCPX_NM']
    
    color = 'green'
    
    # 지도에 동그라미로 데이터 찍기
    folium.CircleMarker([sub_lat, sub_long], color=color, radius=5, tootip=title, fill=True).add_to(m_MokPo_old)

m_MokPo_old.save('apt_MokPo_old.html')

m_MokPo_old
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# ### **③ TongYeong**

# %%
# 지도 새로 띄우기
m_TongYeong_old = folium.Map([np.mean(TongYeong_new['LA']), np.mean(TongYeong_new['LNGT'])], zoom_start=12)

for i in TongYeong_old.index:
    sub_lat = TongYeong_old.loc[i, 'LA']
    sub_long = TongYeong_old.loc[i, 'LNGT']
    
    title = TongYeong_old.loc[i, 'HSCPX_NM']
    
    color = 'blue'
    
    # 지도에 동그라미로 데이터 찍기
    folium.CircleMarker([sub_lat, sub_long], color=color, radius=5, tootip=title, fill=True).add_to(m_TongYeong_old)

m_TongYeong_old.save('apt_TongYeong_old.html')

m_TongYeong_old
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
